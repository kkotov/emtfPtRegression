# %% [markdown]
# ## Formulating the problem
#
# A charged particle propagates through the four layers of steel plates returning
# magnetic flux of the solenoid and the four interleaving "sensitive" layers of the
# detector. The sensitive layers report coordinates and bend angles of the individual
# track segments (highlighted with red arrows in the sketch below):
#
# <img src="https://kkotov.github.io/hep/bend4.png" width=600px />
#
# Collected information is used for the track building and particle's momentum assessment.
# Multiple scattering effects and non-uniform magnetic field render analytical momentum
# assignment impractical. A better solution is building a statistical model regressing
# coordinates of the track segments to the particle's momentum. The model can be trained
# using either Monte Carlo simulation (as in the current study) or real data where the
# target momentum is evaluated with help of another detector subsystem.
#
# This notebook outlines model building and selection using Apache Spark with python (PySpark).
# Since so many people "speak" nothing else but python when it comes to data analysis, I repeat my
# originally study $[$[1](https://kkotov.github.io/emtfPtRegression/2017.01.19/handout.html),
# [2](https://kkotov.github.io/emtfPtRegression/2017.02.10/handout.html),
# [3](https://kkotov.github.io/emtfPtRegression/2017.03.03/handout.html),
# [4](https://kkotov.github.io/emtfPtRegression/2017.03.17/handout.html)$]$
# (with some corrections, though) using these popular tools.

# %% [markdown]
# ## Preparing data (in place of codebook)
#
# The main quantities that are directly related to the curvature of track and, therefore, to its momentum (later referred to as pT)
# are summarized in the following table:
#
# type             | measurement in layer #
# -----------------|---------------------------
#  $\theta$        |           2
#  $\Delta\phi$    | 1-2, 1-3, 1-4, 2-3, 2-4, 3-4
#  $\Delta\theta$  | 1-2, 1-3, 1-4, 2-3, 2-4, 3-4
#  bend            |       1, 2, 3, 4
#
# These predictors were also complemented with several surrogate combinations and compressed using the 'Andrew's scheme" from the [calculate_pt_xml](https://github.com/cms-sw/cmssw/blob/master/L1Trigger/L1TMuonEndCap/src/PtAssignmentEngine2017.cc)
# function. The scheme was ported as is to the [logging module](https://github.com/kkotov/framework/blob/master/workdir/Analyser.cc)
# and ran on CMS EDM files as part of my [analysis pipeline system](http://koskot77.github.io/framework). The result was saved in a simple csv file included below. The original CMS EDM files were located on CERN eos system under */store/user/abrinke1/EMTF/MC/SingleMu_Pt1To1000_FlatRandomOneOverPt/*.

# %%
# Load csv file containing ~300K simulated entries (rows) of predictors and the response from local HDFS
dataframe0 = (sqlContext
                         .read.format("com.databricks.spark.csv")
                         .options(delimiter=',',header='true',inferschema='true')
                         .load("hdfs://localhost:9000/data/oldSim.csv"))

# %%
# Each entry (row) contains two particles (as these are di-muon events)
# Let's transform this into a new "one row - one trajectory" table
# Also note the st1_ring2, dPhiS*, and rpc* surrogate predictors that
# were "cooked up" from the original measurements with Andrew's tools

sqlContext.sql("DROP TABLE IF EXISTS raw_data")
sqlContext.registerDataFrameAsTable(dataframe0,"raw_data")

dataframe1 = sqlContext.sql("""SELECT
                            `ptXML[0]` AS pt,
                            `muPtGen[0]` AS ptTrue,
                            1./`muPtGen[0]` AS ptTrueInv,                            
                            `theta[0]` AS theta,
                            `st1_ring2[0]` AS st1_ring2,
                            `dPhi12[0]` AS dPhi12,
                            `dPhi13[0]` AS dPhi13,
                            `dPhi14[0]` AS dPhi14,
                            `dPhi23[0]` AS dPhi23,
                            `dPhi24[0]` AS dPhi24,
                            `dPhi34[0]` AS dPhi34,
                            `dTheta12[0]` AS dTheta12,
                            `dTheta13[0]` AS dTheta13,
                            `dTheta14[0]` AS dTheta14,
                            `dTheta23[0]` AS dTheta23,
                            `dTheta24[0]` AS dTheta24,
                            `dTheta34[0]` AS dTheta34,
                            `dPhiS4[0]`   AS dPhiS4,
                            `dPhiS4A[0]`  AS dPhiS4A,
                            `dPhiS3[0]`   AS dPhiS3,
                            `dPhiS3A[0]`  AS dPhiS3A,
                            `clct1[0]`    AS clct1,
                            `clct2[0]`    AS clct2,
                            `clct3[0]`    AS clct3,
                            `clct4[0]`    AS clct4,
                            `fr1[0]`      AS fr1,
                            `fr2[0]`      AS fr2,
                            `fr3[0]`      AS fr3,
                            `fr4[0]`      AS fr4,
                            `rpc1[0]`     AS rpc1,
                            `rpc2[0]`     AS rpc2,
                            `rpc3[0]`     AS rpc3,
                            `rpc4[0]`     AS rpc4,
                            `mode[0]`     AS mode
                        FROM raw_data
                        UNION
                        SELECT 
                            `ptXML[1]` AS pt,
                            `muPtGen[1]` AS ptTrue,
                            1./`muPtGen[1]` AS ptTrueInv,                            
                            `theta[1]` AS theta,
                            `st1_ring2[1]` AS st1_ring2,
                            `dPhi12[1]` AS dPhi12,
                            `dPhi13[1]` AS dPhi13,
                            `dPhi14[1]` AS dPhi14,
                            `dPhi23[1]` AS dPhi23,
                            `dPhi24[1]` AS dPhi24,
                            `dPhi34[1]` AS dPhi34,
                            `dTheta12[1]` AS dTheta12,
                            `dTheta13[1]` AS dTheta13,
                            `dTheta14[1]` AS dTheta14,
                            `dTheta23[1]` AS dTheta23,
                            `dTheta24[1]` AS dTheta24,
                            `dTheta34[1]` AS dTheta34,
                            `dPhiS4[1]`   AS dPhiS4,
                            `dPhiS4A[1]`  AS dPhiS4A,
                            `dPhiS3[1]`   AS dPhiS3,
                            `dPhiS3A[1]`  AS dPhiS3A,
                            `clct1[1]`    AS clct1,
                            `clct2[1]`    AS clct2,
                            `clct3[1]`    AS clct3,
                            `clct4[1]`    AS clct4,
                            `fr1[1]`      AS fr1,
                            `fr2[1]`      AS fr2,
                            `fr3[1]`      AS fr3,
                            `fr4[1]`      AS fr4,
                            `rpc1[1]`     AS rpc1,
                            `rpc2[1]`     AS rpc2,
                            `rpc3[1]`     AS rpc3,
                            `rpc4[1]`     AS rpc4,
                            `mode[1]`     AS mode
                        FROM raw_data
                        """)
#print dataframe1.printSchema()

# %%
# Let's see how target variable looks like
# %matplotlib inline
# uncomment the line below to generate all plots in an svg vector format
#%config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt
import numpy as np

plt.hist( [ row['ptTrue'] for row in dataframe1[['ptTrue']].take(10000) ], bins=100 )
plt.yscale('log')
plt.show()

# %% [markdown]
# # Performance metric
#
# The domain-standard trigger turn-on curve, constructed with a certain threshold_pT
# in mind, presents the probability that response_pT > threshold_pT as a function
# of true_pT (aka. *target*). An example of turn-ons for one of the models look as follows:
#
# <img src="https://kkotov.github.io/emtfPtRegression/2017.02.10/assets/fig/unnamed-chunk-5-1.png" width=600px/>
#
# The main limitation of the turn-on metric is that the model curves
# have to be visually compared for a series of thresholds, which a rather
# labor-intensive exercise. Moreover, such metric also does not offer a good quantitative
# way to account for the spectrum: due to abundance of low true_pT events a sharp
# turn-on with a long left tail may do better as well as do worse compared to broad
# turn-on with a smaller tail. The Receiver Operating Characteristic (ROC) curve
# is free from such limitations, incorporate the spectrum shape (prevalence of
# events with different true_pT), and can be quantified
# with a simple area-under-the-curve (AUC) parameter.
#
# Before introducing the ROC metric let me start with the spectrum shape and call it
# rate. For some given threshold_pT the convolution of turn-on (again, probability
# of accepting the event) with the rate in
# the range of [0 < true_pT < threshold_pT] gives a number of false-positive events
# and in the range of [threshold_pT < true_pT < inf] gives true-positives. These
# numbers, normalized by the integrals of the rate in the two regions, give the
# true-/false-positive probabilities. Here is a graphical representation of how
# true-/false-positive are defined with respect to some threshold:
#
# <img src="https://kkotov.github.io/emtfPtRegression/2017.02.10/convolve.svg" width=500px/>
#
# In this scenario the "natural parameter"
# identifying a point on the ROC curve is the threshold_pT. In the code below
# I generate the ROC curve running over the grid of threshold_pT defined by the
# **binning** array.

# %%
import numpy as np

def findBin(val, binning, begin=0, end=-1): 
    """Find bin index of `val` in the `binning`
    Args:
        val (float): value of initerest
        binning (np.ndarray): sorted array of N bin boundaries for N-1 bins
        begin (int), end (int): helper values of the binary search, never to be used explicitly
    Returns:
        bin number (int) from [-1:N-1] range where N-1 means overflow, -1 is underflow, and None for errors
    """
    # first (user made) call
    if end < begin:
        end = len(binning)
        # Sanity check
    if len(binning) < 1 or end <= begin:
        return None
    # underflow goes to the before-the-first bin
    if val <  binning[begin]:
        return int(begin-1)
    # overlow goes to the next-to-the-last bin
    if val >= binning[end-1]:
        return int(end-1)
    # partition at the middle boundary
    center = int((end-begin-1)/2) + begin
    # got lucky?
    if val >= binning[center] and val < binning[center+1]:
        return center
    # binary search:
    if val < binning[center]:
        return findBin(val, binning, begin, center)
    else:
        return findBin(val, binning, center+1, end)

    
import pandas as pd

def rocMetric(events, binning):
    """
    Args:
        events (np.ndarray): input matrix consisting of three columns
                             'targets' - target values
                             'predictions' - predicted values
                             'weights' - bayes correction: over-/under-sample training
                                         instances according to the given weights
                                         (e.g. real `target` spectrum should follow x^-3,
                                          while provided values are destributed as x^-1,
                                          hence each should have a weight proportional to x^-2)
        binning  (np.ndarray): sorted array of N bin boundaries for N-1 bins
    Returns:
        dictionary {thresholdBin: (false_positive_rate, true_positive_rate)}
    """
    binnedByTargets = np.array( [ (e['target'],
                                   e['weight'],
                                   e['prediction'],
                                   findBin(e['target'],binning)
                                   ) for e in events ],
                                dtype  = [('target', np.float),
                                          ('weight', np.float),
                                          ('prediction', np.float),
                                          ('bin', np.int32)]
                      )

    groupedByTargetBins = pd.DataFrame(binnedByTargets).groupby('bin')

    weightOfTargetsAboveThr = map(lambda thr:
                                  dict([ (bin, sum(np.array(pdf['weight'])*np.array(pdf['prediction']>=thr)))
                                     for (bin,pdf) in groupedByTargetBins
                                  ]),
                                  binning
                              )

    falsePos =  [ sum([weight for (trueBin,weight) in wAbove.items() if trueBin<0 or binning[trueBin] < thr])
                  for (thr, wAbove) in zip(binning, weightOfTargetsAboveThr)
                ]

    truePos  =  [ sum([weight for (trueBin,weight) in wAbove.items() if trueBin>=0 and binning[trueBin] >= thr])
                  for (thr, wAbove) in zip(binning, weightOfTargetsAboveThr)
                ]

    cumsumBelow = [ sum([ sum(pdf['weight']) for (bin,pdf) in groupedByTargetBins if bin<x ]) for x in range(len(binning)) ]
    cumsumAbove = [ sum([ sum(pdf['weight']) for (bin,pdf) in groupedByTargetBins if bin>=x ]) for x in range(len(binning)) ]

    truePos  = [ v/cumsum if v>0 else 0 for (v,cumsum) in zip(truePos,cumsumAbove)  ]
    falsePos = [ v/cumsum if v>0 else 0 for (v,cumsum) in zip(falsePos,cumsumBelow) ]
    
    return dict(zip(binning, zip(falsePos,truePos)));


# a bit of unit testing is always a good practice
import unittest

class TestSomeBins(unittest.TestCase): 
    def testBins(self):                          
        """findBin should give known result with known input"""
        step = 1/2.
        binning = np.arange(0,10,step)
        self.assertEqual([ (v,findBin(v,binning)) for v in [1,2,3,4,5,6,7,8,9] ], 
                         [ (v,v/step) for v in [1,2,3,4,5,6,7,8,9] ])

    
class TestSomeROCs(unittest.TestCase): 
    def testROCs(self):                          
        """rocMetric should give known result with known input"""
        events = np.array( [(1.,1.1,0.1),    # underflow for a binning starting at threshold=1.5
                            (2.,1.9,0.01),   # count as inefficiency for threshold=2
                            (2.3,2.51,0.02), # place in falsePos for threshold=2.5, truePos otherwise
                            (3.,3.,0.005)],  # place in truePos (on the edge)
                    dtype = [('target', np.float), ('prediction', np.float), ('weight', np.float)]
        )
        binning = np.arange(1.5,3,0.5)  # three bins total
        roc = rocMetric(events, binning)
        result = sorted([ (findBin(thr, binning),(falsePos,truePos)) for (thr,(falsePos,truePos)) in roc.items()],
                        key = lambda x: x[0])
        expect = [(0, (0, (0.01+0.02+0.005)/(0.01+0.02+0.005))),
                  (1, (0, (0.02+0.005)/(0.01+0.02+0.005))),
                  (2, (0.02/(0.1+0.01+0.02), 0.005/0.005))]
        bins     = [ b for (b,(f,t)) in result ]
        falsePos = [ f for (b,(f,t)) in result ]
        truePos  = [ t for (b,(f,t)) in result ]
        self.assertEqual( np.allclose(bins,     [ b for (b,(f,t)) in expect]), True)
        self.assertEqual( np.allclose(falsePos, [ f for (b,(f,t)) in expect]), True)
        self.assertEqual( np.allclose(truePos,  [ t for (b,(f,t)) in expect]), True)

unittest.main(argv=['ignored', '-v'], exit=False)
# Out:
# testBins (__main__.TestSomeBins)
# findBin should give known result with known input ...
# ok
# testROCs (__main__.TestSomeROCs)
# rocMetric should give known result with known input ...
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.009s
#
# OK

# %% [markdown]
# I'll be visually comparing a lot of ROC curves with a universal plotting function below. Feel free to skip this entire block as it is nothing else but a bulky matplotlib visualization code.

# %%
def prepareRocPlot(falseTruePos, refThresh = {}, legPos = 'upper left'):
    """
    Function for plotting the ROC curves; all aesthetics is hardcoded
    Args:
        falseTruePos: dictionary associating curve name (appears on the legend) 
                      to the tuple of return value of the rocMetric call and color
        refThresh: dictionary of points {thresholds:color} highlited along the ROC curves
    Returns:
        figure and axises
    """
    plt.close()

    # a bit of hardcoded aesthetics below
    fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
    ax0.set_ylabel(r"True positive rate", fontsize=18)
    ax0.set_xlabel(r"False positive rate", fontsize=18)
    ax0.set_ylim(0.7, 1.)
    ax0.set_xlim(0.001, 1.)
    ax0.set_xscale('log')
    plt.title("ROC curves comparison", fontsize=20)

    curves = {}
    points = {}
    
    for (name,(roc,color)) in falseTruePos.items():
        falsePos = [ f for (thr,(f,t)) in roc.items()]
        truePos  = [ t for (thr,(f,t)) in roc.items()]
        curves[name] = plt.scatter(falsePos, truePos, s = 30, c = color, edgecolors = color)
        points[name] = []
        binnedROC = { findBin(thr,binning): point for (thr,point) in roc.items() }
        for (thr,col) in refThresh.items():
            xThr = binnedROC[findBin(thr, binning)][0]
            yThr = binnedROC[findBin(thr, binning)][1]
            points[name].append( plt.scatter([xThr], [yThr], s = 30, c = col, edgecolors = col, marker='^') )

    curves.pop(None, None)
    items = curves.values()
    names = curves.keys()

    if points.items() and points.items()[0][1]:
        items.extend( points.items()[0][1] )
        names.extend( [ str(thr)+" GeV threshold position" for thr in refThresh.keys() ] )

    if items:
        plt.legend( items,
                    names,
                    scatterpoints = 1,
                    loc = legPos,
                    ncol = 1,
                    fontsize = 15
                  )

    return fig, ax0

# %% [markdown]
# ## Univariate linear regression
#
# Let's now perform the simplest non-regularized linear regression that predicts **ptTrueInv** (~curvature) from difference of $\phi$ coordinates in the first and second layers **dPhi12**. Although, difference in $\phi$ coordinate can be positive and negative, in our compression scheme all of the differences are already given by the absolute value while the relative signs are accounted in **dPhiS** surrogate variables

# %%
from pyspark.sql.functions import lit, pow, col, log

# Create 1/pT^2 weight column that, combined with the 1/pT original spectrum, can be used
#  to account 1/pT^3 rate suggested in https://kkotov.github.io/emtfPtRegression/2017.03.03/handout.html
# Also filter highest quality events that have measuements (coordinates) in each of the four layers (mode==15)
dataframe2 = (dataframe1
                 .withColumn('weight', pow(col('ptTrueInv'),2))
                 .filter(dataframe1.mode == 15)
             )

print "Starting with ", dataframe2.count(), " rows"
# Out:
# Starting with
# 339727  rows

# %%
from pyspark.sql.functions import explode, udf
from pyspark.sql.types import IntegerType, ArrayType
# Following the last response from
# https://stackoverflow.com/questions/34360324/scala-spark-sample-with-replacement-specify-probabilities
# for "samplig" I implement an entire bloody routine, that would otherwise be a true one-liner in R:
#  dataframe2[ sample(seq_len(nrow(dataframe2)), size = 100000, replace = T, prob = dataframe2$weight), ]

createDups = udf(lambda s: range(np.random.poisson(s*10000)), ArrayType(IntegerType()))
dataframe3 = dataframe2.select('*',explode(createDups(dataframe2.weight))).sample(True,0.01,123) #.limit(300000)

print "After reweighting I have ", dataframe3.count(), " rows"
print "Events with pT>150 GeV before reweighting: ", dataframe2[ dataframe2.ptTrue > 150 ].count()
print "Events with pT>150 GeV after reweighting:  ", dataframe3[ dataframe3.ptTrue > 150 ].count()

(trainingData, testData) = dataframe3.randomSplit([0.7, 0.3])
# Out:
# After reweighting I have
# 466926  rows
# Events with pT>150 GeV before reweighting:
# 111309
# Events with pT>150 GeV after reweighting:
# 130

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression

# Spark models consume feature vector that needs to be built from columns of predictors
oneFeature = VectorAssembler(inputCols=["dPhi12"], outputCol="features")

# no regularization for the linear regression yet
linearReg = LinearRegression(maxIter = 10,
                             regParam = 0.0,
                             elasticNetParam = 1.0,
                             standardization = False,
                             labelCol = "ptTrueInv",
#                             weightCol = "weight"
                             )
# I weight-sample the source data in the previous cell rather than directly use the weights column
#  commented out above because only the linear model supports such column-based reweighting
#  while I need to put apples to apples when comparing other "non-reweightable" models to it

# chaining the transformations
lrPipeline = Pipeline(stages=[oneFeature, linearReg])

# Fit the model
linearModel = lrPipeline.fit(trainingData)
#print "Intercept: ", linearModel.stages[1].intercept, ",  slope: ", linearModel.stages[1].coefficients

linearTest = linearModel.transform(testData)[['ptTrueInv','dPhi12','prediction','weight']].collect() #take(10000)

# %%
# gosh, in R the construct below would fit into a single subsetting statement, no more comments ...
skim = np.array( [ (1./row['ptTrueInv'], 1./row['prediction'], row['dPhi12'], 1)
                   for row in linearTest
                 ], dtype  = [('target', np.float),
                              ('prediction', np.float),
                              ('dPhi12', np.float),
                              ('weight', np.float)]
       )
# Note inverting target and prediction back to the physics scale above

# Let's now look at the fit visually
plt.close()
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
ax0.set_ylabel(r"Simulated 1/$p_T$ values (targets)", fontsize=18)
ax0.set_xlabel(r"Measured $\Delta \phi_{12}$ values", fontsize=18)
ax0.set_ylim(0, 1.)
ax0.set_xlim(0, 500)
plt.scatter(skim['dPhi12'], 1./skim['target'], s=14**2, c='#d6ebf2', edgecolors='#8cbfd0', alpha=1.)

x_vals = np.array(ax0.get_xlim())
y_vals = linearModel.stages[1].intercept + linearModel.stages[1].coefficients * x_vals

plt.plot(x_vals, y_vals, linewidth=3.0, c='#0cbfd0', linestyle='--')
plt.title("Fitting a linear model to dPhi12", fontsize=20)
plt.show()

# %% [markdown]
# The plot above shows the inflexibility of the linear model. The RMSE optimization against **1/pT** target down-weight the contribution from high **pT** or low **dPhi12** rows. As the result, oppositely to the common sense that suggest that straight tracks (**1/pT** ~= 0) should have little bending (**dPhi12** ~= 0), the intercept does not cross the coordinate origin.

# %%
# Simplese in-sample performance metrics (explained, for example, in https://kkotov.github.io/emtfPtRegression/2017.01.19/#4):
linearModelRMSE = linearModel.stages[1].summary.rootMeanSquaredError
print("RMSE: %f" % linearModelRMSE)
print("Fraction of variance explained (R-squared): %f" % linearModel.stages[1].summary.r2)
print("Significance (tValues): %f and %f" % (linearModel.stages[1].summary.tValues[0],linearModel.stages[1].summary.tValues[1]) )
# Out:
# RMSE: 0.107862
# Fraction of variance explained (R-squared): 0.456682
# Significance (tValues): 524.725995 and 461.724599

# %% [markdown]
# Btw., the metrics above wouldn't be accurate if the column-based reweighting is used in this linear model.
#
# Below I'll build the first ROC curve. I'll use it as a reference to compare with another model a bit later.

# %%
# consider equally-spaced binning
binning = np.arange(2,200,0.5)

linearROC = rocMetric(skim, binning)

fig, ax0 = prepareRocPlot({None:(linearROC,'#0cbfd0')}, {5:'red',4:'brown',3:'green'}, legPos='lower right')
ax0.set_xscale('linear')
ax0.set_ylim(0, 1.)
ax0.set_xlim(0, 1.)
plt.title("ROC curve for univariate linear regression", fontsize=20)
plt.show()

# %% [markdown]
# ## Multivariate linear regression
#
# Let's now consider all of the predictors and select the best model. Leave aside best subset selection as well as forward/backward step-/stage-wise regression. Just perform a scan over lasso regularization hyperparameter that automatically suppresses the least important predictors. Don't forget to standardize the predictors for the regularization to treat them on equal footing.

# %%
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorIndexer

# put together all categorical predictors
assemblerCategorical = VectorAssembler(inputCols=
                            ['clct1', 'clct2', 'clct3', 'clct4',
                             'fr1',   'fr2',   'fr3',   'fr4',
                             'rpc1',  'rpc2',  'rpc3',  'rpc4',
                             'st1_ring2'],
                            outputCol='categoricalFeatures')

# put together all continuous predictors
assemblerContinuous = VectorAssembler(inputCols=
                            ['theta',
                             'dPhi12',   'dPhi13',   'dPhi14',   'dPhi23',   'dPhi24',   'dPhi34',
                             'dTheta12', 'dTheta13', 'dTheta14', 'dTheta23', 'dTheta24', 'dTheta34',
                             'dPhiS4',   'dPhiS4A',  'dPhiS3',   'dPhiS3A'],
                            outputCol='continuousFeatures')

# index categorical predictors
catFeatureIndexer = VectorIndexer(inputCol='categoricalFeatures', outputCol='indexedCatFeatures', maxCategories=10)

# put all predictors togeteher in one feature vector
assembler = VectorAssembler(inputCols=['indexedCatFeatures','continuousFeatures'], outputCol='features')

# chain transformations in a pipeline
multiLinRegPipeline = Pipeline(stages=[assemblerCategorical, catFeatureIndexer, assemblerContinuous, assembler, linearReg])

# lasso regularization is a particular case of the elastic net with alpha=1
linearReg.setElasticNetParam(1)
linearReg.setStandardization(True)

# define a hyperparameter grid
regParSweep = [1., 1/2., 1/4., 1/16., 1/32., 1/64., 1/128., 1/256., 1/512., 1/1024., 1/2048., 1/4096., 1/8192., 1/16384., 1/32768., 1/65536.]

crossval = CrossValidator(estimator = multiLinRegPipeline,
                          estimatorParamMaps = ParamGridBuilder()
                                                 .addGrid(linearReg.regParam, regParSweep)
                                                 .build(),
                          evaluator = RegressionEvaluator(labelCol='ptTrueInv', metricName='rmse'),
                          numFolds = 10)

cvLinModel = crossval.fit(trainingData)

# Note, the whole block above fits more or less in two lines in R:
# https://kkotov.github.io/emtfPtRegression/2017.01.19/#8

# %%
# Let's have a look at the scan
print "Average RMSE metric as a function of regularization parameter:"

plt.close()
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
ax0.set_ylabel(r"RMSE", fontsize=18)
ax0.set_xlabel(r"Lasso regularization parameter", fontsize=18)
ax0.set_ylim(0.05, 0.2)
ax0.set_xlim(min(regParSweep), 1.)
ax0.set_xscale('log')
ax0.set_yscale('log')

plt.scatter(regParSweep, cvLinModel.avgMetrics, s=100, c='#d6ebf2', edgecolors='#8cbfd0')

# find the best point
indexRMSEmin = min(xrange(len(cvLinModel.avgMetrics)), key = cvLinModel.avgMetrics.__getitem__)

x_vals = [regParSweep[indexRMSEmin], regParSweep[indexRMSEmin]]
y_vals = [0, 10]
plt.plot(x_vals, y_vals, linewidth=3.0, c='#0cbfd0', linestyle='--')
plt.title("Regularization hyperparameter scan", fontsize=20)
plt.show()

print "\nNumbers from the plot above:"
for i,j in zip(xrange(len(regParSweep)), cvLinModel.avgMetrics):
    sys.stdout.write("%f %s %f" % (regParSweep[i], " => ", j))
    if i == indexRMSEmin :
        print " (best)"
    else :
        print ""

## optionally one can look at some technical details
# print cvLinModel.extractParamMap()
# print cvLinModel.getEstimator().getStages()[4].params
# print cvLinModel.bestModel.stages[4].coefficients
# Out:
# Average RMSE metric as a function of regularization parameter:
# Numbers from the plot above:
# 1.000000  =>  0.146372
# 0.500000  =>  0.146531
# 0.250000  =>  0.146552
# 0.062500  =>  0.122101
# 0.031250  =>  0.100629
# 0.015625  =>  0.091470
# 0.007812  =>  0.087548
# 0.003906  =>  0.080101
# 0.001953  =>  0.075669
# 0.000977  =>  0.074801
# 0.000488  =>  0.074081
# 0.000244  =>  0.074007 (best)
# 0.000122  =>  0.074092
# 0.000061  =>  0.074155
# 0.000031  =>  0.074029
# 0.000015  =>  0.074778

# %% [markdown]
# No surprise the best fit is achieved at low regularization: it is only when model start chasing the noise, the regularization kicks in. Simple linear model does not have much of flexibility to fit the noise with 30 coefficients in millions of events. Therefore model with small regularization is likely to be the optimal one.
#
# On the other hand, the last seven points are more or less on the same level and the best among them seems to be due to a slight fluctuation down. As I want to have more low-significance predictors to be zeroed out, I choose the right-most point on the lower plateau as the regularization parameter of choice.

# %%
indexRMSEmin = 9

# %% [markdown]
# As I now have chose the optimal model (the one with $\lambda$ = 1/1024.), it is time to check the model's coefficients, apply the model to the test data, and look at the performance.

# %%
# Train the multivariate linear regression with the best lasso regularization on the full training set
linearReg.setStandardization(True)
linearReg.setElasticNetParam(1)
linearReg.setRegParam( regParSweep[indexRMSEmin] )
# activating any regularization changes an under-the-hood solver from "normal" to something else that
#  unfortunately doesn't calculate significance levels of the model coefficients. Documentation at
#  https://spark.apache.org/docs/2.0.2/api/java/org/apache/spark/ml/regression/LinearRegressionSummary.html
#  confirms it

# fit the model
multiLinearModel = multiLinRegPipeline.fit(trainingData)
# apply it to the test data
multiLinearTest = multiLinearModel.transform(testData)

## multiLinearModel.stages[-1].summary.featuresCol == 'features'
## multiLinearModel.stages[-1].summary.residuals.show(10)

# a bulky way to link predictor's index in the feature vector with its name
cffNameIdx = multiLinearTest \
               .schema[str(multiLinearModel.stages[-1].summary.featuresCol)] \
               .metadata['ml_attr']['attrs'] \
               .values()

# flatten the array of binary, ordinal, and numeric predictors
cff = [ (predictor['name'],predictor['idx']) for category in cffNameIdx for predictor in category ]

# with no explicit significance I can only rely on lasso to zero-out the non-significant coefficients
print "Coefficients:"
for c in cff: print "%s = %.3e" % (c[0], multiLinearModel.stages[-1].coefficients[c[1]])
    
print "intercept = %.3f" %  multiLinearModel.stages[-1].intercept

multiLinearR2 = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='r2') \
                     .evaluate(multiLinearTest)
multiLinearRMSE = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='rmse') \
                     .evaluate(multiLinearTest)
print "\nOut-Of-Sample R-squared: %f" % multiLinearR2, " RMSE: %f" % multiLinearRMSE

## also doesn't work:
#cvLinModel.bestModel.stages[2].extractParamMap()
#cvLinModel.bestModel.stages[-1].summary.coefficientStandardErrors()
#cvLinModel.bestModel.stages[-1].summary.pValues
# Out:
# Coefficients:
# indexedCatFeatures_fr1 = -2.158e-02
# indexedCatFeatures_fr2 = 7.057e-04
# indexedCatFeatures_fr3 = -4.194e-04
# indexedCatFeatures_fr4 = 0.000e+00
# indexedCatFeatures_rpc1 = 5.311e-02
# indexedCatFeatures_rpc2 = 0.000e+00
# indexedCatFeatures_rpc3 = 8.521e-03
# indexedCatFeatures_rpc4 = -8.637e-03
# indexedCatFeatures_st1_ring2 = 2.240e-01
# indexedCatFeatures_clct1 = 1.900e-02
# indexedCatFeatures_clct2 = 5.339e-03
# indexedCatFeatures_clct3 = 0.000e+00
# indexedCatFeatures_clct4 = 4.968e-03
# continuousFeatures_theta = -3.210e-02
# continuousFeatures_dPhi12 = 1.764e-04
# continuousFeatures_dPhi13 = 1.270e-04
# continuousFeatures_dPhi14 = 3.660e-05
# continuousFeatures_dPhi23 = -8.273e-06
# continuousFeatures_dPhi24 = -2.601e-04
# continuousFeatures_dPhi34 = -7.814e-04
# continuousFeatures_dTheta12 = 1.555e-03
# continuousFeatures_dTheta13 = 0.000e+00
# continuousFeatures_dTheta14 = -1.345e-03
# continuousFeatures_dTheta23 = 3.226e-03
# continuousFeatures_dTheta24 = 3.653e-04
# continuousFeatures_dTheta34 = 0.000e+00
# continuousFeatures_dPhiS4 = 8.448e-06
# continuousFeatures_dPhiS4A = 9.052e-05
# continuousFeatures_dPhiS3 = 0.000e+00
# continuousFeatures_dPhiS3A = 1.358e-04
# intercept = 0.178
#
# Out-Of-Sample R-squared: 0.742146
#   RMSE: 0.074271

# %% [markdown]
# As can be seen above, even with such a small regularization parameter lasso drops and suppresses nearly third of the predictors. On the other hand linear regression might not have found a good use some of the parameters that potentially hide non-linear dependencies. The same, for example, could happen to the **dPhi** predictors would they be signed. In such case their correlation with the intrinsically unsigned pT variable would be zeroed out along with the corresponding regression coefficients.
#
# Nonetheless, as can be seen below, the multivariate regularized linear model performs way better than a univariate model. I'll use the former for comparison with non-linear methods in the following sections.

# %%
# collect and arange variables on the driver node
# (don't forget to invert prediction back to be consistent with the target and binning
skim2  = np.array( [ (row['ptTrue'], 1./row['prediction'], 1)
                     for row in multiLinearTest[['ptTrue','prediction']].collect()
                   ], dtype  = [('target', np.float),
                                ('prediction', np.float),
                                ('weight', np.float)]
         )
# ROC
multiLinROC = rocMetric(skim2, binning)

fig, ax0 = prepareRocPlot({"Univariate linear model":(linearROC,'blue'),
                           "Multivariate linear model":(multiLinROC,'#0cbfd0')},
                          {3:'red',5:'brown'}, legPos='lower right')
ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0, 1.)
ax0.set_xscale('linear')
plt.title("ROC curves comparison for linear models", fontsize=20)
plt.show()

# %% [markdown]
# No surprise the plot above demonstrates that model with more parameters does better. Nonetheless, it has to be understood that the model is optimized against RSS and not ROC that is a different metric. The **1/pT** target in RSS signifies the low-pT region at a potential expense of higher **pT** behavior. It means that a new model could very well achieve a better (smaller) RMSE/RSS, but do a mediocre job at where the ROCs raises.
#
# ## Departing from linearity
#
# The linear model above could be extended with interactions between predictors (i.e. with cross-products and higher orders). I could also move on to the generalized additive models that are still linear in the coefficients, but allow much greater flexibility as the basis is generally a set of unspecified smooth (nonparametric) functions like splines. Although, that would be an interesting exercise, I'll jump it over it and go straight to the methods that allow arbitrary order interactions and non-linearity with no effort, out of the box. I start with the tree-based methods such as Gradient Boosted Trees and Random Forests. I'll also keep **1/pT** as the target. Unlike the previous blocks, where this choice was in part motivated by proportionality between **1/pT** and **dPhi**'s, now I stress the domain-motivated importance of the low pT region.

# %%
# Let's start with the Gradient Boosted Trees
from pyspark.ml.regression import GBTRegressor

# train the model with 'squared' loss ('absolute' loss appears not to do well here)
gbt = GBTRegressor(featuresCol="features", maxIter=100, labelCol='ptTrueInv', lossType='squared')

# chain transformations in a pipeline
gbtPipeline = Pipeline(stages=[assemblerCategorical, catFeatureIndexer, assemblerContinuous, assembler, gbt])

# fit the model
gbtModel = gbtPipeline.fit(trainingData) #.limit(100000))

# apply the model to test set
gbtTest = gbtModel.transform(testData)

# %%
skim3  = np.array( [ (row['ptTrue'], 1./row['prediction'], 1)
                     for row in gbtTest[['ptTrue','prediction']].collect()
                   ], dtype  = [('target', np.float),
                                ('prediction', np.float),
                                ('weight', np.float)]
         )

gbtROC = rocMetric(skim3, binning)

fig, ax0 = prepareRocPlot({"Multivariate linear model":(multiLinROC,'blue'),
                           "GBT":(gbtROC,'#0cbfd0')},
                          {5:'red',14:'brown'}, legPos='lower right')
ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0, 0.3)
ax0.set_xscale('linear')
plt.show()

# %% [markdown]
# Not surprisingly, Gradient Boosted Tree is superior to the linear models. Below I fit the same model several times with different random seeds and check uncertainty of its predictions.

# %%
gbt.setSeed(11)
(trainSet1, testSet1) = dataframe3.randomSplit([0.7, 0.3], seed=110)
gbtModel1 = gbtPipeline.fit(trainSet1)
gbtTest1 = gbtModel1.transform(testSet1)

gbt.setSeed(110)
(trainSet2, testSet2) = dataframe3.randomSplit([0.7, 0.3], seed=1110)
gbtModel2 = gbtPipeline.fit(trainSet2)
gbtTest2 = gbtModel2.transform(testSet2)

gbt.setSeed(1111)
(trainSet3, testSet3) = dataframe3.randomSplit([0.7, 0.3], seed=11111)
gbtModel3 = gbtPipeline.fit(trainSet3)
gbtTest3 = gbtModel3.transform(testSet3)

# %%
skim3_1  = np.array( [ (1./row['ptTrueInv'], 1./row['prediction'], 1)
                       for row in gbtTest1[['ptTrueInv','prediction']].collect()
                     ], dtype  = [('target', np.float),
                                  ('prediction', np.float),
                                  ('weight', np.float)]
         )
gbtROC1 = rocMetric(skim3_1, binning)
skim3_2  = np.array( [ (1./row['ptTrueInv'], 1./row['prediction'], 1)
                       for row in gbtTest2[['ptTrueInv','prediction']].collect()
                     ], dtype  = [('target', np.float),
                                  ('prediction', np.float),
                                  ('weight', np.float)]
         )
gbtROC2 = rocMetric(skim3_2, binning)
skim3_3  = np.array( [ (1./row['ptTrueInv'], 1./row['prediction'], 1)
                       for row in gbtTest3[['ptTrueInv','prediction']].collect()
                     ], dtype  = [('target', np.float),
                                  ('prediction', np.float),
                                  ('weight', np.float)]
         )
gbtROC3 = rocMetric(skim3_3, binning)

fig, ax0 = prepareRocPlot({"GBT #1":(gbtROC1,'blue'),
                           "GBT #2":(gbtROC2,'#0cbfd0'),
                           "GBT #3":(gbtROC3,'cyan'),
                           },
                          {15:'red',10:'brown',5:'m'},
                          legPos = 'lower right')
ax0.set_ylim(0.5, 1.)
ax0.set_xlim(0.001, 0.3)
plt.show()

# %% [markdown]
# Looks like there is a bit of a noise at bottom-left corner, but the results are consistent.
#
# Let's now check the variable importance.

# %%
import re

# again, associate feature indexes with the original predictors' names
gbtCffNameIdx = gbtTest \
               .schema['features'] \
               .metadata['ml_attr']['attrs'] \
               .values()

# flatten the array of binary, ordinal, and numeric predictors
gbtCff = [ (re.sub(r".*_","",predictor['name']),predictor['idx']) for category in gbtCffNameIdx for predictor in category ]

## Variable importance
#print "Variable importance:"
#for c in gbtCff: print "%s = %.3e" % (c[0], gbtModel.stages[-1].featureImportances[c[1]])

fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')

ax0.barh(range(len(gbtCff)),
         [gbtModel.stages[-1].featureImportances[c[1]] for c in gbtCff],
         color = 'r',
         tick_label = [c[0] for c in gbtCff])

plt.title("GBT variable importance", fontsize=20)
plt.show()

metric = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='r2').evaluate(gbtTest)
print "\nOut-Of-Sample R-squared: %f" % metric
# Out:
# Out-Of-Sample R-squared: 0.899950

# %% [markdown]
# Interesting how much of importance the method assigned to **dPhi34**, though.
#
# Random Forest is an alternative model. Despite its conceptual tuning simplicity, it looks like the Spark's version is very sensitive to it ... to the extent that it runs out of memory and crashes (!) when grow trees deep (say maxDepth>7, or >2^7=128 leafs per tree, ... on my 16Gb node?). While having implemented RF myself (although not in a functional programming language), I find such behavior not acceptable for a tool that is popularized so aggressively. Anyways, have a look at the model below yourselves.

# %%
from pyspark.ml.regression import RandomForestRegressor

# let's train a simple Random Forest
randomForest = RandomForestRegressor(labelCol='ptTrueInv', featuresCol='features', numTrees=256, #128,
                                     impurity='variance', maxDepth=6) #, maxBins=96)

# chain transformations in a pipeline
rfPipeline = Pipeline(stages=[assemblerCategorical, catFeatureIndexer, assemblerContinuous, assembler, randomForest])

# Fit the model
rfModel = rfPipeline.fit(trainingData)

# Apply the model to test set
rfTest = rfModel.transform(testData)

# %%
skim4  = np.array( [ (row['ptTrue'], 1./row['prediction'], 1)
                     for row in rfTest[['ptTrue','prediction']].collect()
                   ], dtype  = [('target', np.float),
                                ('prediction', np.float),
                                ('weight', np.float)]
         )

rfROC = rocMetric(skim4, binning)

fig, ax0 = prepareRocPlot({"Multivariate linear model":(multiLinROC,'blue'),
                           "GBT":(gbtROC,'#0cbfd0'),
                           "Random Forest": (rfROC,'red')})
ax0.set_ylim(0.5, 1.)
ax0.set_xlim(0.001, 0.3)
plt.show()

# %% [markdown]
# A mediocre performance looks disturbing. Below I cross-check the performance with RF in Scikit-Learn and in [my C++ implementation](https://github.com/kkotov/ml).

# %%
# First, load the data with pandas; no more HDFS, only main RAM, only hardcore
import pandas as pd
df0 = pd.read_csv('/home/kkotov/oldSim.csv')

# categorical and continuous predictor columns
cat = ['clct1', 'clct2', 'clct3', 'clct4',
       'fr1',   'fr2',   'fr3',   'fr4',
       'rpc1',  'rpc2',  'rpc3',  'rpc4',
       'st1_ring2']
cont = ['theta',
        'dPhi12',   'dPhi13',   'dPhi14',   'dPhi23',   'dPhi24',   'dPhi34',
        'dTheta12', 'dTheta13', 'dTheta14', 'dTheta23', 'dTheta24', 'dTheta34',
        'dPhiS4',   'dPhiS4A',  'dPhiS3',   'dPhiS3A']
from copy import deepcopy
# combine the above in a single list of predictors
predictors = deepcopy(cat)
predictors.extend( cont )
# and complement it with the target
variables = deepcopy(predictors)
variables.extend( ['muPtGen'] )

# subset the first and second trajectories per entry
import re
df1_1 = df0[ df0['mode[0]'].isin([15]) ][[ re.sub(r'$','[0]',p) for p in variables ]]
df1_2 = df0[ df0['mode[1]'].isin([15]) ][[ re.sub(r'$','[1]',p) for p in variables ]]
# rename the columns
df1_1.columns = variables
df1_2.columns = variables
# and concatenate the two dataframes to have "one event - one trajoctory"
df1 = pd.concat([df1_1, df1_2])

# The sklearn will infer categorical vs. continuous features based on their type, so envorce the type
df1[cont] = df1[cont].astype(float)

# cook-up different targets
import math
df1['invLogPtTrue'] = df1['muPtGen'].apply(lambda x: 1/math.log(x))
df1['ptTrueInv'] = 1./df1['muPtGen']

# split to train and test sampes
nRows = df1[predictors].shape[0]
trainRows = int(0.7*nRows)
(trainSet, testSet) = (df1[1:trainRows], df1[trainRows:nRows])

# reweight to 1/pT^3 spectrum
trainSet = trainSet.sample(n=300000, replace=True, weights=trainSet['ptTrueInv']**2, random_state=123)
testSet  = testSet .sample(n=100000, replace=True, weights=testSet ['ptTrueInv']**2, random_state=123)

# %%
# Train the RF in sklearn
from sklearn.ensemble import RandomForestRegressor

sklRf = RandomForestRegressor(n_estimators=128, max_features=len(predictors)/2, n_jobs=6)

# fit the model
sklRf.fit(trainSet[predictors], trainSet[['ptTrueInv']].values.ravel())

sklPred = sklRf.predict(testSet[predictors])

# predict and invert the target to a normal scale
sklTest = [ 1./x for x in sklRf.predict(testSet[predictors]) ]

# %%
# load the C++ wrapper library for my RF implementation
import ctypes
rflib = ctypes.cdll.LoadLibrary('/home/kkotov/work/emtfPtRegression/2017.09.07/wrapper.so')
rflib.RandomForest_regress.restype = ctypes.c_double

# a python wrapper class
class RandomForest(object):
    def __init__(self):
        self.obj = rflib.RandomForest_new()

    def load(self,filename):
        rflib.RandomForest_load(self.obj, filename)

    def regress(self,e):
        res = rflib.RandomForest_regress(self.obj, e['theta'], e['st1_ring2'],
                                        e['dPhi12'], e['dPhi13'], e['dPhi14'], e['dPhi23'], e['dPhi24'], e['dPhi34'],
                                        e['dTheta14'],
                                        e['dPhiS4'], e['dPhiS4A'], e['dPhiS3'], e['dPhiS3A'],
                                        e['clct1'],
                                        e['fr1'],
                                        e['rpc1'], e['rpc2'], e['rpc3'], e['rpc4']
                                       )
        return res

# instantiate and load an already trained model with the limited set of features given in the wrapper above
rf = RandomForest()
rf.load("/home/kkotov/work/emtfPtRegression/2017.09.07/rf.model")

# the model is trained offline and needs to be tested on events, different from those used in training
# the dataset below is the same oldSim.csv, but sampled for 1/pT^2 weight,
#   and retaining training/test partitioning that was used for training the model loaded above
df2 = pd.read_csv("/home/kkotov/work/emtfPtRegression/2017.09.07/one.csv")
# select events for testing
df2 = df2[df2.trainIdx == 0]
# make predictions and remember that the model was trained for 1/pT target
myRfTest = [ (cnt,1./rf.regress(row)) for (cnt,row) in df2[predictors].iterrows() ]

# %%
# put everything on the same plot
skim5  = np.array( [ (df2.loc[cnt,'muPtGen'], p, 1)
                     for (cnt,p) in myRfTest
                   ], dtype  = [('target', np.float),
                                ('prediction', np.float),
                                ('weight', np.float)]
         )
myRfROC = rocMetric(skim5, binning)

skim6  = np.array( [ (df2.loc[cnt,'muPtGen'], df2.loc[cnt,'ptXML'], 1)
                     for (cnt,p) in myRfTest
                   ], dtype  = [('target', np.float),
                                ('prediction', np.float),
                                ('weight', np.float)]
         )
baseROC = rocMetric(skim6, binning)

skim7  = np.array( [ (df2.loc[cnt,'muPtGen'], df2.loc[cnt,'ranger'], 1)
                     for (cnt,p) in myRfTest
                   ], dtype  = [('target', np.float),
                                ('prediction', np.float),
                                ('weight', np.float)]
         )
rangerROC = rocMetric(skim7, binning)

skim8  = np.array( zip(testSet[['muPtGen']].values.ravel(), sklTest, [1]*(nRows-trainRows)),
                   dtype  = [('target', np.float),
                             ('prediction', np.float),
                             ('weight', np.float)]
         )
sklROC = rocMetric(skim8, binning)


fig, ax0 = prepareRocPlot({"Ranger":                (rangerROC,'grey'),
                           "My Random Forest":      (myRfROC,  '#06ebf2'),
                           "SKLearn Random Forest": (sklROC,   'blue'),
                           "EMTF baseline":         (baseROC,  'red'),
                           "Spark's Random Forest": (rfROC,    'brown'),
                           "Spark's GBT":           (gbtROC,    'black'),
                           }, legPos="lower right")

ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0001, 0.1)
#ax0.set_xscale('linear')

plt.show()

# %% [markdown]
# The EMTF baseline model (what is currently being used in production) demonstrates superior performance over the other models. The only problem is that it was trained on the very same sample. With no information on the original test/train splitting I may be observing the performance gain of running the model on the data it was trained on. Sadly, ranger and SKLearn, the second bests, win over my RF implementation everywhere (I need to double-check my implementation, but there also might be some trick). And RF from Spark ML looses to everything.

# %%
"""
from sklearn.svm import SVR

sklSVM = SVR(kernel="rbf")

# And how do I regularize it?
sklSVM.fit(df1[predictors][1:trainRows], 1./df1[target].values.ravel()[1:trainRows])

sklSVMtest = sklSVM.predict(df1[predictors][trainRows:nRows])
"""
# Out:
# '\nfrom sklearn.svm import SVR\n\nsklSVM = SVR(kernel="rbf")\n\n# And how do I regularize it?\nsklSVM.fit(df1[predictors][1:trainRows], 1./df1[target].values.ravel()[1:trainRows])\n\nsklSVMtest = sklSVM.predict(df1[predictors][trainRows:nRows])\n'

# %%
"""
sklSVMtest = sklSVM.predict(df1[predictors][trainRows:nRows])

skim9  = np.array( zip(df1[target].values.ravel()[trainRows:nRows],
                       1./sklSVMtest,
                       1./df1[target].values.ravel()[trainRows:nRows]**2),
                   dtype  = [('target', np.float),
                             ('prediction', np.float),
                             ('weight', np.float)]
         )
sklSvmROC = rocMetric(skim8, binning)


fig, ax0 = prepareRocPlot({"Ranger": (rangerROC,'grey'),
                           "SKLearn SVM":(sklSvmROC,'blue'),
                           })

plt.show()
"""
# Out:
# '\nsklSVMtest = sklSVM.predict(df1[predictors][trainRows:nRows])\n\nskim9  = np.array( zip(df1[target].values.ravel()[trainRows:nRows],\n                       1./sklSVMtest,\n                       1./df1[target].values.ravel()[trainRows:nRows]**2),\n                   dtype  = [(\'target\', np.float),\n                             (\'prediction\', np.float),\n                             (\'weight\', np.float)]\n         )\nsklSvmROC = rocMetric(skim8, binning)\n\n\nfig, ax0 = prepareRocPlot({"Ranger": (rangerROC,\'grey\'),\n                           "SKLearn SVM":(sklSvmROC,\'blue\'),\n                           })\n\nplt.show()\n'

# %% [markdown]
# Given that it took me ~10 hours to get the SVM above trained, I'm afraid iterative optimization of such model is out of the question until I find some shortcut to train it faster. In principle the memory-based models like SVM and kNN shold to the best, but this is yet to be checked in a free time later.
#
# For now, let's look at the neutal networks. There is a zoo of implementations, but I have a long-standing interest in Keras+TensorFolw and optionally cross-checking it with H2O.
#
# First of all, training a neural networks is an art. Only in simplest problems one can expect a reasonable performance out of the box. So I train the network in several steps, staring with small number of predictors and weights forcing the linearity.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

tfModel = Sequential()

tfModel.add(Dense(units=1, input_dim=1, activation='sigmoid', kernel_initializer='zero', bias_initializer='zero'))
tfModel.add(Dense(units=1, kernel_initializer='zero', bias_initializer='zero'))

tfModel.compile(loss='mse', optimizer='rmsprop')

y_train = trainSet['ptTrueInv'].values.ravel()
y_test  = testSet ['ptTrueInv'].values.ravel()
x_train = trainSet['dPhi12'].values
x_test  = testSet ['dPhi12'].values

# x_train and y_train are Numpy arrays --just like in the Scikit-Learn API.
tfModel.fit(x_train, y_train, epochs=5)

tfTest = [ 1./x[0] for x in tfModel.predict(x_test) ]

print "RMSE test  = ", math.sqrt( sum((y_test  - 1./np.array(tfTest))**2)/len(y_test) )
print "RMSE train = ", math.sqrt( sum((y_train - 1./np.array([ 1./x[0] for x in tfModel.predict(x_train)]))**2)/len(y_train) )
print "Recal, RMSE of the univariate linear model = ", linearModelRMSE
# Out:
# Epoch 1/5
#     32/300000 [..............................] - ETA: 497s - loss: 0.1841
#   3072/300000 [..............................] - ETA: 9s - loss: 0.1181
#   6368/300000 [..............................] - ETA: 7s - loss: 0.0767
#   9696/300000 [..............................] - ETA: 6s - loss: 0.0564
#  12992/300000 [>.............................] - ETA: 5s - loss: 0.0461
#  16288/300000 [>.............................] - ETA: 5s - loss: 0.0397
#  19584/300000 [>.............................] - ETA: 5s - loss: 0.0353
#  22912/300000 [=>............................] - ETA: 4s - loss: 0.0322
#  26176/300000 [=>............................] - ETA: 4s - loss: 0.0297
#  29472/300000 [=>............................] - ETA: 4s - loss: 0.0278
#  32736/300000 [==>...........................] - ETA: 4s - loss: 0.0262
#  36032/300000 [==>...........................] - ETA: 4s - loss: 0.0249
#  39360/300000 [==>...........................] - ETA: 4s - loss: 0.0238
#  42656/300000 [===>..........................] - ETA: 4s - loss: 0.0229
#  45952/300000 [===>..........................] - ETA: 4s - loss: 0.0221
#  49280/300000 [===>..........................] - ETA: 4s - loss: 0.0214
#  52544/300000 [====>.........................] - ETA: 4s - loss: 0.0208
#  55808/300000 [====>.........................] - ETA: 3s - loss: 0.0202
#  59040/300000 [====>.........................] - ETA: 3s - loss: 0.0197
#  62208/300000 [=====>........................] - ETA: 3s - loss: 0.0193
#  65504/300000 [=====>........................] - ETA: 3s - loss: 0.0189
#  68736/300000 [=====>........................] - ETA: 3s - loss: 0.0186
#  71904/300000 [======>.......................] - ETA: 3s - loss: 0.0183
#  75104/300000 [======>.......................] - ETA: 3s - loss: 0.0180
#  78336/300000 [======>.......................] - ETA: 3s - loss: 0.0177
#  81600/300000 [=======>......................] - ETA: 3s - loss: 0.0174
#  84800/300000 [=======>......................] - ETA: 3s - loss: 0.0172
#  88096/300000 [=======>......................] - ETA: 3s - loss: 0.0170
#  91424/300000 [========>.....................] - ETA: 3s - loss: 0.0168
#  94752/300000 [========>.....................] - ETA: 3s - loss: 0.0166
#  98016/300000 [========>.....................] - ETA: 3s - loss: 0.0164
# 101312/300000 [=========>....................] - ETA: 3s - loss: 0.0163
# 104608/300000 [=========>....................] - ETA: 3s - loss: 0.0161
# 107808/300000 [=========>....................] - ETA: 3s - loss: 0.0160
# 111072/300000 [==========>...................] - ETA: 2s - loss: 0.0159
# 114400/300000 [==========>...................] - ETA: 2s - loss: 0.0158
# 117568/300000 [==========>...................] - ETA: 2s - loss: 0.0157
# 120896/300000 [===========>..................] - ETA: 2s - loss: 0.0155
# 124224/300000 [===========>..................] - ETA: 2s - loss: 0.0154
# 127552/300000 [===========>..................] - ETA: 2s - loss: 0.0153
# 130816/300000 [============>.................] - ETA: 2s - loss: 0.0152
# 134112/300000 [============>.................] - ETA: 2s - loss: 0.0151
# 137440/300000 [============>.................] - ETA: 2s - loss: 0.0151
# 140576/300000 [=============>................] - ETA: 2s - loss: 0.0150
# 143872/300000 [=============>................] - ETA: 2s - loss: 0.0149
# 147168/300000 [=============>................] - ETA: 2s - loss: 0.0148
# 150400/300000 [==============>...............] - ETA: 2s - loss: 0.0148
# 153728/300000 [==============>...............] - ETA: 2s - loss: 0.0147
# 156992/300000 [==============>...............] - ETA: 2s - loss: 0.0147
# 160224/300000 [===============>..............] - ETA: 2s - loss: 0.0146
# 163520/300000 [===============>..............] - ETA: 2s - loss: 0.0145
# 166752/300000 [===============>..............] - ETA: 2s - loss: 0.0145
# 170048/300000 [================>.............] - ETA: 2s - loss: 0.0144
# 173376/300000 [================>.............] - ETA: 1s - loss: 0.0144
# 176704/300000 [================>.............] - ETA: 1s - loss: 0.0143
# 180032/300000 [=================>............] - ETA: 1s - loss: 0.0143
# 183328/300000 [=================>............] - ETA: 1s - loss: 0.0142
# 186688/300000 [=================>............] - ETA: 1s - loss: 0.0142
# 189984/300000 [=================>............] - ETA: 1s - loss: 0.0141
# 193280/300000 [==================>...........] - ETA: 1s - loss: 0.0141
# 196608/300000 [==================>...........] - ETA: 1s - loss: 0.0140
# 199904/300000 [==================>...........] - ETA: 1s - loss: 0.0140
# 203168/300000 [===================>..........] - ETA: 1s - loss: 0.0139
# 206464/300000 [===================>..........] - ETA: 1s - loss: 0.0139
# 209728/300000 [===================>..........] - ETA: 1s - loss: 0.0139
# 212992/300000 [====================>.........] - ETA: 1s - loss: 0.0139
# 216256/300000 [====================>.........] - ETA: 1s - loss: 0.0138
# 219584/300000 [====================>.........] - ETA: 1s - loss: 0.0138
# 222912/300000 [=====================>........] - ETA: 1s - loss: 0.0137
# 226240/300000 [=====================>........] - ETA: 1s - loss: 0.0137
# 229536/300000 [=====================>........] - ETA: 1s - loss: 0.0137
# 232800/300000 [======================>.......] - ETA: 1s - loss: 0.0137
# 236128/300000 [======================>.......] - ETA: 0s - loss: 0.0136
# 239264/300000 [======================>.......] - ETA: 0s - loss: 0.0136
# 242560/300000 [=======================>......] - ETA: 0s - loss: 0.0136
# 245856/300000 [=======================>......] - ETA: 0s - loss: 0.0136
# 249152/300000 [=======================>......] - ETA: 0s - loss: 0.0135
# 252416/300000 [========================>.....] - ETA: 0s - loss: 0.0135
# 255712/300000 [========================>.....] - ETA: 0s - loss: 0.0135
# 259040/300000 [========================>.....] - ETA: 0s - loss: 0.0135
# 262272/300000 [=========================>....] - ETA: 0s - loss: 0.0134
# 265600/300000 [=========================>....] - ETA: 0s - loss: 0.0134
# 268928/300000 [=========================>....] - ETA: 0s - loss: 0.0134
# 272128/300000 [==========================>...] - ETA: 0s - loss: 0.0134
# 275424/300000 [==========================>...] - ETA: 0s - loss: 0.0133
# 278688/300000 [==========================>...] - ETA: 0s - loss: 0.0133
# 282016/300000 [===========================>..] - ETA: 0s - loss: 0.0133
# 285312/300000 [===========================>..] - ETA: 0s - loss: 0.0133
# 288512/300000 [===========================>..] - ETA: 0s - loss: 0.0133
# 291808/300000 [============================>.] - ETA: 0s - loss: 0.0132
# 295104/300000 [============================>.] - ETA: 0s - loss: 0.0132
# 298368/300000 [============================>.] - ETA: 0s - loss: 0.0132
# 300000/300000 [==============================] - 4s - loss: 0.0132
# Epoch 2/5
#     32/300000 [..............................] - ETA: 95s - loss: 0.0073
#   3264/300000 [..............................] - ETA: 5s - loss: 0.0113
#   6560/300000 [..............................] - ETA: 4s - loss: 0.0116
#   9856/300000 [..............................] - ETA: 4s - loss: 0.0117
#  13088/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  16032/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  19328/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  22656/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  25952/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  29312/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  32640/300000 [==>...........................] - ETA: 4s - loss: 0.0115
#  35936/300000 [==>...........................] - ETA: 4s - loss: 0.0115
#  39168/300000 [==>...........................] - ETA: 4s - loss: 0.0115
#  42464/300000 [===>..........................] - ETA: 4s - loss: 0.0115
#  45760/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  49056/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  52288/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  55424/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  58560/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  61696/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  64928/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  68160/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  71328/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  74432/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  77632/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  80800/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  84032/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  87360/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  90656/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  93952/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  97216/300000 [========>.....................] - ETA: 3s - loss: 0.0115
# 100256/300000 [=========>....................] - ETA: 3s - loss: 0.0115
# 103584/300000 [=========>....................] - ETA: 3s - loss: 0.0115
# 106848/300000 [=========>....................] - ETA: 3s - loss: 0.0115
# 110112/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 113408/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 116736/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 120032/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 123296/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 126592/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 129920/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 133248/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 136544/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 139872/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 143104/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 146400/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 149696/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 152960/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 156288/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 159616/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 162912/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 166176/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 169440/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 172736/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 176000/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 179264/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 182528/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 185856/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 189152/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 192480/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 195744/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 199040/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 202304/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 205568/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 208864/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 212000/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 215232/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 218528/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 221728/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 225024/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 228288/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 231584/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 234848/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 238176/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 241472/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 244736/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 247936/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 251200/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 254496/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 257792/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 261120/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 264384/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 267488/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 270688/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 273984/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 277248/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 280480/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 283808/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 287136/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 290464/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 293728/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 297056/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# Epoch 3/5
#     32/300000 [..............................] - ETA: 88s - loss: 0.0087
#   3232/300000 [..............................] - ETA: 5s - loss: 0.0112
#   6432/300000 [..............................] - ETA: 5s - loss: 0.0116
#   9760/300000 [..............................] - ETA: 4s - loss: 0.0116
#  13056/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  16320/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  19648/300000 [>.............................] - ETA: 4s - loss: 0.0114
#  22944/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  26272/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  29600/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  32928/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  36256/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  39552/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  42848/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  46176/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  49376/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  52704/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  56032/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  59328/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  62592/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  65792/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  68960/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  72032/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  75168/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  78240/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  81376/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  84672/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  87936/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  91264/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  94528/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  97792/300000 [========>.....................] - ETA: 3s - loss: 0.0115
# 101056/300000 [=========>....................] - ETA: 3s - loss: 0.0116
# 104256/300000 [=========>....................] - ETA: 3s - loss: 0.0115
# 107488/300000 [=========>....................] - ETA: 2s - loss: 0.0116
# 110752/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 113920/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 117248/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 120512/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 123840/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 127104/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 130432/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 133632/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 136864/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 140128/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 143392/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 146720/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 149888/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 153184/300000 [==============>...............] - ETA: 2s - loss: 0.0115
# 156448/300000 [==============>...............] - ETA: 2s - loss: 0.0115
# 159776/300000 [==============>...............] - ETA: 2s - loss: 0.0115
# 163072/300000 [===============>..............] - ETA: 2s - loss: 0.0115
# 166368/300000 [===============>..............] - ETA: 2s - loss: 0.0115
# 169600/300000 [===============>..............] - ETA: 2s - loss: 0.0115
# 172896/300000 [================>.............] - ETA: 1s - loss: 0.0115
# 176128/300000 [================>.............] - ETA: 1s - loss: 0.0115
# 179456/300000 [================>.............] - ETA: 1s - loss: 0.0115
# 182752/300000 [=================>............] - ETA: 1s - loss: 0.0115
# 186080/300000 [=================>............] - ETA: 1s - loss: 0.0115
# 189376/300000 [=================>............] - ETA: 1s - loss: 0.0115
# 192704/300000 [==================>...........] - ETA: 1s - loss: 0.0115
# 196000/300000 [==================>...........] - ETA: 1s - loss: 0.0115
# 199328/300000 [==================>...........] - ETA: 1s - loss: 0.0115
# 202656/300000 [===================>..........] - ETA: 1s - loss: 0.0115
# 205984/300000 [===================>..........] - ETA: 1s - loss: 0.0115
# 209312/300000 [===================>..........] - ETA: 1s - loss: 0.0115
# 212640/300000 [====================>.........] - ETA: 1s - loss: 0.0115
# 215936/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 219232/300000 [====================>.........] - ETA: 1s - loss: 0.0115
# 222528/300000 [=====================>........] - ETA: 1s - loss: 0.0115
# 225856/300000 [=====================>........] - ETA: 1s - loss: 0.0115
# 229120/300000 [=====================>........] - ETA: 1s - loss: 0.0115
# 232256/300000 [======================>.......] - ETA: 1s - loss: 0.0115
# 235456/300000 [======================>.......] - ETA: 0s - loss: 0.0115
# 238560/300000 [======================>.......] - ETA: 0s - loss: 0.0115
# 241632/300000 [=======================>......] - ETA: 0s - loss: 0.0115
# 244768/300000 [=======================>......] - ETA: 0s - loss: 0.0115
# 247744/300000 [=======================>......] - ETA: 0s - loss: 0.0115
# 250880/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 254144/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 257440/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 260704/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 263968/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 267264/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 270400/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 273600/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 276896/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 280224/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 283520/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 286688/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 289856/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 292832/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 295776/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 298752/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# Epoch 4/5
#     32/300000 [..............................] - ETA: 88s - loss: 0.0169
#   3072/300000 [..............................] - ETA: 5s - loss: 0.0115
#   5984/300000 [..............................] - ETA: 5s - loss: 0.0114
#   8960/300000 [..............................] - ETA: 5s - loss: 0.0113
#  12096/300000 [>.............................] - ETA: 5s - loss: 0.0115
#  15264/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  18528/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  21696/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  24992/300000 [=>............................] - ETA: 4s - loss: 0.0117
#  28320/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  31552/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  34656/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  37856/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  41152/300000 [===>..........................] - ETA: 4s - loss: 0.0116
#  44384/300000 [===>..........................] - ETA: 4s - loss: 0.0116
#  47680/300000 [===>..........................] - ETA: 4s - loss: 0.0116
#  50880/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  54176/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  57472/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  60800/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  64096/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  67424/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  70688/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  73952/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  77216/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  80512/300000 [=======>......................] - ETA: 3s - loss: 0.0117
#  83744/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  87072/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  90368/300000 [========>.....................] - ETA: 3s - loss: 0.0116
#  93664/300000 [========>.....................] - ETA: 3s - loss: 0.0116
#  96896/300000 [========>.....................] - ETA: 3s - loss: 0.0116
# 100224/300000 [=========>....................] - ETA: 3s - loss: 0.0116
# 103552/300000 [=========>....................] - ETA: 3s - loss: 0.0116
# 106880/300000 [=========>....................] - ETA: 3s - loss: 0.0116
# 110144/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 113440/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 116768/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 120096/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 123328/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 126624/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 129856/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 133120/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 136448/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 139712/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 142784/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 146048/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 149312/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 152608/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 155904/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 159200/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 162528/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 165824/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 169120/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 172416/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 175712/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 178912/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 182144/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 185440/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 188704/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 192000/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 195296/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 198592/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 201760/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 205056/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 208384/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 211712/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 215040/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 218336/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 221632/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 224960/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 228256/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 231552/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 234848/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 238112/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 241312/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 244544/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 247872/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 251200/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 254464/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 257568/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 260896/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 264192/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 267456/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 270816/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 274112/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 277408/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 280704/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 283936/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 287104/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 290432/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 293696/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 297024/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# Epoch 5/5
#     32/300000 [..............................] - ETA: 87s - loss: 0.0108
#   3136/300000 [..............................] - ETA: 5s - loss: 0.0117
#   6304/300000 [..............................] - ETA: 5s - loss: 0.0117
#   9600/300000 [..............................] - ETA: 4s - loss: 0.0117
#  12896/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  16064/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  19360/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  22656/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  25920/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  29216/300000 [=>............................] - ETA: 4s - loss: 0.0117
#  32480/300000 [==>...........................] - ETA: 4s - loss: 0.0117
#  35808/300000 [==>...........................] - ETA: 4s - loss: 0.0117
#  39104/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  42368/300000 [===>..........................] - ETA: 4s - loss: 0.0116
#  45568/300000 [===>..........................] - ETA: 3s - loss: 0.0117
#  48896/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  52192/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  55488/300000 [====>.........................] - ETA: 3s - loss: 0.0117
#  58784/300000 [====>.........................] - ETA: 3s - loss: 0.0117
#  62112/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  65408/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  68704/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  72000/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  75296/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  78592/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  81856/300000 [=======>......................] - ETA: 3s - loss: 0.0117
#  85184/300000 [=======>......................] - ETA: 3s - loss: 0.0117
#  88480/300000 [=======>......................] - ETA: 3s - loss: 0.0117
#  91744/300000 [========>.....................] - ETA: 3s - loss: 0.0117
#  95040/300000 [========>.....................] - ETA: 3s - loss: 0.0117
#  98368/300000 [========>.....................] - ETA: 3s - loss: 0.0116
# 101632/300000 [=========>....................] - ETA: 3s - loss: 0.0117
# 104864/300000 [=========>....................] - ETA: 3s - loss: 0.0117
# 107904/300000 [=========>....................] - ETA: 2s - loss: 0.0117
# 111168/300000 [==========>...................] - ETA: 2s - loss: 0.0117
# 114496/300000 [==========>...................] - ETA: 2s - loss: 0.0117
# 117792/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 121088/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 124384/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 127584/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 130880/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 134176/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 137472/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 140768/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 144064/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 147392/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 150592/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 153920/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 157184/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 160480/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 163808/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 167136/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 170432/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 173760/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 176928/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 180192/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 183488/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 186816/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 190144/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 193312/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 196512/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 199776/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 203104/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 206464/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 209760/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 213024/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 216352/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 219680/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 222976/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 226304/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 229600/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 232832/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 236096/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 239424/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 242592/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 245792/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 249088/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 252416/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 255680/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 259008/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 262272/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 265568/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 268896/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 272192/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 275488/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 278816/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 282112/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 285408/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 288576/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 291872/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 295136/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 298432/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# RMSE test  =
#  0.100746051073
# RMSE train =
# 0.106852461256
# Recal, RMSE of the univariate linear model =  0.107862260652

# %%
print tfModel.summary() #, '\n'
#print tfModel.get_config(), '\n'
#print tfModel.get_weights(), '\n'
## good set of weights
#tfModel.set_weights(
#    [array([[ 0.01057134]], dtype=float32), array([-0.83383954], dtype=float32),
#     array([[ 0.51123452]], dtype=float32), array([-0.03770353], dtype=float32)] 
#)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.close()
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
ax0.set_ylabel(r"1/$p_T$", fontsize=18)
ax0.set_xlabel(r"$\Delta \phi_{12}$ values", fontsize=18)
ax0.set_ylim(0, 1.)
ax0.set_xlim(0, 500)

# our old friend - linear model
x_vals = np.array(ax0.get_xlim())
y_vals = linearModel.stages[1].intercept + linearModel.stages[1].coefficients * x_vals
linCurve = plt.plot(x_vals, y_vals, linewidth=3.0, c='#0cbfd0', linestyle='--')

# our new friend, neural network that should shadow our old friend
x_range  = np.arange(0,500,1)
y_result = tfModel.predict(x_range)
nnCurve = plt.scatter(x_range, y_result, s=14**2, c='#d6ebf2', edgecolors='#8cbfd0', alpha=1.)

plt.legend( [nnCurve],
            ["Single node NN"],
            scatterpoints = 1,
            ncol = 1,
            fontsize = 15
          )

plt.title("Comparing the linear model with \"linearized\" neural network", fontsize=20)
plt.show()

# %%
skim10 = np.array( zip(1./y_test, tfTest, [1]*len(tfTest)),
                   dtype  = [('target', np.float),
                             ('prediction', np.float),
                             ('weight', np.float)]
         )
tf1ROC = rocMetric(skim10, binning)

fig, ax0 = prepareRocPlot({"Linear model": (linearROC,'grey'),
                           "TensorFlow #1":(tf1ROC,'blue'),
                           },{3:'brown'},legPos="lower right")

ax0.set_ylim(0., 1.)
ax0.set_xlim(0., 0.3)
ax0.set_xscale('linear')

plt.show()

# %% [markdown]
# It looks like the simplest neural network is doing a right thing and a deviation from linearity that now can be accomodated in four coefficients (2 biases + 2 scales) of the NN results in just a bit of performance gain in ROC metric.
#
# Let's add more predictors apply standardization+regularization and compare against multivariate linear model. One thing to keep in mind is that NN will treat all of the inputs as continuous variables.

# %%
# Looks like Keras doesn't provide an independent workflow/option to standardize the predictors, so I resort to SKLearn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df1[predictors])
df1_stand = pd.DataFrame( scaler.transform(df1[predictors]) )
df1_stand.columns = predictors
df1_stand['ptTrueInv'] = df1['ptTrueInv'].values
(trainSet, testSet) = (df1_stand[1:trainRows], df1_stand[trainRows:nRows])
# reweight to 1/pT^3 spectrum
trainSet = trainSet.sample(n=300000, replace=True, weights=trainSet['ptTrueInv']**2, random_state=123)
testSet  = testSet .sample(n=100000, replace=True, weights=testSet ['ptTrueInv']**2, random_state=123)

# %%
from keras import regularizers

tfModel2 = Sequential()

tfModel2.add(Dense(1, input_dim=len(predictors), activation='sigmoid', kernel_initializer='zero', bias_initializer='zero'))
tfModel2.add(Dense(1, kernel_initializer='zero', bias_initializer='zero'))

x_train = trainSet[predictors].values
x_test  = testSet [predictors].values

tfModel2.compile(loss='mse', optimizer='rmsprop')

tfModel2.fit(x_train, y_train, epochs=5)

tfTest2 = [ 1./x[0] for x in tfModel2.predict(x_test) ]

print "RMSE test  = ", math.sqrt( sum((y_test  - 1./np.array(tfTest2))**2)/len(y_test) )
print "RMSE train = ", math.sqrt( sum((y_train - 1./np.array([ 1./x[0] for x in tfModel2.predict(x_train)]))**2)/len(y_train) )
print "Recal, RMSE of the multivariate linear model = ", multiLinearRMSE
# Out:
# Epoch 1/10
#     32/300000 [..............................] - ETA: 965s - loss: 0.1344
#   3136/300000 [..............................] - ETA: 14s - loss: 0.0673
#   6304/300000 [..............................] - ETA: 9s - loss: 0.0446
#   9472/300000 [..............................] - ETA: 7s - loss: 0.0347
#  12640/300000 [>.............................] - ETA: 6s - loss: 0.0294
#  15744/300000 [>.............................] - ETA: 6s - loss: 0.0261
#  18912/300000 [>.............................] - ETA: 5s - loss: 0.0236
#  22080/300000 [=>............................] - ETA: 5s - loss: 0.0217
#  25248/300000 [=>............................] - ETA: 5s - loss: 0.0202
#  28416/300000 [=>............................] - ETA: 5s - loss: 0.0190
#  31616/300000 [==>...........................] - ETA: 5s - loss: 0.0179
#  34784/300000 [==>...........................] - ETA: 4s - loss: 0.0170
#  37952/300000 [==>...........................] - ETA: 4s - loss: 0.0162
#  41120/300000 [===>..........................] - ETA: 4s - loss: 0.0155
#  44288/300000 [===>..........................] - ETA: 4s - loss: 0.0149
#  47488/300000 [===>..........................] - ETA: 4s - loss: 0.0143
#  50656/300000 [====>.........................] - ETA: 4s - loss: 0.0138
#  53824/300000 [====>.........................] - ETA: 4s - loss: 0.0134
#  56992/300000 [====>.........................] - ETA: 4s - loss: 0.0130
#  60160/300000 [=====>........................] - ETA: 4s - loss: 0.0127
#  63328/300000 [=====>........................] - ETA: 4s - loss: 0.0124
#  66528/300000 [=====>........................] - ETA: 4s - loss: 0.0121
#  69728/300000 [=====>........................] - ETA: 3s - loss: 0.0118
#  72928/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  76064/300000 [======>.......................] - ETA: 3s - loss: 0.0113
#  79264/300000 [======>.......................] - ETA: 3s - loss: 0.0111
#  82432/300000 [=======>......................] - ETA: 3s - loss: 0.0109
#  85600/300000 [=======>......................] - ETA: 3s - loss: 0.0107
#  88800/300000 [=======>......................] - ETA: 3s - loss: 0.0105
#  91968/300000 [========>.....................] - ETA: 3s - loss: 0.0104
#  95136/300000 [========>.....................] - ETA: 3s - loss: 0.0102
#  98272/300000 [========>.....................] - ETA: 3s - loss: 0.0101
# 101440/300000 [=========>....................] - ETA: 3s - loss: 0.0099
# 104608/300000 [=========>....................] - ETA: 3s - loss: 0.0098
# 107808/300000 [=========>....................] - ETA: 3s - loss: 0.0097
# 111008/300000 [==========>...................] - ETA: 3s - loss: 0.0096
# 114208/300000 [==========>...................] - ETA: 3s - loss: 0.0094
# 117408/300000 [==========>...................] - ETA: 3s - loss: 0.0093
# 120576/300000 [===========>..................] - ETA: 2s - loss: 0.0092
# 123744/300000 [===========>..................] - ETA: 2s - loss: 0.0091
# 126912/300000 [===========>..................] - ETA: 2s - loss: 0.0091
# 130080/300000 [============>.................] - ETA: 2s - loss: 0.0090
# 133280/300000 [============>.................] - ETA: 2s - loss: 0.0089
# 136448/300000 [============>.................] - ETA: 2s - loss: 0.0088
# 139616/300000 [============>.................] - ETA: 2s - loss: 0.0087
# 142816/300000 [=============>................] - ETA: 2s - loss: 0.0086
# 145984/300000 [=============>................] - ETA: 2s - loss: 0.0086
# 149120/300000 [=============>................] - ETA: 2s - loss: 0.0085
# 152288/300000 [==============>...............] - ETA: 2s - loss: 0.0084
# 155456/300000 [==============>...............] - ETA: 2s - loss: 0.0084
# 158656/300000 [==============>...............] - ETA: 2s - loss: 0.0083
# 161824/300000 [===============>..............] - ETA: 2s - loss: 0.0083
# 164960/300000 [===============>..............] - ETA: 2s - loss: 0.0082
# 168128/300000 [===============>..............] - ETA: 2s - loss: 0.0082
# 171296/300000 [================>.............] - ETA: 2s - loss: 0.0081
# 174464/300000 [================>.............] - ETA: 2s - loss: 0.0081
# 177664/300000 [================>.............] - ETA: 2s - loss: 0.0080
# 180832/300000 [=================>............] - ETA: 1s - loss: 0.0080
# 184000/300000 [=================>............] - ETA: 1s - loss: 0.0079
# 187200/300000 [=================>............] - ETA: 1s - loss: 0.0079
# 190368/300000 [==================>...........] - ETA: 1s - loss: 0.0078
# 193536/300000 [==================>...........] - ETA: 1s - loss: 0.0078
# 196704/300000 [==================>...........] - ETA: 1s - loss: 0.0078
# 199872/300000 [==================>...........] - ETA: 1s - loss: 0.0077
# 203072/300000 [===================>..........] - ETA: 1s - loss: 0.0077
# 206240/300000 [===================>..........] - ETA: 1s - loss: 0.0076
# 209408/300000 [===================>..........] - ETA: 1s - loss: 0.0076
# 212576/300000 [====================>.........] - ETA: 1s - loss: 0.0076
# 215712/300000 [====================>.........] - ETA: 1s - loss: 0.0076
# 218880/300000 [====================>.........] - ETA: 1s - loss: 0.0075
# 222048/300000 [=====================>........] - ETA: 1s - loss: 0.0075
# 225216/300000 [=====================>........] - ETA: 1s - loss: 0.0075
# 228384/300000 [=====================>........] - ETA: 1s - loss: 0.0074
# 231552/300000 [======================>.......] - ETA: 1s - loss: 0.0074
# 234720/300000 [======================>.......] - ETA: 1s - loss: 0.0074
# 237920/300000 [======================>.......] - ETA: 1s - loss: 0.0073
# 241088/300000 [=======================>......] - ETA: 0s - loss: 0.0073
# 244224/300000 [=======================>......] - ETA: 0s - loss: 0.0073
# 247360/300000 [=======================>......] - ETA: 0s - loss: 0.0073
# 250528/300000 [========================>.....] - ETA: 0s - loss: 0.0072
# 253696/300000 [========================>.....] - ETA: 0s - loss: 0.0072
# 256864/300000 [========================>.....] - ETA: 0s - loss: 0.0072
# 260032/300000 [=========================>....] - ETA: 0s - loss: 0.0072
# 263200/300000 [=========================>....] - ETA: 0s - loss: 0.0072
# 266368/300000 [=========================>....] - ETA: 0s - loss: 0.0071
# 269536/300000 [=========================>....] - ETA: 0s - loss: 0.0071
# 272736/300000 [==========================>...] - ETA: 0s - loss: 0.0071
# 275936/300000 [==========================>...] - ETA: 0s - loss: 0.0071
# 279104/300000 [==========================>...] - ETA: 0s - loss: 0.0070
# 282272/300000 [===========================>..] - ETA: 0s - loss: 0.0070
# 285440/300000 [===========================>..] - ETA: 0s - loss: 0.0070
# 288640/300000 [===========================>..] - ETA: 0s - loss: 0.0070
# 291808/300000 [============================>.] - ETA: 0s - loss: 0.0070
# 294976/300000 [============================>.] - ETA: 0s - loss: 0.0070
# 298144/300000 [============================>.] - ETA: 0s - loss: 0.0069
# 300000/300000 [==============================] - 4s - loss: 0.0069
# Epoch 2/10
#     32/300000 [..............................] - ETA: 96s - loss: 0.0043
#   3168/300000 [..............................] - ETA: 5s - loss: 0.0051
#   6336/300000 [..............................] - ETA: 5s - loss: 0.0052
#   9472/300000 [..............................] - ETA: 4s - loss: 0.0052
#  12640/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  15808/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  18976/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  22176/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  25344/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  28480/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  31648/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  34816/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  37984/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  41152/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  44288/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  47456/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  50624/300000 [====>.........................] - ETA: 4s - loss: 0.0054
#  53792/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  56928/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  60096/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  63264/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  66432/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  69600/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  72768/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  75936/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  79072/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  82272/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  85376/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  88544/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  91712/300000 [========>.....................] - ETA: 3s - loss: 0.0054
#  94880/300000 [========>.....................] - ETA: 3s - loss: 0.0054
#  98048/300000 [========>.....................] - ETA: 3s - loss: 0.0054
# 101248/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 104416/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 107552/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 110720/300000 [==========>...................] - ETA: 3s - loss: 0.0054
# 113920/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 117088/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 120224/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 123392/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 126592/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 129792/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 132992/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 135840/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 138976/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 142112/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 145280/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 148448/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 151616/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 154752/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 157888/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 161088/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 164256/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 167424/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 170592/300000 [================>.............] - ETA: 2s - loss: 0.0054
# 173760/300000 [================>.............] - ETA: 2s - loss: 0.0054
# 176928/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 180128/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 183296/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 186464/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 189632/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 192768/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 195936/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 199072/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 202240/300000 [===================>..........] - ETA: 1s - loss: 0.0054
# 205408/300000 [===================>..........] - ETA: 1s - loss: 0.0054
# 208576/300000 [===================>..........] - ETA: 1s - loss: 0.0054
# 211744/300000 [====================>.........] - ETA: 1s - loss: 0.0054
# 214912/300000 [====================>.........] - ETA: 1s - loss: 0.0054
# 218048/300000 [====================>.........] - ETA: 1s - loss: 0.0054
# 221216/300000 [=====================>........] - ETA: 1s - loss: 0.0054
# 224352/300000 [=====================>........] - ETA: 1s - loss: 0.0054
# 227552/300000 [=====================>........] - ETA: 1s - loss: 0.0054
# 230720/300000 [======================>.......] - ETA: 1s - loss: 0.0054
# 233888/300000 [======================>.......] - ETA: 1s - loss: 0.0054
# 237056/300000 [======================>.......] - ETA: 1s - loss: 0.0054
# 240224/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 243392/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 246528/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 249664/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 252864/300000 [========================>.....] - ETA: 0s - loss: 0.0054
# 256064/300000 [========================>.....] - ETA: 0s - loss: 0.0054
# 259232/300000 [========================>.....] - ETA: 0s - loss: 0.0054
# 262400/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 265568/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 268736/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 271904/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 275040/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 278176/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 281344/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 284480/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 287616/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 290752/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 293920/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 297088/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 300000/300000 [==============================] - 4s - loss: 0.0054
# Epoch 3/10
#     32/300000 [..............................] - ETA: 95s - loss: 0.0056
#   3200/300000 [..............................] - ETA: 5s - loss: 0.0051
#   6400/300000 [..............................] - ETA: 5s - loss: 0.0053
#   9568/300000 [..............................] - ETA: 4s - loss: 0.0052
#  12736/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  15936/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  19104/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  22272/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  25440/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  28608/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  31776/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  34912/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  38080/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  41248/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  44416/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  47616/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  50752/300000 [====>.........................] - ETA: 4s - loss: 0.0053
#  53920/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  57056/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  60224/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  63424/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  66624/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  69792/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  72960/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  76128/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  79328/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  82496/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  85664/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  88832/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  92000/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  95200/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  98368/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 101568/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 104736/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 107904/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 111072/300000 [==========>...................] - ETA: 3s - loss: 0.0053
# 114240/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 117408/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 120576/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 123744/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 126912/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 130080/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 133248/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 136448/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 139616/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 142848/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 146016/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 149184/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 152352/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 155520/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 158688/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 161856/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 165024/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 168224/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171360/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174528/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177696/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180864/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 184032/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 187232/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190368/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193472/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196576/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199744/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 202912/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206080/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209248/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212416/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 215584/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 218752/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 221952/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225120/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228320/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 231520/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 234720/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 237888/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 241056/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244224/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 247392/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 250560/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 253760/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 256960/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 260128/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 263296/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266464/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269664/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 272864/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 276032/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 279200/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 282368/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285568/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288736/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 291936/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 295104/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 298272/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# Epoch 4/10
#     32/300000 [..............................] - ETA: 92s - loss: 0.0051
#   3168/300000 [..............................] - ETA: 5s - loss: 0.0051
#   6304/300000 [..............................] - ETA: 5s - loss: 0.0054
#   9504/300000 [..............................] - ETA: 4s - loss: 0.0053
#  12672/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  15840/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  19040/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  22240/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  25408/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  28576/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  31744/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  34944/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  38144/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  41280/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  44448/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  47616/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  50784/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  53952/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  57120/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  60288/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  63456/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  66624/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  69792/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  72960/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  76128/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  79296/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  82464/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  85664/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  88832/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  92032/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  95232/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  98400/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 101568/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 104736/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 107904/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 111072/300000 [==========>...................] - ETA: 3s - loss: 0.0053
# 114240/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 117408/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 120576/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 123744/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 126912/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 130080/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 133248/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 136416/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 139584/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 142784/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 145952/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 149120/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 152288/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 155456/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 158624/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 161824/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 164992/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 168192/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171360/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174528/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177696/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180864/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 184000/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 187168/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190368/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193536/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196736/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199904/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 203104/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206304/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209504/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212672/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 215840/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 219040/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222240/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225408/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228608/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 231776/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 234976/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 238144/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 241344/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244512/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 247680/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 250848/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 254016/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257184/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 260352/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 263520/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266688/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269888/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 273088/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 276224/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 279392/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 282592/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285792/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288960/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 292128/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 295296/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 298464/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# Epoch 5/10
#     32/300000 [..............................] - ETA: 94s - loss: 0.0063
#   3200/300000 [..............................] - ETA: 5s - loss: 0.0056
#   6400/300000 [..............................] - ETA: 5s - loss: 0.0056
#   9568/300000 [..............................] - ETA: 4s - loss: 0.0054
#  12736/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  15904/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  19072/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  22240/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  25408/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  28576/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  31744/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  34912/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  38112/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  41280/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  44448/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  47616/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  50784/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  53952/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  57152/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  60288/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  63456/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  66624/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  69824/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  73024/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  76224/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  79392/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  82560/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  85728/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  88928/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  92096/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  95296/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  98464/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 101632/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 104800/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 107968/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 111136/300000 [==========>...................] - ETA: 3s - loss: 0.0053
# 114304/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 117440/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 120608/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 123776/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 126944/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 130048/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 133216/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 136384/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 139584/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 142784/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 145952/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 149088/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 152256/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 155424/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 158528/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 161696/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 164864/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 168032/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171200/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174400/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177568/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180704/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 183872/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 186976/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190144/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193312/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196480/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199648/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 202816/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 205920/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209088/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212288/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 215424/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 218592/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 221792/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 224992/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228192/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 231360/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 234496/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 237664/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 240832/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244032/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 247232/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 250400/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 253504/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 256512/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 259712/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 262880/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266048/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269248/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 272416/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 275584/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 278752/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 281920/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285056/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288224/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 291424/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 294592/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 297792/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# Epoch 6/10
#     32/300000 [..............................] - ETA: 93s - loss: 0.0032
#   3200/300000 [..............................] - ETA: 5s - loss: 0.0054
#   6400/300000 [..............................] - ETA: 5s - loss: 0.0052
#   9600/300000 [..............................] - ETA: 4s - loss: 0.0051
#  12768/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  15968/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  19136/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  22304/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  25472/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  28640/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  31808/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  34976/300000 [==>...........................] - ETA: 4s - loss: 0.0052
#  38144/300000 [==>...........................] - ETA: 4s - loss: 0.0052
#  41312/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  44480/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  47648/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  50816/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  53984/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  57152/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  60352/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  63520/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  66688/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  69856/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  73024/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  76192/300000 [======>.......................] - ETA: 3s - loss: 0.0052
#  79360/300000 [======>.......................] - ETA: 3s - loss: 0.0052
#  82560/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  85760/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  88864/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  92064/300000 [========>.....................] - ETA: 3s - loss: 0.0052
#  95200/300000 [========>.....................] - ETA: 3s - loss: 0.0052
#  98400/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 101568/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 104736/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 107904/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 111072/300000 [==========>...................] - ETA: 3s - loss: 0.0053
# 114240/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 117408/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 120544/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 123712/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 126880/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 130080/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 133248/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 136416/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 139584/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 142752/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 145888/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 149056/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 152224/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 155360/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 158560/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 161696/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 164896/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 168096/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171296/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174464/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177632/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180800/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 183968/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 187136/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190304/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193472/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196640/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199808/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 203008/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206176/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209344/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212544/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 215680/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 218848/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222048/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225216/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228384/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 231584/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 234752/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 237952/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 241088/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244288/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 247456/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 250656/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 253856/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257024/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 260192/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 263360/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266560/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269760/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 272960/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 276160/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 279136/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 282304/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285504/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288672/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 291840/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 295040/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 298208/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# Epoch 7/10
#     32/300000 [..............................] - ETA: 92s - loss: 0.0027
#   3200/300000 [..............................] - ETA: 5s - loss: 0.0054
#   6368/300000 [..............................] - ETA: 5s - loss: 0.0052
#   9568/300000 [..............................] - ETA: 4s - loss: 0.0052
#  12736/300000 [>.............................] - ETA: 4s - loss: 0.0051
#  15936/300000 [>.............................] - ETA: 4s - loss: 0.0051
#  19104/300000 [>.............................] - ETA: 4s - loss: 0.0051
#  22272/300000 [=>............................] - ETA: 4s - loss: 0.0051
#  25472/300000 [=>............................] - ETA: 4s - loss: 0.0051
#  28672/300000 [=>............................] - ETA: 4s - loss: 0.0051
#  31840/300000 [==>...........................] - ETA: 4s - loss: 0.0052
#  35008/300000 [==>...........................] - ETA: 4s - loss: 0.0052
#  38176/300000 [==>...........................] - ETA: 4s - loss: 0.0052
#  41344/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  44512/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  47648/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  50816/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  53984/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  57152/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  60320/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  63488/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  66656/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  69824/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  72992/300000 [======>.......................] - ETA: 3s - loss: 0.0052
#  76160/300000 [======>.......................] - ETA: 3s - loss: 0.0052
#  79360/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  82528/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  85696/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  88864/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  92032/300000 [========>.....................] - ETA: 3s - loss: 0.0052
#  95200/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  98368/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 101568/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 104736/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 107936/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 111104/300000 [==========>...................] - ETA: 3s - loss: 0.0052
# 114304/300000 [==========>...................] - ETA: 2s - loss: 0.0052
# 117472/300000 [==========>...................] - ETA: 2s - loss: 0.0052
# 120640/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 123808/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 126976/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 130176/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 133376/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 136576/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 139744/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 142944/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 146112/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 149280/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 152448/300000 [==============>...............] - ETA: 2s - loss: 0.0052
# 155616/300000 [==============>...............] - ETA: 2s - loss: 0.0052
# 158784/300000 [==============>...............] - ETA: 2s - loss: 0.0052
# 161952/300000 [===============>..............] - ETA: 2s - loss: 0.0052
# 165120/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 168288/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171488/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174656/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177824/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 181024/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 184192/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 187360/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190560/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193696/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196896/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 200064/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 203264/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206496/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209696/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212864/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 216096/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 219264/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222464/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225664/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228864/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 232032/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 235200/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 238368/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 241536/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244704/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 247872/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 251040/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 254208/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257376/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 260544/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 263712/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266880/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 270080/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 273248/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 276416/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 279584/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# ...
# 239968/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 240896/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 241632/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 242336/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 242912/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 243552/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 244160/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 244672/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 245184/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 245760/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 247648/300000 [=======================>......] - ETA: 1s - loss: 0.0053
# 250848/300000 [========================>.....] - ETA: 1s - loss: 0.0053
# 254016/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257184/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 260352/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 263520/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266688/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269888/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 273088/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 276256/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 279456/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 282624/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285792/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288960/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 292096/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 295296/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 298464/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 5s - loss: 0.0053
# Epoch 9/10
#     32/300000 [..............................] - ETA: 94s - loss: 0.0037
#   3200/300000 [..............................] - ETA: 5s - loss: 0.0056
#   6368/300000 [..............................] - ETA: 5s - loss: 0.0054
#   9568/300000 [..............................] - ETA: 4s - loss: 0.0054
#  12736/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  15904/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  19072/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  22240/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  25408/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  28576/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  31776/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  34976/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  38144/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  41312/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  44480/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  47616/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  50784/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  53952/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  57152/300000 [====>.........................] - ETA: 3s - loss: 0.0052
#  60352/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  63424/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  66592/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  69792/300000 [=====>........................] - ETA: 3s - loss: 0.0052
#  72960/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  76160/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  79328/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  82528/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  85728/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  88896/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  92064/300000 [========>.....................] - ETA: 3s - loss: 0.0052
#  95264/300000 [========>.....................] - ETA: 3s - loss: 0.0052
#  98464/300000 [========>.....................] - ETA: 3s - loss: 0.0052
# 101632/300000 [=========>....................] - ETA: 3s - loss: 0.0052
# 104800/300000 [=========>....................] - ETA: 3s - loss: 0.0052
# 108000/300000 [=========>....................] - ETA: 3s - loss: 0.0052
# 111168/300000 [==========>...................] - ETA: 3s - loss: 0.0052
# 114368/300000 [==========>...................] - ETA: 2s - loss: 0.0052
# 117536/300000 [==========>...................] - ETA: 2s - loss: 0.0052
# 120736/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 123904/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 127008/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 130176/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 133344/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 136512/300000 [============>.................] - ETA: 2s - loss: 0.0052
# 139680/300000 [============>.................] - ETA: 2s - loss: 0.0052
# 142848/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 146016/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 149184/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 152352/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 155520/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 158688/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 161856/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 165056/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 168224/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171392/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174560/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177728/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180896/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 184064/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 187232/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190400/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193568/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196768/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199936/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 203104/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206272/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209440/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212608/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 215776/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 218944/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222112/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225248/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228416/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 231392/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 234592/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 237760/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 240928/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244096/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 247264/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 250432/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 253600/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 256800/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 259968/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 263136/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266304/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269472/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 272640/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 275808/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 278976/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 282144/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285344/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288512/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 291712/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 294912/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 298080/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# Epoch 10/10
#     32/300000 [..............................] - ETA: 95s - loss: 0.0039
#   3168/300000 [..............................] - ETA: 5s - loss: 0.0056
#   6336/300000 [..............................] - ETA: 5s - loss: 0.0055
#   9504/300000 [..............................] - ETA: 4s - loss: 0.0054
#  12672/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  15840/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  19008/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  22176/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  25376/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  28544/300000 [=>............................] - ETA: 4s - loss: 0.0053
#  31712/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  34880/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  38048/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  41216/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  44416/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  47584/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  50784/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  53952/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  57152/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  60320/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  63488/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  66656/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  69824/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  72992/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  76160/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  79328/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  82496/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  85664/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  88832/300000 [=======>......................] - ETA: 3s - loss: 0.0052
#  92032/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  95232/300000 [========>.....................] - ETA: 3s - loss: 0.0052
#  98432/300000 [========>.....................] - ETA: 3s - loss: 0.0052
# 101600/300000 [=========>....................] - ETA: 3s - loss: 0.0052
# 104768/300000 [=========>....................] - ETA: 3s - loss: 0.0052
# 107936/300000 [=========>....................] - ETA: 3s - loss: 0.0052
# 111136/300000 [==========>...................] - ETA: 3s - loss: 0.0053
# 114304/300000 [==========>...................] - ETA: 2s - loss: 0.0052
# 117472/300000 [==========>...................] - ETA: 2s - loss: 0.0052
# 120640/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 123840/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 127008/300000 [===========>..................] - ETA: 2s - loss: 0.0052
# 130144/300000 [============>.................] - ETA: 2s - loss: 0.0052
# 133312/300000 [============>.................] - ETA: 2s - loss: 0.0052
# 136480/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 139648/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 142816/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 145984/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 149152/300000 [=============>................] - ETA: 2s - loss: 0.0052
# 152320/300000 [==============>...............] - ETA: 2s - loss: 0.0052
# 155488/300000 [==============>...............] - ETA: 2s - loss: 0.0052
# 158688/300000 [==============>...............] - ETA: 2s - loss: 0.0052
# 161856/300000 [===============>..............] - ETA: 2s - loss: 0.0052
# 165024/300000 [===============>..............] - ETA: 2s - loss: 0.0052
# 168224/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 171392/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 174560/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177728/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180928/300000 [=================>............] - ETA: 1s - loss: 0.0052
# 184096/300000 [=================>............] - ETA: 1s - loss: 0.0052
# 187264/300000 [=================>............] - ETA: 1s - loss: 0.0052
# 190432/300000 [==================>...........] - ETA: 1s - loss: 0.0052
# 193600/300000 [==================>...........] - ETA: 1s - loss: 0.0052
# 196800/300000 [==================>...........] - ETA: 1s - loss: 0.0052
# 199968/300000 [==================>...........] - ETA: 1s - loss: 0.0052
# 203136/300000 [===================>..........] - ETA: 1s - loss: 0.0052
# 206304/300000 [===================>..........] - ETA: 1s - loss: 0.0052
# 209472/300000 [===================>..........] - ETA: 1s - loss: 0.0052
# 212640/300000 [====================>.........] - ETA: 1s - loss: 0.0052
# 215776/300000 [====================>.........] - ETA: 1s - loss: 0.0052
# 218976/300000 [====================>.........] - ETA: 1s - loss: 0.0052
# 222144/300000 [=====================>........] - ETA: 1s - loss: 0.0052
# 225312/300000 [=====================>........] - ETA: 1s - loss: 0.0052
# 228480/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 231648/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 234816/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 237984/300000 [======================>.......] - ETA: 0s - loss: 0.0052
# 241184/300000 [=======================>......] - ETA: 0s - loss: 0.0052
# 244352/300000 [=======================>......] - ETA: 0s - loss: 0.0052
# 247520/300000 [=======================>......] - ETA: 0s - loss: 0.0052
# 250720/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 253920/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257088/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 260256/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 263456/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 266624/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 269792/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 272960/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 276128/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 279328/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 282496/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 285664/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 288864/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 292032/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 295232/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 298400/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# RMSE test  =
#  0.0673620411575
# RMSE train =
# 0.0725378318034
# Recal, RMSE of the multivariate linear model =  0.0742713539022

# %%
#print tfModel2.summary(), '\n'
#print tfModel2.get_weights(), '\n'

#tfModel2.set_weights(
#[np.array([[ 0.01458856],[ 0.06636513],[ 0.05803583],[ 0.00870287],[ 0.00434294],[-0.02969492],[-0.04272453],
#           [ 0.03005668],[-0.00023399],[-0.02966939],[ 0.03424917],[-0.01941773],[ 0.01155921],[ 0.03046101],
#           [ 0.08938213],[ 0.00336247],[ 0.08769946]], dtype=np.float32),
# np.array([ 0.22583365], dtype=np.float32), np.array([[ 0.2605353]], dtype=np.float32), np.array([ 0.00587982], dtype=np.float32)]
#)

#tfTest2 = [ 1./x[0] for x in tfModel2.predict(x_test) ]

plt.hist( tfTest2, bins=100 )
plt.yscale('log')
plt.show()

# %%
skim11 = np.array( zip(1/y_test, tfTest2, [1]*len(tfTest2) ),
                   dtype  = [('target', np.float),
                             ('prediction', np.float),
                             ('weight', np.float)]
         )
tf2ROC = rocMetric(skim11, binning)


fig, ax0 = prepareRocPlot({"Multivariate Linear Model": (multiLinROC,'grey'),
                           "TensorFlow #2":(tf2ROC,'blue'),
                           "TensorFlow #1":(tf1ROC,'brown'),
                           },legPos = "lower right")

ax0.set_ylim(0., 1.)
ax0.set_xlim(0., 1.)
ax0.set_xscale('linear')

plt.show()

# %%
#from keras.layers import Dropout
#from keras.optimizers import SGD

tfModel3 = Sequential()

tfModel3.add(Dense(5, input_dim=len(cont), activation='relu', kernel_initializer='uniform', bias_initializer='uniform'))
tfModel3.add(Dense(5, activation='relu', kernel_initializer='uniform', bias_initializer='uniform'))
tfModel3.add(Dense(1, kernel_initializer='uniform', bias_initializer='uniform'))

tfModel3.compile(loss='mean_squared_error',
              optimizer='sgd',
              metrics=['accuracy'])

# Whenever the weight-decay regularization is used, standartize continuous inputs for the NN
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df1[cont])
df1_stand = pd.DataFrame( scaler.transform(df1[cont]) )

## no need in deepcopy below, numpy does it for me
#x_train = df1_stand.values[1:trainRows]
#x_test  = df1_stand.values[trainRows:nRows]

# x_train and y_train are Numpy arrays --just like in the Scikit-Learn API.
tfModel3.fit(x_train, y_train, epochs=20)

#tfTest = [ math.exp(1./x) for x in tfModel.predict(x_test, batch_size=64) ]
tfTest3 = [ 1./x[0] for x in tfModel3.predict(x_test) ]

# %%
plt.hist( tfTest3, bins=100 )
plt.yscale('log')
plt.show()

skim12 = np.array( zip(df1["muPtGen"].values.ravel()[trainRows:nRows],
                       tfTest3,
                       1./df1["muPtGen"].values.ravel()[trainRows:nRows]**2),
                   dtype  = [('target', np.float),
                             ('prediction', np.float),
                             ('weight', np.float)]
         )
tf3ROC = rocMetric(skim12, binning)


fig, ax0 = prepareRocPlot({"Multivariate Linear model": (multiLinROC,'grey'),
                           "TensorFlow #2":(tf3ROC,'blue'),
                           })

plt.show()

# %%
import h2o
h2o.init()

fr = h2o.import_file(path="/home/kkotov/work/emtfPtRegression/2017.09.07/one.csv")
fr[cat] = fr[cat].asfactor()
fr["invLogPtTrue"] = 1./fr["muPtGen"].log()

print fr.columns

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

h2oDlModel = H2ODeepLearningEstimator(
                 nfolds = 10,
                 keep_cross_validation_predictions = True,
                 keep_cross_validation_fold_assignment = True,
                 #validation_frame = valid,
                 input_dropout_ratio = 0.2,
                 hidden = [10],
                 epochs = 500)

predictors = [1]
predictors.extend( range(2,31) )
train_data = fr[ fr["trainIdx"] == 1 ]
test_data  = fr[ fr["trainIdx"] == 0 ]

h2oDlModel.train(x = predictors,
                 y = 35,
                 training_frame = train_data)

# %%
#print 1./test_data[target].head(), 1./h2oDlModel.predict(test_data).head()

dlH2Otest = (1./h2oDlModel.predict(test_data)['predict']).exp().as_data_frame()["exp(predict)"].values.ravel()

plt.hist( [ i for i in dlH2Otest if i<1000], bins=100 )
plt.yscale('log')
plt.show()

skim11 = np.array( zip(test_data.as_data_frame()["muPtGen"].values.ravel(),
                       [ i for i in dlH2Otest if i<1000 ],
                       1./test_data.as_data_frame()["muPtGen"].values.ravel()**2),
                   dtype  = [('target', np.float),
                             ('prediction', np.float),
                             ('weight', np.float)]
         )
dlH2OROC = rocMetric(skim11, binning)

fig, ax0 = prepareRocPlot({"Ranger": (rangerROC,'grey'),
                           "H2O":(dlH2OROC,'blue'),
                           })

plt.show()

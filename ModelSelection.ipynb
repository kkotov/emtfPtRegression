# %% [markdown]
# ## Formulating the problem
#
# A charged particle propagates through the four layers of steel plates returning
# magnetic flux of the solenoid and the four interleaving "sensitive" layers of the
# detector. The sensitive layers report coordinates and bend angles of the individual
# track segments (highlighted with red arrows in the sketch below):
#
# <img src="https://kkotov.github.io/hep/bend4.png" width=600px />
#
# Collected information is used for the track building and particle's momentum assessment.
# Multiple scattering effects and non-uniform magnetic field render analytical momentum
# assignment impractical. A better solution is building a statistical model regressing
# coordinates of the track segments to the particle's momentum. The model can be trained
# using either Monte Carlo simulation (as in the current study) or real data where the
# target momentum is evaluated with help of another detector subsystem.
#
# This notebook outlines model building and selection using Apache Spark with python (PySpark),
# Scikit-learn, Keras (with TensorFlow back-end), and H2O. Since so many people "speak" nothing else
# but python when it comes to data analysis, I repeat my originally study performed in R
# $[$[1](https://kkotov.github.io/emtfPtRegression/2017.01.19/handout.html),
# [2](https://kkotov.github.io/emtfPtRegression/2017.02.10/handout.html),
# [3](https://kkotov.github.io/emtfPtRegression/2017.03.03/handout.html),
# [4](https://kkotov.github.io/emtfPtRegression/2017.03.17/handout.html)$]$
# (with some corrections, though) using these popular python front-ends.

# %% [markdown]
# ## Preparing data (in place of codebook)
#
# The main quantities that are directly related to the curvature of track and, therefore, to its momentum (later referred to as **pT**)
# are summarized in the following table:
#
# type             | measurement in layer #
# -----------------|---------------------------
#  $\theta$        |           2
#  $\Delta\phi$    | 1-2, 1-3, 1-4, 2-3, 2-4, 3-4
#  $\Delta\theta$  | 1-2, 1-3, 1-4, 2-3, 2-4, 3-4
#  bend            |       1, 2, 3, 4
#
# These predictors were also complemented with several surrogate combinations and compressed using the 'Andrew's scheme" from the [calculate_pt_xml](https://github.com/cms-sw/cmssw/blob/master/L1Trigger/L1TMuonEndCap/src/PtAssignmentEngine2017.cc)
# function. The scheme was ported as is to the [logging module](https://github.com/kkotov/framework/blob/master/workdir/Analyser.cc)
# and ran on CMS EDM files as part of my [analysis pipeline system](http://koskot77.github.io/framework). The result was saved in a simple csv file included below. The original CMS EDM files were located on CERN eos system under */store/user/abrinke1/EMTF/MC/SingleMu_Pt1To1000_FlatRandomOneOverPt/*.

# %%
# Load csv file containing ~300K simulated entries (rows) of predictors and the response from local HDFS
dataframe0 = (sqlContext
                         .read.format("com.databricks.spark.csv")
                         .options(delimiter=',',header='true',inferschema='true')
                         .load("hdfs://localhost:9000/data/oldSim.csv"))

# %%
# Each entry (row) contains two particles (as these are di-muon events)
# Let's transform this into a new "one row - one trajectory" table
# Also note the st1_ring2, dPhiS*, and rpc* surrogate predictors that
# were "cooked up" from the original measurements with Andrew's tools

sqlContext.sql("DROP TABLE IF EXISTS raw_data")
sqlContext.registerDataFrameAsTable(dataframe0,"raw_data")

dataframe1 = sqlContext.sql("""SELECT
                            `ptXML[0]` AS pt,
                            `muPtGen[0]` AS ptTrue,
                            1./`muPtGen[0]` AS ptTrueInv,                            
                            `theta[0]` AS theta,
                            `st1_ring2[0]` AS st1_ring2,
                            `dPhi12[0]` AS dPhi12,
                            `dPhi13[0]` AS dPhi13,
                            `dPhi14[0]` AS dPhi14,
                            `dPhi23[0]` AS dPhi23,
                            `dPhi24[0]` AS dPhi24,
                            `dPhi34[0]` AS dPhi34,
                            `dTheta12[0]` AS dTheta12,
                            `dTheta13[0]` AS dTheta13,
                            `dTheta14[0]` AS dTheta14,
                            `dTheta23[0]` AS dTheta23,
                            `dTheta24[0]` AS dTheta24,
                            `dTheta34[0]` AS dTheta34,
                            `dPhiS4[0]`   AS dPhiS4,
                            `dPhiS4A[0]`  AS dPhiS4A,
                            `dPhiS3[0]`   AS dPhiS3,
                            `dPhiS3A[0]`  AS dPhiS3A,
                            `clct1[0]`    AS clct1,
                            `clct2[0]`    AS clct2,
                            `clct3[0]`    AS clct3,
                            `clct4[0]`    AS clct4,
                            `fr1[0]`      AS fr1,
                            `fr2[0]`      AS fr2,
                            `fr3[0]`      AS fr3,
                            `fr4[0]`      AS fr4,
                            `rpc1[0]`     AS rpc1,
                            `rpc2[0]`     AS rpc2,
                            `rpc3[0]`     AS rpc3,
                            `rpc4[0]`     AS rpc4,
                            `mode[0]`     AS mode
                        FROM raw_data
                        UNION
                        SELECT 
                            `ptXML[1]` AS pt,
                            `muPtGen[1]` AS ptTrue,
                            1./`muPtGen[1]` AS ptTrueInv,                            
                            `theta[1]` AS theta,
                            `st1_ring2[1]` AS st1_ring2,
                            `dPhi12[1]` AS dPhi12,
                            `dPhi13[1]` AS dPhi13,
                            `dPhi14[1]` AS dPhi14,
                            `dPhi23[1]` AS dPhi23,
                            `dPhi24[1]` AS dPhi24,
                            `dPhi34[1]` AS dPhi34,
                            `dTheta12[1]` AS dTheta12,
                            `dTheta13[1]` AS dTheta13,
                            `dTheta14[1]` AS dTheta14,
                            `dTheta23[1]` AS dTheta23,
                            `dTheta24[1]` AS dTheta24,
                            `dTheta34[1]` AS dTheta34,
                            `dPhiS4[1]`   AS dPhiS4,
                            `dPhiS4A[1]`  AS dPhiS4A,
                            `dPhiS3[1]`   AS dPhiS3,
                            `dPhiS3A[1]`  AS dPhiS3A,
                            `clct1[1]`    AS clct1,
                            `clct2[1]`    AS clct2,
                            `clct3[1]`    AS clct3,
                            `clct4[1]`    AS clct4,
                            `fr1[1]`      AS fr1,
                            `fr2[1]`      AS fr2,
                            `fr3[1]`      AS fr3,
                            `fr4[1]`      AS fr4,
                            `rpc1[1]`     AS rpc1,
                            `rpc2[1]`     AS rpc2,
                            `rpc3[1]`     AS rpc3,
                            `rpc4[1]`     AS rpc4,
                            `mode[1]`     AS mode
                        FROM raw_data
                        """)
#print dataframe1.printSchema()

# %%
# Let's see how target variable looks like
# %matplotlib inline
# uncomment the line below to generate all plots in an svg vector format
#%config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt
import numpy as np

plt.hist( [ row['ptTrue'] for row in dataframe1[['ptTrue']].take(10000) ], bins=100 )
plt.yscale('log')
plt.show()

# %% [markdown]
# # Performance metric
#
# The domain-standard trigger turn-on curve, constructed with a certain threshold_pT
# in mind, presents the probability that response_pT > threshold_pT as a function
# of true_pT (aka. *target*). An example of turn-ons for one of the models look as follows:
#
# <img src="https://kkotov.github.io/emtfPtRegression/2017.02.10/assets/fig/unnamed-chunk-5-1.png" width=600px/>
#
# The main limitation of the turn-on metric is that the model curves
# have to be visually compared for a series of thresholds, which a rather
# labor-intensive exercise. Moreover, such metric also does not offer a good quantitative
# way to account for the spectrum: due to abundance of low true_pT events a sharp
# turn-on with a long left tail may do better as well as do worse compared to broad
# turn-on with a smaller tail. The Receiver Operating Characteristic (ROC) curve
# is free from such limitations, incorporate the spectrum shape (prevalence of
# events with low true_pT), and can be quantified
# with a simple area-under-the-curve (AUC) parameter.
#
# Before introducing the ROC metric let me start with the spectrum shape and call it
# rate. For some given threshold_pT the convolution of turn-on (again, probability
# of accepting the event) with the rate in
# the range of [0 < true_pT < threshold_pT] gives a number of false-positive events
# and in the range of [threshold_pT < true_pT < inf] gives true-positives. These
# numbers, normalized by the integrals of the rate in the two regions, give the
# true-/false-positive probabilities. Here is a graphical representation of how
# true-/false-positive are defined with respect to some threshold:
#
# <img src="https://kkotov.github.io/emtfPtRegression/2017.02.10/convolve.svg" width=500px/>
#
# In this scenario the "natural parameter"
# identifying a point on the ROC curve is the threshold_pT. In the code below
# I generate the ROC curve running over the grid of threshold_pT defined by the
# **binning** array.

# %%
import numpy as np

def findBin(val, binning, begin=0, end=-1): 
    """Find bin index of `val` in the `binning`
    Args:
        val (float): value of initerest
        binning (np.ndarray): sorted array of N bin boundaries for N-1 bins
        begin (int), end (int): helper values of the binary search, never to be used explicitly
    Returns:
        bin number (int) from [-1:N-1] range where N-1 means overflow, -1 is underflow, and None for errors
    """
    # first (user made) call
    if end < begin:
        end = len(binning)
        # Sanity check
    if len(binning) < 1 or end <= begin:
        return None
    # underflow goes to the before-the-first bin
    if val <  binning[begin]:
        return int(begin-1)
    # overlow goes to the next-to-the-last bin
    if val >= binning[end-1]:
        return int(end-1)
    # partition at the middle boundary
    center = int((end-begin-1)/2) + begin
    # got lucky?
    if val >= binning[center] and val < binning[center+1]:
        return center
    # binary search:
    if val < binning[center]:
        return findBin(val, binning, begin, center)
    else:
        return findBin(val, binning, center+1, end)

    
import pandas as pd

def rocMetric(events, binning, absoluteRate=False):
    """
    Args:
        events (np.ndarray):   input matrix consisting of three columns
                               'targets' - target values
                               'predictions' - predicted values
                               'weights' - bayes correction: over-/under-sample training
                                           instances according to the given weights
                                           (e.g. real `target` spectrum should follow x^-3,
                                            while provided values are destributed as x^-1,
                                            hence each should have a weight proportional to x^-2)
                                            'weights' is a pure man's approach better to be avoided
        binning  (np.ndarray): sorted array of N bin boundaries for N-1 bins
        absoluteRate:          an optional handle to get absolute (non-normalizad) false positives 
    Returns:
        dictionary {thresholdBin: (false_positive_rate, true_positive_rate)}
    """
    binnedByTargets = np.array( [ (e['target'],
                                   e['weight'],
                                   e['prediction'],
                                   findBin(e['target'],binning)
                                   ) for e in events ],
                                dtype  = [('target', np.float),
                                          ('weight', np.float),
                                          ('prediction', np.float),
                                          ('bin', np.int32)]
                      )

    groupedByTargetBins = pd.DataFrame(binnedByTargets).groupby('bin')

    weightOfTargetsAboveThr = map(lambda thr:
                                  dict([ (bin, sum(np.array(pdf['weight'])*np.array(pdf['prediction']>=thr)))
                                     for (bin,pdf) in groupedByTargetBins
                                  ]),
                                  binning
                              )

    falsePos =  [ sum([weight for (trueBin,weight) in wAbove.items() if trueBin<0 or binning[trueBin] < thr])
                  for (thr, wAbove) in zip(binning, weightOfTargetsAboveThr)
                ]

    truePos  =  [ sum([weight for (trueBin,weight) in wAbove.items() if trueBin>=0 and binning[trueBin] >= thr])
                  for (thr, wAbove) in zip(binning, weightOfTargetsAboveThr)
                ]

    cumsumAbove = [ sum([ sum(pdf['weight']) for (bin,pdf) in groupedByTargetBins if bin>=x ]) for x in range(len(binning)) ]
    cumsumBelow = [ sum([ sum(pdf['weight']) for (bin,pdf) in groupedByTargetBins if bin< x ]) for x in range(len(binning)) ]

    if absoluteRate :
        totalRate = [ falsePos[i] + truePos[i] for i in range(len(binning)) ]
        truePos  = [ v/cumsum if v>0 else 0 for (v,cumsum) in zip(truePos,cumsumAbove)  ]

        return dict(zip(binning, zip(totalRate,truePos)));
    
    else :
        truePos  = [ v/cumsum if v>0 else 0 for (v,cumsum) in zip(truePos,cumsumAbove)  ]
        falsePos = [ v/cumsum if v>0 else 0 for (v,cumsum) in zip(falsePos,cumsumBelow) ]

        return dict(zip(binning, zip(falsePos,truePos)));


# a bit of unit testing is always a good practice
import unittest

class TestSomeBins(unittest.TestCase): 
    def testBins(self):                          
        """findBin should give known result with known input"""
        step = 1/2.
        binning = np.arange(0,10,step)
        self.assertEqual([ (v,findBin(v,binning)) for v in [1,2,3,4,5,6,7,8,9] ], 
                         [ (v,v/step) for v in [1,2,3,4,5,6,7,8,9] ])

    
class TestSomeROCs(unittest.TestCase): 
    def testROCs(self):                          
        """rocMetric should give known result with known input"""
        events = np.array( [(1.,1.1,0.1),    # underflow for a binning starting at threshold=1.5
                            (2.,1.9,0.01),   # count as inefficiency for threshold=2
                            (2.3,2.51,0.02), # place in falsePos for threshold=2.5, truePos otherwise
                            (3.,3.,0.005)],  # place in truePos (on the edge)
                    dtype = [('target', np.float), ('prediction', np.float), ('weight', np.float)]
        )
        binning = np.arange(1.5,3,0.5)  # three bins total
        roc = rocMetric(events, binning)
        result = sorted([ (findBin(thr, binning),(falsePos,truePos)) for (thr,(falsePos,truePos)) in roc.items()],
                        key = lambda x: x[0])
        expect = [(0, (0, (0.01+0.02+0.005)/(0.01+0.02+0.005))),
                  (1, (0, (0.02+0.005)/(0.01+0.02+0.005))),
                  (2, (0.02/(0.1+0.01+0.02), 0.005/0.005))]
        bins     = [ b for (b,(f,t)) in result ]
        falsePos = [ f for (b,(f,t)) in result ]
        truePos  = [ t for (b,(f,t)) in result ]
        self.assertEqual( np.allclose(bins,     [ b for (b,(f,t)) in expect]), True)
        self.assertEqual( np.allclose(falsePos, [ f for (b,(f,t)) in expect]), True)
        self.assertEqual( np.allclose(truePos,  [ t for (b,(f,t)) in expect]), True)

unittest.main(argv=['ignored', '-v'], exit=False)
# Out:
# testBins (__main__.TestSomeBins)
# findBin should give known result with known input ...
# ok
# testROCs (__main__.TestSomeROCs)
# rocMetric should give known result with known input ...
# ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.008s
#
# OK

# %% [markdown]
# I'll be visually comparing a lot of ROC curves using a universal plotting function below. Feel free to skip this entire block as it is nothing else but a bulky matplotlib visualization code.

# %%
def prepareRocPlot(falseTruePos, refThresh = {}, legPos = 'upper left'):
    """
    Function for plotting the ROC curves; all aesthetics is hardcoded
    Args:
        falseTruePos: dictionary associating curve name (appears on the legend) 
                      to the tuple of return value of the rocMetric call and color
        refThresh: dictionary of points {thresholds:color} highlited along the ROC curves
    Returns:
        figure and axises
    """
    plt.close()

    # a bit of hardcoded aesthetics below
    fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
    ax0.set_ylabel(r"True positive rate", fontsize=18)
    ax0.set_xlabel(r"False positive rate", fontsize=18)
    ax0.set_ylim(0.7, 1.)
    ax0.set_xlim(0.001, 1.)
    ax0.set_xscale('log')
    plt.title("ROC curves comparison", fontsize=20)

    curves = {}
    points = {}
    
    for (name,(roc,color)) in falseTruePos.items():
        falsePos = [ f for (thr,(f,t)) in roc.items()]
        truePos  = [ t for (thr,(f,t)) in roc.items()]
        curves[name] = plt.scatter(falsePos, truePos, s = 30, c = color, edgecolors = color)
        points[name] = []
        binnedROC = { findBin(thr,binning): point for (thr,point) in roc.items() }
        for (thr,col) in refThresh.items():
            xThr = binnedROC[findBin(thr, binning)][0]
            yThr = binnedROC[findBin(thr, binning)][1]
            points[name].append( plt.scatter([xThr], [yThr], s = 30, c = col, edgecolors = col, marker='^') )

    curves.pop(None, None)
    items = curves.values()
    names = curves.keys()

    if points.items() and points.items()[0][1]:
        items.extend( points.items()[0][1] )
        names.extend( [ str(thr)+" GeV threshold position" for thr in refThresh.keys() ] )

    if items:
        plt.legend( items,
                    names,
                    scatterpoints = 1,
                    loc = legPos,
                    ncol = 1,
                    fontsize = 15 )

    return fig, ax0

# %% [markdown]
# ## Univariate linear regression
#
# Let's now perform the simplest non-regularized linear regression that predicts **1/pT** aliased as **ptTrueInv** (~curvature) from difference of $\phi$ coordinates in the first and second layers **dPhi12**. Although, difference in $\phi$ coordinate can be positive and negative, in our pre-processing compression scheme all of the differences are already given by the absolute value while the relative signs are accounted in **dPhiS** surrogate variables

# %%
from pyspark.sql.functions import lit, pow, col, log

# Create 1/pT^2 weight column that, combined with the 1/pT original spectrum, can be used
#  to account 1/pT^3 rate suggested in https://kkotov.github.io/emtfPtRegression/2017.03.03/handout.html
# Also accept only the highest quality events that have measuements (coordinates) in each of the four layers (mode==15)
dataframe2 = (dataframe1
                 .withColumn('weight', pow(col('ptTrueInv'),2))
                 .filter(dataframe1.mode == 15)
             )

print "Starting with ", dataframe2.count(), " rows"
# Out:
# Starting with
# 339727  rows

# %%
from pyspark.sql.functions import explode, udf
from pyspark.sql.types import IntegerType, ArrayType
# Following the last response from
# https://stackoverflow.com/questions/34360324/scala-spark-sample-with-replacement-specify-probabilities
# for "samplig" I implement an entire bloody routine, that would otherwise be a true one-liner in R:
#  dataframe2[ sample(seq_len(nrow(dataframe2)), size = 100000, replace = T, prob = dataframe2$weight), ]

createDups = udf(lambda s: range(np.random.poisson(s*10000)), ArrayType(IntegerType()))
dataframe3 = dataframe2.select('*',explode(createDups(dataframe2.weight))).sample(True,0.01,123) #.limit(300000)

print "After reweighting I have ", dataframe3.count(), " rows"
print "Events with pT>150 GeV before reweighting: ", dataframe2[ dataframe2.ptTrue > 150 ].count()
print "Events with pT>150 GeV after reweighting:  ", dataframe3[ dataframe3.ptTrue > 150 ].count()

(trainingData, testData) = dataframe3.randomSplit([0.7, 0.3])
# Out:
# After reweighting I have
# 466730  rows
# Events with pT>150 GeV before reweighting:
# 111309
# Events with pT>150 GeV after reweighting:
# 123

# %%
## The block below reads in the same data but after all the manupulations done independently
##  it also takes train/test split used for other methods outside of this notebook
#df0 = (sqlContext
#                         .read.format("com.databricks.spark.csv")
#                         .options(delimiter=',',header='true',inferschema='true')
#                         .load("hdfs://localhost:9000/data/one.csv"))
#
#df1 = df0.withColumn('ptTrueInv', pow(col('muPtGen'),-1)).withColumn('ptTrue', col('muPtGen'))
#df1.printSchema()
#print "After reweighting I have ", df1.count(), " rows"
#print "Events with pT>150 GeV after reweighting:  ", df1[ df1.muPtGen > 150 ].count()
#
#trainingData = df1[ df1.trainIdx == 0 ]
#testData     = df1[ df1.trainIdx == 1 ]

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression

# Spark models consume feature vector that needs to be built from columns of predictors
oneFeature = VectorAssembler(inputCols=["dPhi12"], outputCol="features")

# no regularization for the linear regression yet
linearReg = LinearRegression(maxIter = 10,
                             regParam = 0.0,
                             elasticNetParam = 1.0,
                             standardization = False,
                             labelCol = "ptTrueInv",
#                             weightCol = "weight"
                             )
# I weight-sample the source data in the previous cell rather than directly use the weights column
#  commented out above because among all only the linear model supports such column-based reweighting
#  while I need to put apples to apples when comparing the other "non-reweightable" models to it

# chaining the transformations
lrPipeline = Pipeline(stages=[oneFeature, linearReg])

# Fit the model
linearModel = lrPipeline.fit(trainingData)

# Use it on the test data
linearTest = linearModel.transform(testData)[['ptTrueInv','dPhi12','prediction']].collect() #take(10000)

# %%
# gosh, in R the construct below would fit into a single subsetting statement, no more comments ...
skim1 = np.array( [ (1./row['ptTrueInv'], 1./row['prediction'], row['dPhi12'], 1)
                    for row in linearTest
                  ], dtype  = [('target', np.float),
                               ('prediction', np.float),
                               ('dPhi12', np.float),
                               ('weight', np.float)]
        )
# Note inverting target and prediction back to the physics scale above

# Let's now look at the fit visually
plt.close()
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
ax0.set_ylabel(r"Simulated 1/$p_T$ values (targets)", fontsize=18)
ax0.set_xlabel(r"Measured $\Delta \phi_{12}$ values", fontsize=18)
ax0.set_ylim(0, 1.)
ax0.set_xlim(0, 500)
plt.scatter(skim1['dPhi12'], 1./skim1['target'], s=1, c='#d6ebf2', edgecolors='#8cbfd0', alpha=1.)

x_vals = np.array(ax0.get_xlim())
y_vals = linearModel.stages[1].intercept + linearModel.stages[1].coefficients * x_vals

plt.plot(x_vals, y_vals, linewidth=3.0, c='#0cbfd0', linestyle='--')
plt.title("Fitting a linear model to dPhi12", fontsize=20)
plt.show()

# %% [markdown]
# The plot above shows the inflexibility of the linear model. The RMSE optimization against **1/pT** target down-weight the contribution from high **pT** or low **dPhi12** rows. As the result, oppositely to the common sense that suggest that straight energetic tracks (**1/pT** ~= 0) should have little bending (**dPhi12** ~= 0), the regression does not cross the coordinate origin and the intercept limits maximum assignable **pT** around 6 GeV. Let's see at some simple metrics below.

# %%
# Simplest in-sample performance metrics (explained, for example, in https://kkotov.github.io/emtfPtRegression/2017.01.19/#4):
linearModelRMSE = linearModel.stages[1].summary.rootMeanSquaredError
print("RMSE: %f" % linearModelRMSE)
print("Fraction of variance explained (R-squared): %f" % linearModel.stages[1].summary.r2)
print "Intercept: ", linearModel.stages[1].intercept, ",  slope: ", linearModel.stages[1].coefficients
print("Significance (tValues): %f, %f" % (linearModel.stages[1].summary.tValues[0],linearModel.stages[1].summary.tValues[1]) )
# Out:
# RMSE: 0.107693
# Fraction of variance explained (R-squared): 0.458022
# Intercept:  0.159378080046 ,  slope:  [0.000837508122593]
# Significance (tValues): 526.110888, 462.036291

# %% [markdown]
# Btw., the metrics above wouldn't be accurate if the column-based reweighting is used in this linear model.
#
# Below I'll build the first ROC curve. I'll use it as a reference to compare with another model a bit later.

# %%
# consider equally-spaced binning
binning = np.arange(2,200,0.5)

linearROC = rocMetric(skim1, binning)

fig, ax0 = prepareRocPlot({None:(linearROC,'#0cbfd0')}, {5:'red',4:'brown',3:'green'}, legPos='lower right')
ax0.set_xscale('linear')
ax0.set_ylim(0, 1.)
ax0.set_xlim(0, 1.)
plt.title("ROC curve for univariate linear regression", fontsize=20)
plt.show()

# %% [markdown]
# ## Multivariate linear regression
#
# Let's now consider all of the predictors and select the best model. Leave aside best subset selection as well as forward/backward step-/stage-wise regression. Just perform a scan over lasso regularization hyperparameter that automatically suppresses the least important predictors. Don't forget to standardize the predictors to treat them on equal footing with the regularization.

# %%
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import VectorIndexer

# put together all categorical predictors
assemblerCategorical = VectorAssembler(inputCols=
                            ['clct1', 'clct2', 'clct3', 'clct4',
                             'fr1',   'fr2',   'fr3',   'fr4',
                             'rpc1',  'rpc2',  'rpc3',  'rpc4',
                             'st1_ring2'],
                            outputCol='categoricalFeatures')

# put together all continuous predictors
assemblerContinuous = VectorAssembler(inputCols=
                            ['theta',
                             'dPhi12',   'dPhi13',   'dPhi14',   'dPhi23',   'dPhi24',   'dPhi34',
                             'dTheta12', 'dTheta13', 'dTheta14', 'dTheta23', 'dTheta24', 'dTheta34',
                             'dPhiS4',   'dPhiS4A',  'dPhiS3',   'dPhiS3A'],
                            outputCol='continuousFeatures')

# index categorical predictors
catFeatureIndexer = VectorIndexer(inputCol='categoricalFeatures', outputCol='indexedCatFeatures', maxCategories=10)

# put all predictors togeteher in one feature vector
assembler = VectorAssembler(inputCols=['indexedCatFeatures','continuousFeatures'], outputCol='features')

# chain transformations in a pipeline
multiLinRegPipeline = Pipeline(stages=[assemblerCategorical, catFeatureIndexer, assemblerContinuous, assembler, linearReg])

# lasso regularization is a particular case of the elastic net with alpha=1
linearReg.setElasticNetParam(1)
linearReg.setStandardization(True)

# define a hyperparameter grid
regParSweep = [1., 1/2., 1/4., 1/16., 1/32., 1/64., 1/128., 1/256., 1/512., 1/1024., 1/2048., 1/4096., 1/8192., 1/16384., 1/32768., 1/65536.]

crossval = CrossValidator(estimator = multiLinRegPipeline,
                          estimatorParamMaps = ParamGridBuilder()
                                                 .addGrid(linearReg.regParam, regParSweep)
                                                 .build(),
                          evaluator = RegressionEvaluator(labelCol='ptTrueInv', metricName='rmse'),
                          numFolds = 10)

cvLinModel = crossval.fit(trainingData)

# Note, the whole block above fits more or less in a couple of lines in R:
# https://kkotov.github.io/emtfPtRegression/2017.01.19/#8

# %%
# Let's have a look at the scan
print "Average RMSE metric as a function of regularization parameter:"

plt.close()
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
ax0.set_ylabel(r"RMSE", fontsize=18)
ax0.set_xlabel(r"Lasso regularization parameter", fontsize=18)
ax0.set_ylim(0.05, 0.2)
ax0.set_xlim(min(regParSweep), 1.)
ax0.set_xscale('log')
ax0.set_yscale('log')

plt.scatter(regParSweep, cvLinModel.avgMetrics, s=100, c='#d6ebf2', edgecolors='#8cbfd0')

# find the best point
indexRMSEmin = min(xrange(len(cvLinModel.avgMetrics)), key = cvLinModel.avgMetrics.__getitem__)

x_vals = [regParSweep[indexRMSEmin], regParSweep[indexRMSEmin]]
y_vals = [0, 10]
plt.plot(x_vals, y_vals, linewidth=3.0, c='#0cbfd0', linestyle='--')
plt.title("Regularization hyperparameter scan", fontsize=20)
plt.show()

print "\nNumbers from the plot above:"
for i,j in zip(xrange(len(regParSweep)), cvLinModel.avgMetrics):
    sys.stdout.write("%f %s %f" % (regParSweep[i], " => ", j))
    if i == indexRMSEmin :
        print " (best)"
    else :
        print ""

## optionally one can look at some technical details
# print cvLinModel.extractParamMap()
# print cvLinModel.getEstimator().getStages()[4].params
# print cvLinModel.bestModel.stages[4].coefficients
# Out:
# Average RMSE metric as a function of regularization parameter:
# Numbers from the plot above:
# 1.000000  =>  0.146299
# 0.500000  =>  0.146385
# 0.250000  =>  0.146233
# 0.062500  =>  0.121651
# 0.031250  =>  0.100368
# 0.015625  =>  0.091160
# 0.007812  =>  0.087443
# 0.003906  =>  0.079812
# 0.001953  =>  0.075647
# 0.000977  =>  0.074369
# 0.000488  =>  0.073879
# 0.000244  =>  0.073833
# 0.000122  =>  0.074035
# 0.000061  =>  0.073766 (best)
# 0.000031  =>  0.073795
# 0.000015  =>  0.074537

# %% [markdown]
# No surprise the best fit is achieved at low regularization: it is only when model start chasing the noise, the regularization kicks in. Simple linear model does not have much of flexibility to fit the noise with 30 coefficients in millions of events. Therefore model with small regularization is likely to be the optimal one.
#
# On the other hand, the last seven points are more or less on the same level and the best among them seems to be due to a slight fluctuation down. As I want to have more low-significance predictors to be zeroed out, I choose the right-most point on the lower plateau as the regularization parameter of choice.

# %%
indexRMSEmin = 9

# %% [markdown]
# As I now have chose the optimal model (the one with $\lambda$ = 1/1024.), it is time to check the model's coefficients, apply the model to the test data, and look at the performance.

# %%
# Train the multivariate linear regression with the best lasso regularization on the full training set
linearReg.setStandardization(True)
linearReg.setElasticNetParam(1)
linearReg.setRegParam( regParSweep[indexRMSEmin] )
# activating any regularization changes an under-the-hood solver from "normal" to something else that
#  unfortunately doesn't calculate significance levels of the model coefficients. Documentation at
#  https://spark.apache.org/docs/2.0.2/api/java/org/apache/spark/ml/regression/LinearRegressionSummary.html
#  confirms it

# fit the model
multiLinearModel = multiLinRegPipeline.fit(trainingData)
# apply it to the test data
multiLinearTest = multiLinearModel.transform(testData)

## multiLinearModel.stages[-1].summary.featuresCol == 'features'
## multiLinearModel.stages[-1].summary.residuals.show(10)

# a bulky way to link predictor's index in the feature vector with its original name
cffNameIdx = multiLinearTest \
               .schema[str(multiLinearModel.stages[-1].summary.featuresCol)] \
               .metadata['ml_attr']['attrs'] \
               .values()

# flatten the array of binary, ordinal, and numeric predictors
cff = [ (predictor['name'],predictor['idx']) for category in cffNameIdx for predictor in category ]

# with no explicit significance I can only rely on lasso to zero-out the non-significant coefficients
print "Coefficients:"
for c in cff: print "%s = %.3e" % (c[0], multiLinearModel.stages[-1].coefficients[c[1]])
    
print "intercept = %.3f" %  multiLinearModel.stages[-1].intercept

multiLinearR2 = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='r2') \
                     .evaluate(multiLinearTest)
multiLinearRMSE = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='rmse') \
                     .evaluate(multiLinearTest)
print "\nOut-Of-Sample R-squared: %f" % multiLinearR2, " RMSE: %f" % multiLinearRMSE

## also doesn't work:
#cvLinModel.bestModel.stages[2].extractParamMap()
#cvLinModel.bestModel.stages[-1].summary.coefficientStandardErrors()
#cvLinModel.bestModel.stages[-1].summary.pValues
# Out:
# Coefficients:
# indexedCatFeatures_fr1 = -2.136e-02
# indexedCatFeatures_fr2 = 9.461e-04
# indexedCatFeatures_fr3 = -7.464e-04
# indexedCatFeatures_fr4 = 0.000e+00
# indexedCatFeatures_rpc1 = 5.528e-02
# indexedCatFeatures_rpc2 = 0.000e+00
# indexedCatFeatures_rpc3 = 8.407e-03
# indexedCatFeatures_rpc4 = -8.847e-03
# indexedCatFeatures_st1_ring2 = 2.209e-01
# indexedCatFeatures_clct1 = 1.933e-02
# indexedCatFeatures_clct2 = 5.507e-03
# indexedCatFeatures_clct3 = 0.000e+00
# indexedCatFeatures_clct4 = 5.036e-03
# continuousFeatures_theta = -3.190e-02
# continuousFeatures_dPhi12 = 1.751e-04
# continuousFeatures_dPhi13 = 1.273e-04
# continuousFeatures_dPhi14 = 3.583e-05
# continuousFeatures_dPhi23 = -7.738e-06
# continuousFeatures_dPhi24 = -2.571e-04
# continuousFeatures_dPhi34 = -7.797e-04
# continuousFeatures_dTheta12 = 1.951e-03
# continuousFeatures_dTheta13 = 0.000e+00
# continuousFeatures_dTheta14 = -1.637e-03
# continuousFeatures_dTheta23 = 3.011e-03
# continuousFeatures_dTheta24 = 4.008e-04
# continuousFeatures_dTheta34 = 0.000e+00
# continuousFeatures_dPhiS4 = 8.349e-06
# continuousFeatures_dPhiS4A = 8.925e-05
# continuousFeatures_dPhiS3 = 0.000e+00
# continuousFeatures_dPhiS3A = 1.414e-04
# intercept = 0.178
#
# Out-Of-Sample R-squared: 0.740100
#   RMSE: 0.074551

# %% [markdown]
# As can be seen above, even with such a small regularization parameter lasso drops and suppresses nearly third of the predictors. On the other hand linear regression might not have found a good use some of the parameters that potentially hide non-linear dependencies. The same, for example, could happen to the **dPhi** predictors would they be signed. In such case their correlation with the intrinsically unsigned **pT** variable would be zeroed out along with the corresponding regression coefficients.
#
# Nonetheless, as can be seen below, the multivariate regularized linear model performs way better than a univariate model. I'll use the former for comparison with non-linear methods in the following sections.

# %%
# collect and arange variables on the driver node
# (don't forget to invert prediction back to be consistent with the target and binning
stdTypes = [('target', np.float), ('prediction', np.float), ('weight', np.float)]
skim2  = np.array( [ (row['ptTrue'], 1./row['prediction'], 1)
                     for row in multiLinearTest[['ptTrue','prediction']].collect()
                   ], dtype = stdTypes )
# ROC
multiLinROC = rocMetric(skim2, binning)

fig, ax0 = prepareRocPlot({"Univariate linear model":(linearROC,'blue'),
                           "Multivariate linear model":(multiLinROC,'#0cbfd0')},
                          {3:'red',5:'brown'}, legPos='lower right')
ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0, 1.)
ax0.set_xscale('linear')
plt.title("ROC curves comparison for linear models", fontsize=20)
plt.show()

# %% [markdown]
# No surprise the plot above demonstrates that model with more parameters does better. Nonetheless, it has to be understood that the model is optimized against RSS and not ROC that is a different metric. The **1/pT** target in RSS signifies the low-pT region at a potential expense of higher **pT** behavior. It means that a new model could very well achieve a better (smaller) RMSE/RSS, but do a mediocre job at where the ROCs raises. Fortunately, it was not the case here.
#
# ## Departing from linearity with ensemble trees methods
#
# The linear model above could be extended with interactions among predictors (i.e. with cross-products and higher orders). I could also move on to the generalized additive models that are still linear in the coefficients, but allow much greater flexibility as the basis is generally a set of unspecified smooth (nonparametric) functions like splines. Although, that would be an interesting exercise, I'll jump over it and go straight to the methods that allow arbitrary order interactions and non-linearity with no effort, out of the box. I start with the tree-based methods such as Gradient Boosted Trees and Random Forests. I'll also keep **1/pT** as the target that stresses the domain-motivated importance of the low pT region.

# %%
# Let's start with the Gradient Boosted Trees
from pyspark.ml.regression import GBTRegressor

# train the model with 'squared' loss ('absolute' loss appears not to do well here)
gbt = GBTRegressor(featuresCol="features", maxIter=100, labelCol='ptTrueInv', lossType='squared')

# chain transformations in a pipeline
gbtPipeline = Pipeline(stages=[assemblerCategorical, catFeatureIndexer, assemblerContinuous, assembler, gbt])

# fit the model
gbtModel = gbtPipeline.fit(trainingData) #.limit(100000))

# apply the model to test set
gbtTest = gbtModel.transform(testData)

# and evaluate its performance
gbtRMSE = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='rmse') \
                     .evaluate(gbtTest)

# %%
gbtROC = rocMetric(
             np.array( [(row['ptTrue'], 1./row['prediction'], 1) for row in gbtTest[['ptTrue','prediction']].collect()],
                       dtype = stdTypes ),
             binning)

fig, ax0 = prepareRocPlot({"Multivariate linear model":(multiLinROC,'blue'),
                           "GBT":(gbtROC,'#0cbfd0')},
                          {5:'red',14:'brown'}, legPos='lower right')
ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0, 0.3)
ax0.set_xscale('linear')
plt.show()

# %% [markdown]
# Not surprisingly, Gradient Boosted Tree is superior to the linear models. Below I fit the same model several times with different random seeds and check uncertainty of its predictions.

# %%
gbt.setSeed(11)
(trainSet1, testSet1) = dataframe3.randomSplit([0.7, 0.3], seed=110)
gbtModel1 = gbtPipeline.fit(trainSet1)
gbtTest1 = gbtModel1.transform(testSet1)

gbt.setSeed(110)
(trainSet2, testSet2) = dataframe3.randomSplit([0.7, 0.3], seed=1110)
gbtModel2 = gbtPipeline.fit(trainSet2)
gbtTest2 = gbtModel2.transform(testSet2)

gbt.setSeed(1111)
(trainSet3, testSet3) = dataframe3.randomSplit([0.7, 0.3], seed=11111)
gbtModel3 = gbtPipeline.fit(trainSet3)
gbtTest3 = gbtModel3.transform(testSet3)

# %%
gbtROC1 = rocMetric(
              np.array( [(1./row['ptTrueInv'], 1./row['prediction'], 1) for row in gbtTest1[['ptTrueInv','prediction']].collect()],
                        dtype = stdTypes ),
              binning )

gbtROC2 = rocMetric(
              np.array( [(1./row['ptTrueInv'], 1./row['prediction'], 1) for row in gbtTest2[['ptTrueInv','prediction']].collect()],
                        dtype = stdTypes ),
              binning )

gbtROC3 = rocMetric(
              np.array( [(1./row['ptTrueInv'], 1./row['prediction'], 1) for row in gbtTest3[['ptTrueInv','prediction']].collect()],
                        dtype = stdTypes ),
              binning )

fig, ax0 = prepareRocPlot({"GBT #1":(gbtROC1,'blue'),
                           "GBT #2":(gbtROC2,'#0cbfd0'),
                           "GBT #3":(gbtROC3,'cyan')},
                          {15:'red',10:'brown',5:'m'},
                          legPos = 'lower right')
ax0.set_ylim(0.5, 1.)
ax0.set_xlim(0.001, 0.3)
plt.show()

# %% [markdown]
# Looks like there is a bit of a noise at bottom-left corner, but the results are self-consistent.
#
# Let's now check the variable importance.

# %%
import re

# again, associate feature indexes with the original predictors' names
gbtCffNameIdx = gbtTest \
               .schema['features'] \
               .metadata['ml_attr']['attrs'] \
               .values()

# flatten the array of binary, ordinal, and numeric predictors
gbtCff = [ (re.sub(r".*_","",predictor['name']),predictor['idx']) for category in gbtCffNameIdx for predictor in category ]

## Variable importance
#print "Variable importance:"
#for c in gbtCff: print "%s = %.3e" % (c[0], gbtModel.stages[-1].featureImportances[c[1]])

fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')

ax0.barh(range(len(gbtCff)),
         [gbtModel.stages[-1].featureImportances[c[1]] for c in gbtCff],
         color = 'r',
         tick_label = [c[0] for c in gbtCff])

plt.title("GBT variable importance", fontsize=20)
plt.show()

metric = RegressionEvaluator(labelCol='ptTrueInv', predictionCol='prediction', metricName='r2').evaluate(gbtTest)
print "\nOut-Of-Sample R-squared: %f" % metric
# Out:
# Out-Of-Sample R-squared: 0.899601

# %% [markdown]
# Interesting how much of importance the method assigned to **dPhi34**, though.
#
# Random Forest is an alternative model. Despite its conceptual tuning simplicity, it looks like the Spark's version is very sensitive to the choice of tuning parameters ... to the extent that it runs out of memory and crashes (!) when grow trees deep (say maxDepth>7, or >2^7=128 leafs per tree, ... on my 16Gb node?). While having implemented RF myself (although not in a functional programming language), I find such behavior not acceptable for a tool that is so widely popularized. Anyways, have a look at the model below yourselves.

# %%
from pyspark.ml.regression import RandomForestRegressor

# let's train a simple Random Forest
randomForest = RandomForestRegressor(labelCol='ptTrueInv', featuresCol='features', numTrees=256, #128,
                                     impurity='variance', maxDepth=5) #, maxBins=96)

# chain transformations in a pipeline
rfPipeline = Pipeline(stages=[assemblerCategorical, catFeatureIndexer, assemblerContinuous, assembler, randomForest])

# Fit the model
rfModel = rfPipeline.fit(trainingData)

# Apply the model to test set
rfTest = rfModel.transform(testData)

# %%
rfROC = rocMetric( np.array(
                       [ (row['ptTrue'], 1./row['prediction'], 1) for row in rfTest[['ptTrue','prediction']].collect() ],
                       dtype  = stdTypes ),
                   binning )

fig, ax0 = prepareRocPlot({"Multivariate linear model":(multiLinROC,'blue'),
                           "GBT":(gbtROC,'#0cbfd0'),
                           "Random Forest": (rfROC,'red')})
ax0.set_ylim(0.5, 1.)
ax0.set_xlim(0.001, 0.3)
plt.show()

# %% [markdown]
# A mediocre Spark's RF performance looks disturbing. Below I cross-check the performance against RF in [Scikit-Learn](scikit-learn.org), [Ranger](https://github.com/imbs-hl/ranger), and in [my C++ implementation](https://github.com/kkotov/ml).

# %%
# First, load the data with pandas; no more HDFS, only main RAM
import pandas as pd
df0 = pd.read_csv('/home/kkotov/oldSim.csv')

# categorical and continuous predictor columns
#cat = ['clct1', 'clct2', 'clct3', 'clct4',
#       'fr1',   'fr2',   'fr3',   'fr4',
#       'rpc1',  'rpc2',  'rpc3',  'rpc4',
#       'st1_ring2']
#cont = ['theta',
#        'dPhi12',   'dPhi13',   'dPhi14',   'dPhi23',   'dPhi24',   'dPhi34',
#        'dTheta12', 'dTheta13', 'dTheta14', 'dTheta23', 'dTheta24', 'dTheta34',
#        'dPhiS4',   'dPhiS4A',  'dPhiS3',   'dPhiS3A']
# only a subset of predictors were used to train the model that would fit into the pT LUT memory
cat = ['clct1',
       'fr1',
       'rpc1',  'rpc2',  'rpc3',  'rpc4',
       'st1_ring2']
cont = ['theta',
        'dPhi12',   'dPhi13',   'dPhi14',   'dPhi23',   'dPhi24',   'dPhi34',
        'dTheta14',
        'dPhiS4',   'dPhiS4A',  'dPhiS3',   'dPhiS3A']

from copy import deepcopy
# combine the above in a single list of predictors
predictors = deepcopy(cat)
predictors.extend( cont )
# and complement it with the target
variables = deepcopy(predictors)
variables.extend( ['muPtGen'] )

# subset the first and second trajectories per entry
import re
df1_1 = df0[ df0['mode[0]'].isin([15]) ][[ re.sub(r'$','[0]',p) for p in variables ]]
df1_2 = df0[ df0['mode[1]'].isin([15]) ][[ re.sub(r'$','[1]',p) for p in variables ]]
# rename the columns
df1_1.columns = variables
df1_2.columns = variables
# and concatenate the two dataframes to have "one event - one trajoctory"
df1 = pd.concat([df1_1, df1_2])

# The sklearn will infer categorical vs. continuous features based on their type, so envorce the type
df1[cont] = df1[cont].astype(float)

# cook-up different targets
import math
df1['invLogPtTrue']  = df1['muPtGen'].apply(lambda x: 1/math.log(x))
df1['invSqrtPtTrue'] = df1['muPtGen'].apply(lambda x: 1/math.sqrt(x))
df1['invSqrt2PtTrue']= df1['muPtGen'].apply(lambda x: 1/math.sqrt(math.sqrt(x)))
df1['ptTrueInv']  = 1./df1['muPtGen']

# split to train and test sampes
nRows = df1[predictors].shape[0]
trainRows = int(0.7*nRows)
(trainSet, testSet) = (df1[1:trainRows], df1[trainRows:nRows])

# reweight to 1/pT^3 spectrum
trainSet = trainSet.sample(n=300000, replace=True, weights=trainSet['ptTrueInv']**2, random_state=123)
testSet  = testSet .sample(n=100000, replace=True, weights=testSet ['ptTrueInv']**2, random_state=123)

# %%
# Train the RF and GBT in sklearn
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# models
sklRf  = RandomForestRegressor(n_estimators=128, max_features=len(predictors)/2, n_jobs=6)
sklGbt = GradientBoostingRegressor(n_estimators=128, learning_rate=0.1, max_depth=8, random_state=0, loss='ls')

# fit the model
sklRf .fit(trainSet[predictors], trainSet[['ptTrueInv']].values.ravel())
sklGbt.fit(trainSet[predictors], trainSet[['ptTrueInv']].values.ravel())

# predict and invert the target to a normal scale
sklRfTest  = 1./sklRf. predict(testSet[predictors])
sklGbtTest = 1./sklGbt.predict(testSet[predictors])

sklRfRMSE  = math.sqrt( mean_squared_error(testSet[['ptTrueInv']].values.ravel(), 1./sklRfTest)  )
sklGbtRMSE = math.sqrt( mean_squared_error(testSet[['ptTrueInv']].values.ravel(), 1./sklGbtTest) )

print "Scikit-learn RMSE: RF=", sklRfRMSE, " GBT=", sklGbtRMSE
# Out:
# Scikit-learn RMSE: RF= 0.0485027505491  GBT= 0.0492592165143

# %%
# load the C++ wrapper library for my RF implementation
import ctypes
rflib = ctypes.cdll.LoadLibrary('/home/kkotov/work/emtfPtRegression/2017.09.07/wrapper.so')
rflib.RandomForest_regress.restype = ctypes.c_double

# a python wrapper's counterpart
class RandomForest(object):
    def __init__(self):
        self.obj = rflib.RandomForest_new()

    def load(self,filename):
        rflib.RandomForest_load(self.obj, filename)

    def regress(self,e):

        res = rflib.RandomForest_regress(self.obj, e['theta'], e['st1_ring2'],
                                        e['dPhi12'], e['dPhi13'], e['dPhi14'], e['dPhi23'], e['dPhi24'], e['dPhi34'],
                                        e['dTheta14'],
                                        e['dPhiS4'], e['dPhiS4A'], e['dPhiS3'], e['dPhiS3A'],
                                        e['clct1'],
                                        e['fr1'],
                                        e['rpc1'], e['rpc2'], e['rpc3'], e['rpc4']
                                       )
        return res

# instantiate and load an already trained model with the limited set of features given in the wrapper above
rf = RandomForest()
rf.load("/home/kkotov/work/emtfPtRegression/2017.09.07/rf.model")

# the model is trained offline and needs to be tested on events, different from those used in training
# the dataset below is the same oldSim.csv, but sampled for 1/pT^2 weight,
#   and retaining training/test partitioning that was used for training the model loaded above
df2 = pd.read_csv("/home/kkotov/work/emtfPtRegression/2017.09.07/one.csv")
# select events for testing
df2 = df2[df2.trainIdx == 0]
# make predictions and remember that the model was trained for 1/pT target
myRfTest = [ (cnt,1./rf.regress(row)) for (cnt,row) in df2[predictors].iterrows() ]

# %%
# put everything on the same plot
myRfROC = rocMetric(np.array([(df2.loc[cnt,'muPtGen'], p, 1) for (cnt,p) in myRfTest], dtype=stdTypes), binning)
baseROC = rocMetric(np.array([(df2.loc[cnt,'muPtGen'], df2.loc[cnt,'ptXML'], 1) for (cnt,p) in myRfTest], dtype=stdTypes), binning)
rangerROC=rocMetric(np.array([(df2.loc[cnt,'muPtGen'], df2.loc[cnt,'ranger'],1) for (cnt,p) in myRfTest], dtype=stdTypes), binning)
sklRfROC =rocMetric(np.array( zip(testSet[['muPtGen']].values.ravel(), sklRfTest, [1]*len(sklRfTest)),  dtype=stdTypes), binning)
sklGbtROC=rocMetric(np.array( zip(testSet[['muPtGen']].values.ravel(), sklGbtTest,[1]*len(sklGbtTest)), dtype=stdTypes), binning)

fig, ax0 = prepareRocPlot({"Ranger":                (rangerROC,'grey'),
                           "My Random Forest":      (myRfROC,  '#06ebf2'),
                           "SKLearn Random Forest": (sklRfROC, 'blue'),
                           "SKLearn GBT":           (sklGbtROC,'green'),
                           "EMTF baseline":         (baseROC,  'red'),
                           "Spark's Random Forest": (rfROC,    'brown'),
                           "Spark's GBT":           (gbtROC,   'black'),
                           }, legPos="lower right")

ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0001, 0.1)
#ax0.set_xscale('linear')

plt.show()

# %% [markdown]
# The EMTF baseline model (what is currently being used in production) demonstrates superior performance over the other models. The only problem is that it was trained on the very same sample. With no information on the original test/train splitting I may be observing the performance gain of running the model on the data it was trained on. RF and GBT of SKLearn together with Ranger and my RF implementation set the second best performance level (all are surprisingly close). And RF from Spark ML looses to everything.

# %% [markdown]
# ## Neural Networks
#
# Let's now look at the neural networks. First of all, tuning a neural network (NN) is an art. Only in simplest problems and for simplest NN configurations one can expect a reasonable performance out of the box. In order to have "a feel" for the right NN model I create several references starting with the smallest number of predictors, zero initial weights, and smooth activation function. It puts NN model close to the interpretable linear model.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

tfModel1 = Sequential()

# only input and output layers, no hidden layers yet
tfModel1.add(Dense(units=1, input_dim=1, activation='sigmoid', kernel_initializer='zero', bias_initializer='zero'))
tfModel1.add(Dense(units=1, kernel_initializer='zero', bias_initializer='zero'))

tfModel1.compile(loss='mse', optimizer='rmsprop')

y_train = trainSet['ptTrueInv'].values.ravel()
y_test  = testSet ['ptTrueInv'].values.ravel()
x_train = trainSet['dPhi12'].values
x_test  = testSet ['dPhi12'].values

# x_train and y_train are Numpy arrays --just like in the Scikit-Learn API.
tfModel1.fit(x_train, y_train, epochs=5)

tfTest1 = 1./tfModel1.predict(x_test).ravel()

print "RMSE test  = ", math.sqrt( mean_squared_error(y_test,  1./tfTest1)  )
print "RMSE train = ", math.sqrt( mean_squared_error(y_train, tfModel1.predict(x_train).ravel() ))
print "Recall, RMSE of the univariate linear model = ", linearModelRMSE
# Out:
# Epoch 1/5
#     32/300000 [..............................] - ETA: 576s - loss: 0.1089
#   3264/300000 [..............................] - ETA: 10s - loss: 0.0638
#   6496/300000 [..............................] - ETA: 7s - loss: 0.0430
#   9952/300000 [..............................] - ETA: 6s - loss: 0.0341
#  13344/300000 [>.............................] - ETA: 5s - loss: 0.0295
#  16768/300000 [>.............................] - ETA: 5s - loss: 0.0266
#  20160/300000 [=>............................] - ETA: 5s - loss: 0.0246
#  23584/300000 [=>............................] - ETA: 4s - loss: 0.0232
#  26976/300000 [=>............................] - ETA: 4s - loss: 0.0219
#  30400/300000 [==>...........................] - ETA: 4s - loss: 0.0209
#  33792/300000 [==>...........................] - ETA: 4s - loss: 0.0200
#  37152/300000 [==>...........................] - ETA: 4s - loss: 0.0193
#  40544/300000 [===>..........................] - ETA: 4s - loss: 0.0187
#  44000/300000 [===>..........................] - ETA: 4s - loss: 0.0182
#  47360/300000 [===>..........................] - ETA: 4s - loss: 0.0177
#  50816/300000 [====>.........................] - ETA: 4s - loss: 0.0174
#  54112/300000 [====>.........................] - ETA: 3s - loss: 0.0170
#  57568/300000 [====>.........................] - ETA: 3s - loss: 0.0167
#  60928/300000 [=====>........................] - ETA: 3s - loss: 0.0164
#  64352/300000 [=====>........................] - ETA: 3s - loss: 0.0162
#  67744/300000 [=====>........................] - ETA: 3s - loss: 0.0159
#  71072/300000 [======>.......................] - ETA: 3s - loss: 0.0157
#  74496/300000 [======>.......................] - ETA: 3s - loss: 0.0155
#  77920/300000 [======>.......................] - ETA: 3s - loss: 0.0153
#  81312/300000 [=======>......................] - ETA: 3s - loss: 0.0152
#  84768/300000 [=======>......................] - ETA: 3s - loss: 0.0151
#  88096/300000 [=======>......................] - ETA: 3s - loss: 0.0149
#  91520/300000 [========>.....................] - ETA: 3s - loss: 0.0148
#  94848/300000 [========>.....................] - ETA: 3s - loss: 0.0147
#  98304/300000 [========>.....................] - ETA: 3s - loss: 0.0146
# 101728/300000 [=========>....................] - ETA: 3s - loss: 0.0145
# 105184/300000 [=========>....................] - ETA: 3s - loss: 0.0144
# 108480/300000 [=========>....................] - ETA: 2s - loss: 0.0143
# 111936/300000 [==========>...................] - ETA: 2s - loss: 0.0142
# 115264/300000 [==========>...................] - ETA: 2s - loss: 0.0142
# 118688/300000 [==========>...................] - ETA: 2s - loss: 0.0141
# 122080/300000 [===========>..................] - ETA: 2s - loss: 0.0140
# 125504/300000 [===========>..................] - ETA: 2s - loss: 0.0139
# 128896/300000 [===========>..................] - ETA: 2s - loss: 0.0139
# 132288/300000 [============>.................] - ETA: 2s - loss: 0.0138
# 135616/300000 [============>.................] - ETA: 2s - loss: 0.0137
# 139008/300000 [============>.................] - ETA: 2s - loss: 0.0137
# 142368/300000 [=============>................] - ETA: 2s - loss: 0.0136
# 145792/300000 [=============>................] - ETA: 2s - loss: 0.0136
# 149184/300000 [=============>................] - ETA: 2s - loss: 0.0135
# 152608/300000 [==============>...............] - ETA: 2s - loss: 0.0135
# 156032/300000 [==============>...............] - ETA: 2s - loss: 0.0135
# 159488/300000 [==============>...............] - ETA: 2s - loss: 0.0134
# 162880/300000 [===============>..............] - ETA: 2s - loss: 0.0134
# 166336/300000 [===============>..............] - ETA: 2s - loss: 0.0133
# 169696/300000 [===============>..............] - ETA: 1s - loss: 0.0133
# 173120/300000 [================>.............] - ETA: 1s - loss: 0.0132
# 176544/300000 [================>.............] - ETA: 1s - loss: 0.0132
# 180000/300000 [=================>............] - ETA: 1s - loss: 0.0132
# 183392/300000 [=================>............] - ETA: 1s - loss: 0.0132
# 186784/300000 [=================>............] - ETA: 1s - loss: 0.0131
# 190176/300000 [==================>...........] - ETA: 1s - loss: 0.0131
# 193600/300000 [==================>...........] - ETA: 1s - loss: 0.0131
# 196960/300000 [==================>...........] - ETA: 1s - loss: 0.0131
# 200416/300000 [===================>..........] - ETA: 1s - loss: 0.0130
# 203840/300000 [===================>..........] - ETA: 1s - loss: 0.0130
# 207296/300000 [===================>..........] - ETA: 1s - loss: 0.0130
# 210656/300000 [====================>.........] - ETA: 1s - loss: 0.0130
# 214112/300000 [====================>.........] - ETA: 1s - loss: 0.0129
# 217536/300000 [====================>.........] - ETA: 1s - loss: 0.0129
# 220992/300000 [=====================>........] - ETA: 1s - loss: 0.0129
# 224416/300000 [=====================>........] - ETA: 1s - loss: 0.0129
# 227808/300000 [=====================>........] - ETA: 1s - loss: 0.0128
# 231200/300000 [======================>.......] - ETA: 1s - loss: 0.0128
# 234624/300000 [======================>.......] - ETA: 0s - loss: 0.0128
# 237984/300000 [======================>.......] - ETA: 0s - loss: 0.0128
# 241344/300000 [=======================>......] - ETA: 0s - loss: 0.0128
# 244736/300000 [=======================>......] - ETA: 0s - loss: 0.0127
# 248128/300000 [=======================>......] - ETA: 0s - loss: 0.0127
# 251584/300000 [========================>.....] - ETA: 0s - loss: 0.0127
# 255008/300000 [========================>.....] - ETA: 0s - loss: 0.0127
# 258400/300000 [========================>.....] - ETA: 0s - loss: 0.0127
# 261728/300000 [=========================>....] - ETA: 0s - loss: 0.0127
# 265152/300000 [=========================>....] - ETA: 0s - loss: 0.0126
# 268576/300000 [=========================>....] - ETA: 0s - loss: 0.0126
# 271968/300000 [==========================>...] - ETA: 0s - loss: 0.0126
# 275424/300000 [==========================>...] - ETA: 0s - loss: 0.0126
# 278880/300000 [==========================>...] - ETA: 0s - loss: 0.0126
# 282304/300000 [===========================>..] - ETA: 0s - loss: 0.0126
# 285696/300000 [===========================>..] - ETA: 0s - loss: 0.0126
# 289024/300000 [===========================>..] - ETA: 0s - loss: 0.0126
# 292384/300000 [============================>.] - ETA: 0s - loss: 0.0126
# 295776/300000 [============================>.] - ETA: 0s - loss: 0.0125
# 299136/300000 [============================>.] - ETA: 0s - loss: 0.0125
# 300000/300000 [==============================] - 4s - loss: 0.0125
# Epoch 2/5
#     32/300000 [..............................] - ETA: 108s - loss: 0.0088
#   3232/300000 [..............................] - ETA: 5s - loss: 0.0114
#   6464/300000 [..............................] - ETA: 5s - loss: 0.0114
#   9696/300000 [..............................] - ETA: 4s - loss: 0.0114
#  12960/300000 [>.............................] - ETA: 4s - loss: 0.0113
#  16320/300000 [>.............................] - ETA: 4s - loss: 0.0114
#  19680/300000 [>.............................] - ETA: 4s - loss: 0.0115
#  23104/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  26464/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  29760/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  32992/300000 [==>...........................] - ETA: 4s - loss: 0.0115
#  36352/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  39488/300000 [==>...........................] - ETA: 4s - loss: 0.0115
#  42752/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  45984/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  49344/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  52768/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  56096/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  59360/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  62592/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  65408/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  68256/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  71392/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  74624/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  78016/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  81312/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  84576/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  87840/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  91040/300000 [========>.....................] - ETA: 3s - loss: 0.0116
#  94208/300000 [========>.....................] - ETA: 3s - loss: 0.0116
#  97408/300000 [========>.....................] - ETA: 3s - loss: 0.0116
# 100800/300000 [=========>....................] - ETA: 3s - loss: 0.0116
# 104128/300000 [=========>....................] - ETA: 3s - loss: 0.0116
# 107360/300000 [=========>....................] - ETA: 2s - loss: 0.0116
# 110176/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 113408/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 116640/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 119456/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 122720/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 125952/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 129120/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 132096/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 135040/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 138240/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 141568/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 144928/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 148160/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 151264/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 154400/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 157568/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 160768/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 163968/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 167392/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 170816/300000 [================>.............] - ETA: 2s - loss: 0.0116
# 174208/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 177472/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 180640/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 183872/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 186880/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 190048/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 193408/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 196768/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 200192/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 203584/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 207040/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 210464/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 213824/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 217248/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 220704/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 224128/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 227584/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 231008/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 234464/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 237888/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 241344/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 244768/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 248224/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 251648/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 255072/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 258496/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 261920/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 265376/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 268832/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 272288/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 275744/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 279136/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 282560/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 285920/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 289344/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 292736/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 296096/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 299520/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# Epoch 3/5
#     32/300000 [..............................] - ETA: 98s - loss: 0.0116
#   3360/300000 [..............................] - ETA: 5s - loss: 0.0112
#   6752/300000 [..............................] - ETA: 4s - loss: 0.0115
#  10208/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  13632/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  17024/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  20384/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  23808/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  27232/300000 [=>............................] - ETA: 4s - loss: 0.0115
#  30624/300000 [==>...........................] - ETA: 4s - loss: 0.0114
#  34080/300000 [==>...........................] - ETA: 4s - loss: 0.0115
#  37536/300000 [==>...........................] - ETA: 3s - loss: 0.0115
#  40928/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  44320/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  47712/300000 [===>..........................] - ETA: 3s - loss: 0.0114
#  51136/300000 [====>.........................] - ETA: 3s - loss: 0.0114
#  54560/300000 [====>.........................] - ETA: 3s - loss: 0.0114
#  57984/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  61344/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  64768/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  68160/300000 [=====>........................] - ETA: 3s - loss: 0.0114
#  71520/300000 [======>.......................] - ETA: 3s - loss: 0.0114
#  74944/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  78400/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  81856/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  85184/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  88608/300000 [=======>......................] - ETA: 3s - loss: 0.0115
#  92064/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  95264/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  98656/300000 [========>.....................] - ETA: 2s - loss: 0.0115
# 102016/300000 [=========>....................] - ETA: 2s - loss: 0.0115
# 105440/300000 [=========>....................] - ETA: 2s - loss: 0.0116
# 108832/300000 [=========>....................] - ETA: 2s - loss: 0.0115
# 112224/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 115552/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 118976/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 122432/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 125856/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 129152/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 132544/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 135808/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 139232/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 142624/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 146016/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 149408/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 152800/300000 [==============>...............] - ETA: 2s - loss: 0.0115
# 156192/300000 [==============>...............] - ETA: 2s - loss: 0.0115
# 159584/300000 [==============>...............] - ETA: 2s - loss: 0.0115
# 162944/300000 [===============>..............] - ETA: 2s - loss: 0.0115
# 166304/300000 [===============>..............] - ETA: 1s - loss: 0.0115
# 169664/300000 [===============>..............] - ETA: 1s - loss: 0.0115
# 173088/300000 [================>.............] - ETA: 1s - loss: 0.0115
# 176512/300000 [================>.............] - ETA: 1s - loss: 0.0115
# 179968/300000 [================>.............] - ETA: 1s - loss: 0.0115
# 183424/300000 [=================>............] - ETA: 1s - loss: 0.0115
# 186688/300000 [=================>............] - ETA: 1s - loss: 0.0115
# 189952/300000 [=================>............] - ETA: 1s - loss: 0.0115
# 193344/300000 [==================>...........] - ETA: 1s - loss: 0.0115
# 196736/300000 [==================>...........] - ETA: 1s - loss: 0.0115
# 200096/300000 [===================>..........] - ETA: 1s - loss: 0.0115
# 203424/300000 [===================>..........] - ETA: 1s - loss: 0.0115
# 206816/300000 [===================>..........] - ETA: 1s - loss: 0.0115
# 210240/300000 [====================>.........] - ETA: 1s - loss: 0.0115
# 213664/300000 [====================>.........] - ETA: 1s - loss: 0.0115
# 216992/300000 [====================>.........] - ETA: 1s - loss: 0.0115
# 220320/300000 [=====================>........] - ETA: 1s - loss: 0.0115
# 223616/300000 [=====================>........] - ETA: 1s - loss: 0.0115
# 227040/300000 [=====================>........] - ETA: 1s - loss: 0.0115
# 230432/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 233792/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 237184/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 240512/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 243872/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 247200/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 250528/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 253888/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 257280/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 260704/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 264064/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 267424/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 270784/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 274208/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 277536/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 280960/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 284448/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 287904/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 291328/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 294720/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 298144/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# Epoch 4/5
#     32/300000 [..............................] - ETA: 88s - loss: 0.0117
#   3392/300000 [..............................] - ETA: 5s - loss: 0.0117
#   6816/300000 [..............................] - ETA: 4s - loss: 0.0114
#  10240/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  13664/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  17056/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  20416/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  23840/300000 [=>............................] - ETA: 4s - loss: 0.0117
#  27232/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  30656/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  34080/300000 [==>...........................] - ETA: 3s - loss: 0.0115
#  37504/300000 [==>...........................] - ETA: 3s - loss: 0.0116
#  40928/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  44256/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  47584/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  50816/300000 [====>.........................] - ETA: 3s - loss: 0.0116
#  54240/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  57632/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  61088/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  64512/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  67872/300000 [=====>........................] - ETA: 3s - loss: 0.0116
#  71104/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  74304/300000 [======>.......................] - ETA: 3s - loss: 0.0115
#  77664/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  81152/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  84576/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  87968/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  91392/300000 [========>.....................] - ETA: 3s - loss: 0.0116
#  94848/300000 [========>.....................] - ETA: 3s - loss: 0.0115
#  98272/300000 [========>.....................] - ETA: 3s - loss: 0.0116
# 101600/300000 [=========>....................] - ETA: 2s - loss: 0.0115
# 104992/300000 [=========>....................] - ETA: 2s - loss: 0.0115
# 108416/300000 [=========>....................] - ETA: 2s - loss: 0.0115
# 111648/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 115040/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 118432/300000 [==========>...................] - ETA: 2s - loss: 0.0115
# 121792/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 125152/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 128576/300000 [===========>..................] - ETA: 2s - loss: 0.0115
# 131968/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 135264/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 138688/300000 [============>.................] - ETA: 2s - loss: 0.0115
# 142144/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 145568/300000 [=============>................] - ETA: 2s - loss: 0.0115
# 148960/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 152448/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 155840/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 159264/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 162720/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 166176/300000 [===============>..............] - ETA: 1s - loss: 0.0116
# 169600/300000 [===============>..............] - ETA: 1s - loss: 0.0116
# 173056/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 176416/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 179840/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 183264/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 186720/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 190144/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 193600/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 196992/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 200416/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 203808/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 207264/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 210688/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 214016/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 217408/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 220864/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 224256/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 227648/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 231072/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 234528/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 237920/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 241216/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 244608/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 248032/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 251328/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 254752/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 258208/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 261664/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 264960/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 268384/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 271808/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 275232/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 278496/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 281888/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 285216/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 288608/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 292000/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 295392/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 298752/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# Epoch 5/5
#     32/300000 [..............................] - ETA: 100s - loss: 0.0098
#   3360/300000 [..............................] - ETA: 5s - loss: 0.0120
#   6816/300000 [..............................] - ETA: 4s - loss: 0.0118
#  10112/300000 [>.............................] - ETA: 4s - loss: 0.0116
#  13504/300000 [>.............................] - ETA: 4s - loss: 0.0117
#  16928/300000 [>.............................] - ETA: 4s - loss: 0.0117
#  20128/300000 [=>............................] - ETA: 4s - loss: 0.0117
#  23520/300000 [=>............................] - ETA: 4s - loss: 0.0117
#  26880/300000 [=>............................] - ETA: 4s - loss: 0.0116
#  30336/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  33632/300000 [==>...........................] - ETA: 4s - loss: 0.0116
#  37056/300000 [==>...........................] - ETA: 3s - loss: 0.0116
#  40448/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  43744/300000 [===>..........................] - ETA: 3s - loss: 0.0115
#  47168/300000 [===>..........................] - ETA: 3s - loss: 0.0116
#  50528/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  53984/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  57408/300000 [====>.........................] - ETA: 3s - loss: 0.0115
#  60832/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  64224/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  67648/300000 [=====>........................] - ETA: 3s - loss: 0.0115
#  71072/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  74496/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  77952/300000 [======>.......................] - ETA: 3s - loss: 0.0116
#  81376/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  84832/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  88256/300000 [=======>......................] - ETA: 3s - loss: 0.0116
#  91680/300000 [========>.....................] - ETA: 3s - loss: 0.0117
#  95072/300000 [========>.....................] - ETA: 3s - loss: 0.0117
#  98464/300000 [========>.....................] - ETA: 3s - loss: 0.0116
# 101728/300000 [=========>....................] - ETA: 2s - loss: 0.0117
# 104992/300000 [=========>....................] - ETA: 2s - loss: 0.0117
# 108256/300000 [=========>....................] - ETA: 2s - loss: 0.0117
# 111456/300000 [==========>...................] - ETA: 2s - loss: 0.0117
# 114720/300000 [==========>...................] - ETA: 2s - loss: 0.0117
# 117664/300000 [==========>...................] - ETA: 2s - loss: 0.0116
# 121056/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 124480/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 127872/300000 [===========>..................] - ETA: 2s - loss: 0.0116
# 131296/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 134752/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 138176/300000 [============>.................] - ETA: 2s - loss: 0.0116
# 141568/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 144992/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 148448/300000 [=============>................] - ETA: 2s - loss: 0.0116
# 151744/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 155168/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 158592/300000 [==============>...............] - ETA: 2s - loss: 0.0116
# 162016/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 165408/300000 [===============>..............] - ETA: 2s - loss: 0.0116
# 168864/300000 [===============>..............] - ETA: 1s - loss: 0.0116
# 172256/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 175712/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 179136/300000 [================>.............] - ETA: 1s - loss: 0.0116
# 182560/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 185984/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 189408/300000 [=================>............] - ETA: 1s - loss: 0.0116
# 192672/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 196000/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 199296/300000 [==================>...........] - ETA: 1s - loss: 0.0116
# 202592/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 205696/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 208992/300000 [===================>..........] - ETA: 1s - loss: 0.0116
# 212224/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 215520/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 218880/300000 [====================>.........] - ETA: 1s - loss: 0.0116
# 222304/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 225760/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 229184/300000 [=====================>........] - ETA: 1s - loss: 0.0116
# 232608/300000 [======================>.......] - ETA: 1s - loss: 0.0116
# 236000/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 239264/300000 [======================>.......] - ETA: 0s - loss: 0.0116
# 242592/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 245952/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 249216/300000 [=======================>......] - ETA: 0s - loss: 0.0116
# 252160/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 255392/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 258464/300000 [========================>.....] - ETA: 0s - loss: 0.0116
# 261760/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 264992/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 268416/300000 [=========================>....] - ETA: 0s - loss: 0.0116
# 271808/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 275232/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 278592/300000 [==========================>...] - ETA: 0s - loss: 0.0116
# 282016/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 285408/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 288768/300000 [===========================>..] - ETA: 0s - loss: 0.0116
# 292096/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 295552/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 298976/300000 [============================>.] - ETA: 0s - loss: 0.0116
# 300000/300000 [==============================] - 4s - loss: 0.0116
# RMSE test  =
#  0.101665360392
# RMSE train =
# 0.106886269261
# Recall, RMSE of the univariate linear model =  0.107693264644
# Using TensorFlow backend.

# %%
print tfModel1.summary() #, '\n'
#print tfModel.get_config(), '\n'
#print tfModel1.get_weights(), '\n'
## an example of a good set of weights
#tfModel1.set_weights(
#    [np.array([[ 0.01057134]], dtype=np.float32), np.array([-0.83383954], dtype=np.float32),
#     np.array([[ 0.51123452]], dtype=np.float32), np.array([-0.03770353], dtype=np.float32)] 
#)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.close()
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
ax0.set_ylabel(r"1/$p_T$", fontsize=18)
ax0.set_xlabel(r"$\Delta \phi_{12}$ values", fontsize=18)
ax0.set_ylim(0, 1.)
ax0.set_xlim(0, 500)

# our old friend - linear model
x_vals = np.array(ax0.get_xlim())
y_vals = linearModel.stages[1].intercept + linearModel.stages[1].coefficients * x_vals
linCurve = plt.plot(x_vals, y_vals, linewidth=3.0, c='#0cbfd0', linestyle='--')

# our new friend, neural network, that should shadow our old friend
x_range  = np.arange(0,500,1)
y_result = tfModel1.predict(x_range)
nnCurve = plt.scatter(x_range, y_result, s=14**2, c='#d6ebf2', edgecolors='#8cbfd0', alpha=1.)

#plt.scatter(x_test, y_test, s=1, c='#d6ebf2', edgecolors='#8cbfd0', alpha=1.)

plt.legend( [nnCurve],
            ["Single node NN"],
            scatterpoints = 1,
            ncol = 1,
            fontsize = 15
          )

plt.title("Comparing the linear model with \"linearized\" neural network", fontsize=20)
plt.show()

# %%
tf1ROC = rocMetric(np.array( zip(1./y_test, tfTest1, [1]*len(tfTest1)), dtype = stdTypes ), binning)

fig, ax0 = prepareRocPlot({"Linear model": (linearROC,'grey'),
                           "NN model #1":(tf1ROC,'blue'),
                           },{4:'brown'},legPos="lower right")

ax0.set_ylim(0., 1.)
ax0.set_xlim(0., 0.3)
ax0.set_xscale('linear')
plt.show()

# %% [markdown]
# It looks like the simplest neural network is doing a right thing and a deviation from linearity, that now can be accommodated in four coefficients (2 biases + 2 scales) of the NN, results in a little bit of performance gain in ROC metric. But like the original linear model, it doesn't do a good job (well, any job) above pT ~ 8 GeV:

# %%
# zoom in to the low-pT part of the spectrum
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
plt.hist( 1./y_test, bins=100, range=[0, 15], alpha=0.5 )
plt.hist(   tfTest1, bins=100, range=[0, 15], alpha=0.5 )
ax0.set_xlim(0., 10)
ax0.set_ylabel(r"# events", fontsize=18)
ax0.set_xlabel(r"pT (GeV)", fontsize=18)
plt.yscale('log')
plt.title("Target (blue) and predicted (green) pT spectra", fontsize=20)
plt.show()

# %% [markdown]
# Let's now add more predictors (standardized for later regularization) and compare against multivariate linear model. One thing to keep in mind is that NN treats all of the inputs as continuous variables.

# %%
# Looks like Keras doesn't provide an independent workflow/option to standardize the predictors, so I resort to SKLearn
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df1[predictors])

df1_std = pd.DataFrame( scaler.transform(df1[predictors]) )
df1_std.columns = predictors

df1_std['ptTrueInv']      = df1['ptTrueInv'].values
df1_std['invSqrtPtTrue']  = df1['invSqrtPtTrue'].values
df1_std['invSqrt2PtTrue'] = df1['invSqrt2PtTrue'].values

(trainSet_std, testSet_std) = (df1_std[1:trainRows], df1_std[trainRows:nRows])

# reweight to 1/pT^3 spectrum
trainSet_std = trainSet_std.sample(n=300000, replace=True, weights=trainSet_std['ptTrueInv']**2, random_state=123)
testSet_std  = testSet_std .sample(n=100000, replace=True, weights=testSet_std ['ptTrueInv']**2, random_state=123)

# %%
tfModel2 = Sequential()

# no hidden layers yet
tfModel2.add(Dense(1, input_dim=len(predictors), activation='sigmoid', kernel_initializer='zero', bias_initializer='zero'))
tfModel2.add(Dense(1, kernel_initializer='zero', bias_initializer='zero'))

x_train = trainSet_std[predictors].values
x_test  = testSet_std [predictors].values

tfModel2.compile(loss='mse', optimizer='rmsprop')

tfModel2.fit(x_train, y_train, epochs=5)

tfTest2 = 1./tfModel2.predict(x_test).ravel()

print "RMSE test  = ", math.sqrt( mean_squared_error(y_test, 1./tfTest2) )
print "RMSE train = ", math.sqrt( mean_squared_error(y_train, tfModel2.predict(x_train).ravel()) )
print "Recall, RMSE of the multivariate linear model = ", multiLinearRMSE
# Out:
# Epoch 1/5
#     32/300000 [..............................] - ETA: 248s - loss: 0.0954
#   3104/300000 [..............................] - ETA: 7s - loss: 0.0708
#   6304/300000 [..............................] - ETA: 5s - loss: 0.0467
#   9408/300000 [..............................] - ETA: 5s - loss: 0.0362
#  12672/300000 [>.............................] - ETA: 5s - loss: 0.0305
#  15904/300000 [>.............................] - ETA: 4s - loss: 0.0269
#  19168/300000 [>.............................] - ETA: 4s - loss: 0.0242
#  22432/300000 [=>............................] - ETA: 4s - loss: 0.0223
#  25696/300000 [=>............................] - ETA: 4s - loss: 0.0206
#  28928/300000 [=>............................] - ETA: 4s - loss: 0.0193
#  32192/300000 [==>...........................] - ETA: 4s - loss: 0.0181
#  35424/300000 [==>...........................] - ETA: 4s - loss: 0.0172
#  38688/300000 [==>...........................] - ETA: 4s - loss: 0.0164
#  41920/300000 [===>..........................] - ETA: 4s - loss: 0.0156
#  45184/300000 [===>..........................] - ETA: 4s - loss: 0.0150
#  48416/300000 [===>..........................] - ETA: 4s - loss: 0.0145
#  51648/300000 [====>.........................] - ETA: 3s - loss: 0.0140
#  54880/300000 [====>.........................] - ETA: 3s - loss: 0.0136
#  58112/300000 [====>.........................] - ETA: 3s - loss: 0.0132
#  61344/300000 [=====>........................] - ETA: 3s - loss: 0.0128
#  64576/300000 [=====>........................] - ETA: 3s - loss: 0.0125
#  67840/300000 [=====>........................] - ETA: 3s - loss: 0.0122
#  71104/300000 [======>.......................] - ETA: 3s - loss: 0.0119
#  74336/300000 [======>.......................] - ETA: 3s - loss: 0.0117
#  77568/300000 [======>.......................] - ETA: 3s - loss: 0.0114
#  80832/300000 [=======>......................] - ETA: 3s - loss: 0.0112
#  84032/300000 [=======>......................] - ETA: 3s - loss: 0.0110
#  87328/300000 [=======>......................] - ETA: 3s - loss: 0.0107
#  90592/300000 [========>.....................] - ETA: 3s - loss: 0.0106
#  93824/300000 [========>.....................] - ETA: 3s - loss: 0.0104
#  96960/300000 [========>.....................] - ETA: 3s - loss: 0.0102
# 100192/300000 [=========>....................] - ETA: 3s - loss: 0.0101
# 103424/300000 [=========>....................] - ETA: 3s - loss: 0.0100
# 106656/300000 [=========>....................] - ETA: 3s - loss: 0.0098
# 109888/300000 [=========>....................] - ETA: 3s - loss: 0.0097
# 113088/300000 [==========>...................] - ETA: 2s - loss: 0.0096
# 116288/300000 [==========>...................] - ETA: 2s - loss: 0.0095
# 119488/300000 [==========>...................] - ETA: 2s - loss: 0.0094
# 122688/300000 [===========>..................] - ETA: 2s - loss: 0.0093
# 125952/300000 [===========>..................] - ETA: 2s - loss: 0.0092
# 129184/300000 [===========>..................] - ETA: 2s - loss: 0.0091
# 132320/300000 [============>.................] - ETA: 2s - loss: 0.0090
# 135552/300000 [============>.................] - ETA: 2s - loss: 0.0089
# 138816/300000 [============>.................] - ETA: 2s - loss: 0.0088
# 141952/300000 [=============>................] - ETA: 2s - loss: 0.0088
# 145248/300000 [=============>................] - ETA: 2s - loss: 0.0087
# 148256/300000 [=============>................] - ETA: 2s - loss: 0.0086
# 151520/300000 [==============>...............] - ETA: 2s - loss: 0.0086
# 154784/300000 [==============>...............] - ETA: 2s - loss: 0.0085
# 158048/300000 [==============>...............] - ETA: 2s - loss: 0.0084
# 161312/300000 [===============>..............] - ETA: 2s - loss: 0.0084
# 164576/300000 [===============>..............] - ETA: 2s - loss: 0.0083
# 167840/300000 [===============>..............] - ETA: 2s - loss: 0.0083
# 171104/300000 [================>.............] - ETA: 2s - loss: 0.0082
# 174336/300000 [================>.............] - ETA: 1s - loss: 0.0081
# 177600/300000 [================>.............] - ETA: 1s - loss: 0.0081
# 180832/300000 [=================>............] - ETA: 1s - loss: 0.0080
# 184096/300000 [=================>............] - ETA: 1s - loss: 0.0080
# 187328/300000 [=================>............] - ETA: 1s - loss: 0.0080
# 190496/300000 [==================>...........] - ETA: 1s - loss: 0.0079
# 193728/300000 [==================>...........] - ETA: 1s - loss: 0.0079
# 196928/300000 [==================>...........] - ETA: 1s - loss: 0.0078
# 200160/300000 [===================>..........] - ETA: 1s - loss: 0.0078
# 203296/300000 [===================>..........] - ETA: 1s - loss: 0.0078
# 206528/300000 [===================>..........] - ETA: 1s - loss: 0.0077
# 209824/300000 [===================>..........] - ETA: 1s - loss: 0.0077
# 213024/300000 [====================>.........] - ETA: 1s - loss: 0.0077
# 216320/300000 [====================>.........] - ETA: 1s - loss: 0.0076
# 219552/300000 [====================>.........] - ETA: 1s - loss: 0.0076
# 222848/300000 [=====================>........] - ETA: 1s - loss: 0.0076
# 226080/300000 [=====================>........] - ETA: 1s - loss: 0.0075
# 229344/300000 [=====================>........] - ETA: 1s - loss: 0.0075
# 232544/300000 [======================>.......] - ETA: 1s - loss: 0.0075
# 235584/300000 [======================>.......] - ETA: 1s - loss: 0.0074
# 238784/300000 [======================>.......] - ETA: 0s - loss: 0.0074
# 242048/300000 [=======================>......] - ETA: 0s - loss: 0.0074
# 245056/300000 [=======================>......] - ETA: 0s - loss: 0.0074
# 248256/300000 [=======================>......] - ETA: 0s - loss: 0.0073
# 251456/300000 [========================>.....] - ETA: 0s - loss: 0.0073
# 254720/300000 [========================>.....] - ETA: 0s - loss: 0.0073
# 257632/300000 [========================>.....] - ETA: 0s - loss: 0.0073
# 260832/300000 [=========================>....] - ETA: 0s - loss: 0.0072
# 264064/300000 [=========================>....] - ETA: 0s - loss: 0.0072
# 267264/300000 [=========================>....] - ETA: 0s - loss: 0.0072
# 270528/300000 [==========================>...] - ETA: 0s - loss: 0.0072
# 273792/300000 [==========================>...] - ETA: 0s - loss: 0.0072
# 277056/300000 [==========================>...] - ETA: 0s - loss: 0.0071
# 280288/300000 [===========================>..] - ETA: 0s - loss: 0.0071
# 283520/300000 [===========================>..] - ETA: 0s - loss: 0.0071
# 286752/300000 [===========================>..] - ETA: 0s - loss: 0.0071
# 290016/300000 [============================>.] - ETA: 0s - loss: 0.0071
# 293184/300000 [============================>.] - ETA: 0s - loss: 0.0070
# 296416/300000 [============================>.] - ETA: 0s - loss: 0.0070
# 299680/300000 [============================>.] - ETA: 0s - loss: 0.0070
# 300000/300000 [==============================] - 4s - loss: 0.0070
# Epoch 2/5
#     32/300000 [..............................] - ETA: 92s - loss: 0.0059
#   3136/300000 [..............................] - ETA: 5s - loss: 0.0054
#   6304/300000 [..............................] - ETA: 5s - loss: 0.0053
#   9472/300000 [..............................] - ETA: 4s - loss: 0.0054
#  12672/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  15904/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  19168/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  22432/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  25696/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  28832/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  32096/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  35360/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  38624/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  41664/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  44928/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  48128/300000 [===>..........................] - ETA: 3s - loss: 0.0053
#  51392/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  54496/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  57696/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  60896/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  63968/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  67168/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  70432/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  73664/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  76832/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  80096/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  83328/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  86528/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  89792/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  93056/300000 [========>.....................] - ETA: 3s - loss: 0.0054
#  96288/300000 [========>.....................] - ETA: 3s - loss: 0.0054
#  99552/300000 [========>.....................] - ETA: 3s - loss: 0.0054
# 102816/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 106016/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 109312/300000 [=========>....................] - ETA: 2s - loss: 0.0054
# 112448/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 115744/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 118880/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 122144/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 125376/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 128608/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 131872/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 135136/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 138368/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 141600/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 144800/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 148096/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 151328/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 154592/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 157792/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 161056/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 164256/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 167520/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 170720/300000 [================>.............] - ETA: 2s - loss: 0.0054
# 173984/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 177184/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 180480/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 183712/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 187008/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 190240/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 193504/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 196736/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 199936/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 203168/300000 [===================>..........] - ETA: 1s - loss: 0.0054
# 206432/300000 [===================>..........] - ETA: 1s - loss: 0.0054
# 209664/300000 [===================>..........] - ETA: 1s - loss: 0.0054
# 212928/300000 [====================>.........] - ETA: 1s - loss: 0.0054
# 216192/300000 [====================>.........] - ETA: 1s - loss: 0.0054
# 219392/300000 [====================>.........] - ETA: 1s - loss: 0.0054
# 222624/300000 [=====================>........] - ETA: 1s - loss: 0.0054
# 225856/300000 [=====================>........] - ETA: 1s - loss: 0.0054
# 229056/300000 [=====================>........] - ETA: 1s - loss: 0.0054
# 232288/300000 [======================>.......] - ETA: 1s - loss: 0.0054
# 235552/300000 [======================>.......] - ETA: 1s - loss: 0.0054
# 238816/300000 [======================>.......] - ETA: 0s - loss: 0.0054
# 242080/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 245344/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 248576/300000 [=======================>......] - ETA: 0s - loss: 0.0054
# 251776/300000 [========================>.....] - ETA: 0s - loss: 0.0054
# 255008/300000 [========================>.....] - ETA: 0s - loss: 0.0054
# 258272/300000 [========================>.....] - ETA: 0s - loss: 0.0054
# 261536/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 264704/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 267904/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 271072/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 274368/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 277600/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 280864/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 284096/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 287200/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 290432/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 293664/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 296832/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 300000/300000 [==============================] - 4s - loss: 0.0054
# Epoch 3/5
#     32/300000 [..............................] - ETA: 99s - loss: 0.0055
#   3168/300000 [..............................] - ETA: 5s - loss: 0.0056
#   6368/300000 [..............................] - ETA: 5s - loss: 0.0053
#   9600/300000 [..............................] - ETA: 4s - loss: 0.0053
#  12864/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  16128/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  19360/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  22624/300000 [=>............................] - ETA: 4s - loss: 0.0055
#  25856/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  29088/300000 [=>............................] - ETA: 4s - loss: 0.0055
#  32320/300000 [==>...........................] - ETA: 4s - loss: 0.0055
#  35552/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  38784/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  42080/300000 [===>..........................] - ETA: 4s - loss: 0.0054
#  45344/300000 [===>..........................] - ETA: 4s - loss: 0.0054
#  48608/300000 [===>..........................] - ETA: 3s - loss: 0.0054
#  51840/300000 [====>.........................] - ETA: 3s - loss: 0.0054
#  55104/300000 [====>.........................] - ETA: 3s - loss: 0.0054
#  58400/300000 [====>.........................] - ETA: 3s - loss: 0.0054
#  61664/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  64864/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  68160/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  71328/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  74592/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  77760/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  81024/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  84160/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  87328/300000 [=======>......................] - ETA: 3s - loss: 0.0054
#  90464/300000 [========>.....................] - ETA: 3s - loss: 0.0054
#  93728/300000 [========>.....................] - ETA: 3s - loss: 0.0054
#  96960/300000 [========>.....................] - ETA: 3s - loss: 0.0054
# 100160/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 103392/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 106656/300000 [=========>....................] - ETA: 3s - loss: 0.0054
# 109856/300000 [=========>....................] - ETA: 2s - loss: 0.0054
# 113152/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 116352/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 119616/300000 [==========>...................] - ETA: 2s - loss: 0.0054
# 122816/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 126080/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 129344/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 132608/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 135840/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 139136/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 142368/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 145600/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 148864/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 152128/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 155360/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 158592/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 161792/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 164992/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 168096/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 171360/300000 [================>.............] - ETA: 2s - loss: 0.0054
# 174528/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 177792/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 180992/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 184064/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 187296/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 190592/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 193792/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 197088/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 200288/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 203520/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206720/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209984/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 213216/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 216512/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 219712/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222976/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 226208/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 229440/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 232672/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 235712/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 238912/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 242144/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 245408/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 248608/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 251776/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 254944/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 258208/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 261440/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 264672/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 267936/300000 [=========================>....] - ETA: 0s - loss: 0.0054
# 271200/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 274432/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 277440/300000 [==========================>...] - ETA: 0s - loss: 0.0054
# 280736/300000 [===========================>..] - ETA: 0s - loss: 0.0054
# 283968/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 287232/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 290496/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 293728/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 297024/300000 [============================>.] - ETA: 0s - loss: 0.0054
# 300000/300000 [==============================] - 4s - loss: 0.0054
# Epoch 4/5
#     32/300000 [..............................] - ETA: 79s - loss: 0.0083
#   3168/300000 [..............................] - ETA: 5s - loss: 0.0054
#   6272/300000 [..............................] - ETA: 5s - loss: 0.0053
#   9504/300000 [..............................] - ETA: 4s - loss: 0.0054
#  12736/300000 [>.............................] - ETA: 4s - loss: 0.0053
#  15936/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  19168/300000 [>.............................] - ETA: 4s - loss: 0.0054
#  22464/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  25696/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  28960/300000 [=>............................] - ETA: 4s - loss: 0.0054
#  32192/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  35456/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  38624/300000 [==>...........................] - ETA: 4s - loss: 0.0054
#  41760/300000 [===>..........................] - ETA: 4s - loss: 0.0054
#  45024/300000 [===>..........................] - ETA: 4s - loss: 0.0054
#  48288/300000 [===>..........................] - ETA: 3s - loss: 0.0054
#  51552/300000 [====>.........................] - ETA: 3s - loss: 0.0054
#  54528/300000 [====>.........................] - ETA: 3s - loss: 0.0054
#  57696/300000 [====>.........................] - ETA: 3s - loss: 0.0054
#  60960/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  64192/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  67456/300000 [=====>........................] - ETA: 3s - loss: 0.0054
#  70720/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  73984/300000 [======>.......................] - ETA: 3s - loss: 0.0054
#  77280/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  80544/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  83808/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  87040/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  90272/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  93472/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  96704/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  99968/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 103264/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 106368/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 109600/300000 [=========>....................] - ETA: 2s - loss: 0.0053
# 112832/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 116096/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 119296/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 122528/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 125760/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 129024/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 132288/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 135552/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 138752/300000 [============>.................] - ETA: 2s - loss: 0.0054
# 141984/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 145184/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 148480/300000 [=============>................] - ETA: 2s - loss: 0.0054
# 151712/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 155008/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 158176/300000 [==============>...............] - ETA: 2s - loss: 0.0054
# 161408/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 164640/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 167904/300000 [===============>..............] - ETA: 2s - loss: 0.0054
# 171136/300000 [================>.............] - ETA: 2s - loss: 0.0054
# 174400/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 177600/300000 [================>.............] - ETA: 1s - loss: 0.0054
# 180864/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 184096/300000 [=================>............] - ETA: 1s - loss: 0.0054
# 187200/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190400/300000 [==================>...........] - ETA: 1s - loss: 0.0054
# 193632/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196832/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199968/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 203136/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206400/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209632/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212928/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 216192/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 219424/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222656/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225856/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 229088/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 232256/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 235296/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 238528/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 241728/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 244960/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 248192/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 251456/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 254720/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257984/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 261216/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 264416/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 267616/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 270848/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 274080/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 277344/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 280576/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 283776/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 287008/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 290112/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 293312/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 296544/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 299808/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# Epoch 5/5
#     32/300000 [..............................] - ETA: 93s - loss: 0.0067
#   3232/300000 [..............................] - ETA: 5s - loss: 0.0050
#   6304/300000 [..............................] - ETA: 5s - loss: 0.0052
#   9536/300000 [..............................] - ETA: 4s - loss: 0.0052
#  12736/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  15968/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  19264/300000 [>.............................] - ETA: 4s - loss: 0.0052
#  22496/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  25760/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  28864/300000 [=>............................] - ETA: 4s - loss: 0.0052
#  32000/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  35264/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  38560/300000 [==>...........................] - ETA: 4s - loss: 0.0053
#  41824/300000 [===>..........................] - ETA: 4s - loss: 0.0052
#  45024/300000 [===>..........................] - ETA: 4s - loss: 0.0053
#  48320/300000 [===>..........................] - ETA: 3s - loss: 0.0053
#  51552/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  54848/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  58080/300000 [====>.........................] - ETA: 3s - loss: 0.0053
#  61312/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  64512/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  67744/300000 [=====>........................] - ETA: 3s - loss: 0.0053
#  70976/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  74208/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  77440/300000 [======>.......................] - ETA: 3s - loss: 0.0053
#  80704/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  83904/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  87168/300000 [=======>......................] - ETA: 3s - loss: 0.0053
#  90432/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  93664/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  96608/300000 [========>.....................] - ETA: 3s - loss: 0.0053
#  99840/300000 [========>.....................] - ETA: 3s - loss: 0.0053
# 103040/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 106336/300000 [=========>....................] - ETA: 3s - loss: 0.0053
# 109568/300000 [=========>....................] - ETA: 2s - loss: 0.0053
# 112864/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 116064/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 119296/300000 [==========>...................] - ETA: 2s - loss: 0.0053
# 122528/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 125792/300000 [===========>..................] - ETA: 2s - loss: 0.0053
# 128768/300000 [===========>..................] - ETA: 2s - loss: 0.0054
# 132000/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 135200/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 138464/300000 [============>.................] - ETA: 2s - loss: 0.0053
# 141696/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 144928/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 148128/300000 [=============>................] - ETA: 2s - loss: 0.0053
# 151360/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 154592/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 157824/300000 [==============>...............] - ETA: 2s - loss: 0.0053
# 160864/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 164160/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 167392/300000 [===============>..............] - ETA: 2s - loss: 0.0053
# 170688/300000 [================>.............] - ETA: 2s - loss: 0.0053
# 173952/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 177184/300000 [================>.............] - ETA: 1s - loss: 0.0053
# 180416/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 183616/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 186848/300000 [=================>............] - ETA: 1s - loss: 0.0053
# 190080/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 193312/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 196576/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 199744/300000 [==================>...........] - ETA: 1s - loss: 0.0053
# 203040/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 206272/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 209536/300000 [===================>..........] - ETA: 1s - loss: 0.0053
# 212800/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 216000/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 219232/300000 [====================>.........] - ETA: 1s - loss: 0.0053
# 222496/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 225664/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 228864/300000 [=====================>........] - ETA: 1s - loss: 0.0053
# 232032/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 235264/300000 [======================>.......] - ETA: 1s - loss: 0.0053
# 238560/300000 [======================>.......] - ETA: 0s - loss: 0.0053
# 241792/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 245024/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 248256/300000 [=======================>......] - ETA: 0s - loss: 0.0053
# 251520/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 254784/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 257984/300000 [========================>.....] - ETA: 0s - loss: 0.0053
# 261248/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 264512/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 267648/300000 [=========================>....] - ETA: 0s - loss: 0.0053
# 270880/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 274112/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 277376/300000 [==========================>...] - ETA: 0s - loss: 0.0053
# 280576/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 283840/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 287072/300000 [===========================>..] - ETA: 0s - loss: 0.0053
# 290336/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 293568/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 296800/300000 [============================>.] - ETA: 0s - loss: 0.0053
# 300000/300000 [==============================] - 4s - loss: 0.0053
# RMSE test  =
#  0.0686492778964
# RMSE train =
# 0.0727839285973
# Recall, RMSE of the multivariate linear model =  0.0745507835679

# %% [markdown]
# This "linearized" multivariate Neural Network model extends to predicting pT up to 12 GeV and does a slightly better job at around the 1.5 GeV cut-off:

# %%
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
plt.hist( 1./y_test, bins=100, range=[0, 15], alpha=0.5 )
plt.hist(   tfTest2, bins=100, range=[0, 15], alpha=0.5 )
ax0.set_xlim(0., 15)
ax0.set_ylabel(r"# events", fontsize=18)
ax0.set_xlabel(r"pT (GeV)", fontsize=18)
plt.yscale('log')
plt.title("Target (blue) and predicted (green) pT spectra", fontsize=20)
plt.show()

# %% [markdown]
# Let's now play with NN configuration. At this moment I gave up on any interpretability of the NN for good. I also use the best RF ROC metric as a reference. Several models with 0, 1, and 2 hidden layers are shown below. Just a bit of weight-decay regularization is applied to the weights and biases. It makes training more stable and improves reproducibility for different random seeds. Also, now the target is **1/pT^0.25** to add more weight of the intermediate pT region (~10-20) GeV in RSS and improve ROC performance there.

# %%
from keras import regularizers
from keras import initializers
#from keras.layers import Dropout

# I automatize NN model construction as I am going to create lots of models
def buildNN(nInputs, config) :
    model = Sequential()
    # input layer
    model.add(Dense(config[0],
                    input_dim = nInputs,
                    activation = 'relu',
                    kernel_initializer = initializers.random_uniform(seed=1), #random_normal(stddev=0.01, seed=1), #'uniform',
                    kernel_regularizer = regularizers.l2(0.00001),
                    bias_initializer = initializers.random_uniform(seed=1), #'uniform',
                    bias_regularizer = regularizers.l2(0.000001),
                    #activity_regularizer=regularizers.l1(0.01)
                    )
              )
    #model.add(Dropout(0.2))

    # hidden layers
    for nUnits in config[1:-1] :
        model.add(Dense(nUnits,
                        activation = 'relu',
                        kernel_initializer = initializers.random_uniform(seed=1), #'uniform',
                        kernel_regularizer = regularizers.l2(0.00001),
                        bias_initializer = initializers.random_uniform(seed=1), #'uniform',
                        bias_regularizer = regularizers.l2(0.000001),
                        #activity_regularizer=regularizers.l1(0.01)
                        )
                  )
        #model.add(Dropout(0.2))

    # aggregating output layer (no activation needed)
    model.add(Dense(config[-1],
                    kernel_initializer = initializers.random_uniform(seed=1), #'uniform',
                    kernel_regularizer = regularizers.l2(0.00001),
                    bias_initializer = initializers.random_uniform(seed=1), #'uniform',
                    bias_regularizer = regularizers.l2(0.000001),
                    #activity_regularizer=regularizers.l1(0.01)
                    )
              )
    
    model.compile(loss = 'mean_squared_error', optimizer = 'rmsprop')
    return model

# change target to 1/pT^0.25
y_train = trainSet['invSqrt2PtTrue'].values.ravel()
y_test  = testSet ['invSqrt2PtTrue'].values.ravel()

# train several NN configurations

tfModel3 = buildNN(nInputs=len(predictors), config=(10,1))
tfModel3.fit(x_train, y_train, validation_split=0.2, epochs=5)
tfTest3 = 1./tfModel3.predict(x_test)**4
print "RMSE 10+1: ", math.sqrt( tfModel3.evaluate(x_test, y_test, verbose = 0) )

tfModel4 = buildNN(nInputs=len(predictors), config=(10,5,1))
tfModel4.fit(x_train, y_train, validation_split=0.2, epochs=5)
tfTest4 = 1./tfModel4.predict(x_test)**4
print "RMSE 10+5+1: ", math.sqrt( tfModel4.evaluate(x_test, y_test, verbose = 0) )

tfModel5 = buildNN(nInputs=len(predictors), config=(100,50,1))
tfModel5.fit(x_train, y_train, validation_split=0.2, epochs=10)
tfTest5 = 1./tfModel5.predict(x_test)**4
print "RMSE 100+50+1: ", math.sqrt( tfModel5.evaluate(x_test, y_test, verbose = 0) )

tfModel6 = buildNN(nInputs=len(predictors), config=(100,50,50,1))
tfModel6.fit(x_train, y_train, validation_split=0.2, epochs=10)
tfTest6 = 1./tfModel6.predict(x_test)**4
print "RMSE 100+50+50+1: ", math.sqrt( tfModel6.evaluate(x_test, y_test, verbose = 0) )

tfModel7 = buildNN(nInputs=len(predictors), config=(100,50,50,50,1))
tfModel7.fit(x_train, y_train, validation_split=0.2, epochs=15)
tfTest7 = 1./tfModel7.predict(x_test)**4
print "RMSE 100+50+50+50+1: ", math.sqrt( tfModel7.evaluate(x_test, y_test, verbose = 0) )
# Out:
# Train on 240000 samples, validate on 60000 samples
# Epoch 1/5
#     32/240000 [..............................] - ETA: 299s - loss: 0.5745
#   2880/240000 [..............................] - ETA: 7s - loss: 0.2062
#   5760/240000 [..............................] - ETA: 5s - loss: 0.1335
#   8768/240000 [>.............................] - ETA: 5s - loss: 0.0937
#  11648/240000 [>.............................] - ETA: 4s - loss: 0.0715
#  14624/240000 [>.............................] - ETA: 4s - loss: 0.0577
#  17600/240000 [=>............................] - ETA: 4s - loss: 0.0484
#  20608/240000 [=>............................] - ETA: 4s - loss: 0.0417
#  23552/240000 [=>............................] - ETA: 4s - loss: 0.0368
#  26464/240000 [==>...........................] - ETA: 3s - loss: 0.0331
#  29408/240000 [==>...........................] - ETA: 3s - loss: 0.0300
#  32384/240000 [===>..........................] - ETA: 3s - loss: 0.0274
#  35296/240000 [===>..........................] - ETA: 3s - loss: 0.0253
#  38304/240000 [===>..........................] - ETA: 3s - loss: 0.0235
#  41280/240000 [====>.........................] - ETA: 3s - loss: 0.0219
#  44288/240000 [====>.........................] - ETA: 3s - loss: 0.0205
#  47104/240000 [====>.........................] - ETA: 3s - loss: 0.0194
#  50080/240000 [=====>........................] - ETA: 3s - loss: 0.0183
#  52864/240000 [=====>........................] - ETA: 3s - loss: 0.0174
#  55712/240000 [=====>........................] - ETA: 3s - loss: 0.0166
#  58528/240000 [======>.......................] - ETA: 3s - loss: 0.0159
#  61376/240000 [======>.......................] - ETA: 3s - loss: 0.0152
#  64224/240000 [=======>......................] - ETA: 3s - loss: 0.0146
#  67040/240000 [=======>......................] - ETA: 3s - loss: 0.0141
#  69792/240000 [=======>......................] - ETA: 3s - loss: 0.0136
#  72704/240000 [========>.....................] - ETA: 2s - loss: 0.0131
#  75584/240000 [========>.....................] - ETA: 2s - loss: 0.0126
#  78496/240000 [========>.....................] - ETA: 2s - loss: 0.0122
#  81440/240000 [=========>....................] - ETA: 2s - loss: 0.0118
#  84352/240000 [=========>....................] - ETA: 2s - loss: 0.0115
#  87296/240000 [=========>....................] - ETA: 2s - loss: 0.0111
#  90240/240000 [==========>...................] - ETA: 2s - loss: 0.0108
#  93216/240000 [==========>...................] - ETA: 2s - loss: 0.0105
#  96032/240000 [===========>..................] - ETA: 2s - loss: 0.0102
#  98976/240000 [===========>..................] - ETA: 2s - loss: 0.0100
# 101888/240000 [===========>..................] - ETA: 2s - loss: 0.0097
# 104832/240000 [============>.................] - ETA: 2s - loss: 0.0095
# 107776/240000 [============>.................] - ETA: 2s - loss: 0.0093
# 110688/240000 [============>.................] - ETA: 2s - loss: 0.0091
# 113504/240000 [=============>................] - ETA: 2s - loss: 0.0089
# 116480/240000 [=============>................] - ETA: 2s - loss: 0.0087
# 119296/240000 [=============>................] - ETA: 2s - loss: 0.0085
# 122208/240000 [==============>...............] - ETA: 2s - loss: 0.0083
# 125152/240000 [==============>...............] - ETA: 2s - loss: 0.0082
# 128064/240000 [===============>..............] - ETA: 1s - loss: 0.0080
# 130944/240000 [===============>..............] - ETA: 1s - loss: 0.0079
# 133760/240000 [===============>..............] - ETA: 1s - loss: 0.0077
# 136672/240000 [================>.............] - ETA: 1s - loss: 0.0076
# 139648/240000 [================>.............] - ETA: 1s - loss: 0.0075
# 142592/240000 [================>.............] - ETA: 1s - loss: 0.0073
# 145568/240000 [=================>............] - ETA: 1s - loss: 0.0072
# 148512/240000 [=================>............] - ETA: 1s - loss: 0.0071
# 151520/240000 [=================>............] - ETA: 1s - loss: 0.0070
# 154464/240000 [==================>...........] - ETA: 1s - loss: 0.0069
# 157472/240000 [==================>...........] - ETA: 1s - loss: 0.0068
# 160416/240000 [===================>..........] - ETA: 1s - loss: 0.0067
# 163392/240000 [===================>..........] - ETA: 1s - loss: 0.0066
# 166336/240000 [===================>..........] - ETA: 1s - loss: 0.0065
# 169312/240000 [====================>.........] - ETA: 1s - loss: 0.0064
# 172224/240000 [====================>.........] - ETA: 1s - loss: 0.0063
# 175168/240000 [====================>.........] - ETA: 1s - loss: 0.0062
# 178112/240000 [=====================>........] - ETA: 1s - loss: 0.0061
# 181120/240000 [=====================>........] - ETA: 1s - loss: 0.0061
# 184032/240000 [======================>.......] - ETA: 0s - loss: 0.0060
# 186976/240000 [======================>.......] - ETA: 0s - loss: 0.0059
# 189824/240000 [======================>.......] - ETA: 0s - loss: 0.0058
# 192864/240000 [=======================>......] - ETA: 0s - loss: 0.0058
# 195808/240000 [=======================>......] - ETA: 0s - loss: 0.0057
# 198752/240000 [=======================>......] - ETA: 0s - loss: 0.0056
# 201728/240000 [========================>.....] - ETA: 0s - loss: 0.0056
# 204704/240000 [========================>.....] - ETA: 0s - loss: 0.0055
# 207680/240000 [========================>.....] - ETA: 0s - loss: 0.0054
# 210688/240000 [=========================>....] - ETA: 0s - loss: 0.0054
# 213600/240000 [=========================>....] - ETA: 0s - loss: 0.0053
# 216544/240000 [==========================>...] - ETA: 0s - loss: 0.0053
# 219456/240000 [==========================>...] - ETA: 0s - loss: 0.0052
# 222432/240000 [==========================>...] - ETA: 0s - loss: 0.0052
# 225408/240000 [===========================>..] - ETA: 0s - loss: 0.0051
# 228288/240000 [===========================>..] - ETA: 0s - loss: 0.0051
# 231232/240000 [===========================>..] - ETA: 0s - loss: 0.0050
# 234208/240000 [============================>.] - ETA: 0s - loss: 0.0050
# 237184/240000 [============================>.] - ETA: 0s - loss: 0.0049
# 240000/240000 [==============================] - 4s - loss: 0.0049 - val_loss: 0.0012
# Epoch 2/5
#     32/240000 [..............................] - ETA: 64s - loss: 7.9243e-04
#   2816/240000 [..............................] - ETA: 4s - loss: 0.0014
#   5728/240000 [..............................] - ETA: 4s - loss: 0.0013
#   8672/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  11648/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  14592/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  17536/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  20512/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  23488/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  26400/240000 [==>...........................] - ETA: 3s - loss: 0.0012
#  29344/240000 [==>...........................] - ETA: 3s - loss: 0.0012
#  32288/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  35136/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  38112/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  41088/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  44032/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  47008/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  49952/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  52896/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  55808/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  58784/240000 [======>.......................] - ETA: 3s - loss: 0.0012
#  61728/240000 [======>.......................] - ETA: 3s - loss: 0.0012
#  64672/240000 [=======>......................] - ETA: 3s - loss: 0.0012
#  67616/240000 [=======>......................] - ETA: 2s - loss: 0.0012
#  70560/240000 [=======>......................] - ETA: 2s - loss: 0.0012
#  73504/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  76448/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  79392/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  82368/240000 [=========>....................] - ETA: 2s - loss: 0.0012
#  85280/240000 [=========>....................] - ETA: 2s - loss: 0.0012
#  88256/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  91200/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  94176/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  97120/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 100096/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 103008/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 105984/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 108928/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 111904/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 114816/240000 [=============>................] - ETA: 2s - loss: 0.0012
# 117760/240000 [=============>................] - ETA: 2s - loss: 0.0012
# 120704/240000 [==============>...............] - ETA: 2s - loss: 0.0012
# 123680/240000 [==============>...............] - ETA: 1s - loss: 0.0012
# 126528/240000 [==============>...............] - ETA: 1s - loss: 0.0012
# 129536/240000 [===============>..............] - ETA: 1s - loss: 0.0012
# 132512/240000 [===============>..............] - ETA: 1s - loss: 0.0012
# 135488/240000 [===============>..............] - ETA: 1s - loss: 0.0012
# 138432/240000 [================>.............] - ETA: 1s - loss: 0.0012
# 141408/240000 [================>.............] - ETA: 1s - loss: 0.0012
# 144384/240000 [=================>............] - ETA: 1s - loss: 0.0012
# 147328/240000 [=================>............] - ETA: 1s - loss: 0.0012
# 150304/240000 [=================>............] - ETA: 1s - loss: 0.0012
# 153280/240000 [==================>...........] - ETA: 1s - loss: 0.0012
# 156160/240000 [==================>...........] - ETA: 1s - loss: 0.0012
# 159104/240000 [==================>...........] - ETA: 1s - loss: 0.0012
# 162080/240000 [===================>..........] - ETA: 1s - loss: 0.0012
# 165024/240000 [===================>..........] - ETA: 1s - loss: 0.0012
# 167968/240000 [===================>..........] - ETA: 1s - loss: 0.0012
# 170816/240000 [====================>.........] - ETA: 1s - loss: 0.0012
# 173760/240000 [====================>.........] - ETA: 1s - loss: 0.0012
# 176704/240000 [=====================>........] - ETA: 1s - loss: 0.0012
# 179680/240000 [=====================>........] - ETA: 1s - loss: 0.0012
# 182624/240000 [=====================>........] - ETA: 0s - loss: 0.0012
# 185600/240000 [======================>.......] - ETA: 0s - loss: 0.0012
# 188544/240000 [======================>.......] - ETA: 0s - loss: 0.0012
# 191520/240000 [======================>.......] - ETA: 0s - loss: 0.0012
# 194464/240000 [=======================>......] - ETA: 0s - loss: 0.0012
# 197440/240000 [=======================>......] - ETA: 0s - loss: 0.0012
# 200288/240000 [========================>.....] - ETA: 0s - loss: 0.0012
# 203232/240000 [========================>.....] - ETA: 0s - loss: 0.0012
# 206112/240000 [========================>.....] - ETA: 0s - loss: 0.0012
# 209056/240000 [=========================>....] - ETA: 0s - loss: 0.0012
# 211968/240000 [=========================>....] - ETA: 0s - loss: 0.0012
# 214944/240000 [=========================>....] - ETA: 0s - loss: 0.0012
# 217856/240000 [==========================>...] - ETA: 0s - loss: 0.0012
# 220832/240000 [==========================>...] - ETA: 0s - loss: 0.0012
# 223776/240000 [==========================>...] - ETA: 0s - loss: 0.0012
# 226752/240000 [===========================>..] - ETA: 0s - loss: 0.0012
# 229632/240000 [===========================>..] - ETA: 0s - loss: 0.0012
# 232608/240000 [============================>.] - ETA: 0s - loss: 0.0012
# 235520/240000 [============================>.] - ETA: 0s - loss: 0.0012
# 238272/240000 [============================>.] - ETA: 0s - loss: 0.0012
# 240000/240000 [==============================] - 4s - loss: 0.0012 - val_loss: 0.0013
# Epoch 3/5
#     32/240000 [..............................] - ETA: 59s - loss: 0.0018
#   2880/240000 [..............................] - ETA: 4s - loss: 0.0012
#   5600/240000 [..............................] - ETA: 4s - loss: 0.0012
#   8544/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  11488/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  14464/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  17408/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  20384/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  23296/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  26272/240000 [==>...........................] - ETA: 3s - loss: 0.0012
#  29216/240000 [==>...........................] - ETA: 3s - loss: 0.0012
#  32224/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  35136/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  38144/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  41088/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  44064/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  46944/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  49920/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  52864/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  55840/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  58688/240000 [======>.......................] - ETA: 3s - loss: 0.0012
#  61664/240000 [======>.......................] - ETA: 3s - loss: 0.0012
#  64352/240000 [=======>......................] - ETA: 3s - loss: 0.0012
#  67328/240000 [=======>......................] - ETA: 2s - loss: 0.0012
#  70048/240000 [=======>......................] - ETA: 2s - loss: 0.0012
#  72960/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  75936/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  78880/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  81824/240000 [=========>....................] - ETA: 2s - loss: 0.0012
#  84800/240000 [=========>....................] - ETA: 2s - loss: 0.0012
#  87744/240000 [=========>....................] - ETA: 2s - loss: 0.0012
#  90592/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  93536/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  96448/240000 [===========>..................] - ETA: 2s - loss: 0.0012
#  99424/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 102432/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 105376/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 108384/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 111328/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 114304/240000 [=============>................] - ETA: 2s - loss: 0.0012
# 117216/240000 [=============>................] - ETA: 2s - loss: 0.0012
# 120000/240000 [==============>...............] - ETA: 2s - loss: 0.0012
# 122688/240000 [==============>...............] - ETA: 2s - loss: 0.0012
# 125504/240000 [==============>...............] - ETA: 1s - loss: 0.0012
# 128448/240000 [===============>..............] - ETA: 1s - loss: 0.0012
# 131424/240000 [===============>..............] - ETA: 1s - loss: 0.0012
# 134304/240000 [===============>..............] - ETA: 1s - loss: 0.0012
# 137280/240000 [================>.............] - ETA: 1s - loss: 0.0012
# 140224/240000 [================>.............] - ETA: 1s - loss: 0.0012
# 143200/240000 [================>.............] - ETA: 1s - loss: 0.0012
# 146176/240000 [=================>............] - ETA: 1s - loss: 0.0012
# 149152/240000 [=================>............] - ETA: 1s - loss: 0.0012
# 152032/240000 [==================>...........] - ETA: 1s - loss: 0.0012
# 155008/240000 [==================>...........] - ETA: 1s - loss: 0.0012
# 157952/240000 [==================>...........] - ETA: 1s - loss: 0.0012
# 160896/240000 [===================>..........] - ETA: 1s - loss: 0.0012
# 163840/240000 [===================>..........] - ETA: 1s - loss: 0.0012
# 166816/240000 [===================>..........] - ETA: 1s - loss: 0.0012
# 169728/240000 [====================>.........] - ETA: 1s - loss: 0.0012
# 172704/240000 [====================>.........] - ETA: 1s - loss: 0.0012
# 175584/240000 [====================>.........] - ETA: 1s - loss: 0.0012
# 178432/240000 [=====================>........] - ETA: 1s - loss: 0.0012
# 181408/240000 [=====================>........] - ETA: 1s - loss: 0.0012
# 184352/240000 [======================>.......] - ETA: 0s - loss: 0.0012
# 187296/240000 [======================>.......] - ETA: 0s - loss: 0.0012
# 190208/240000 [======================>.......] - ETA: 0s - loss: 0.0012
# 193216/240000 [=======================>......] - ETA: 0s - loss: 0.0012
# 196128/240000 [=======================>......] - ETA: 0s - loss: 0.0012
# 199104/240000 [=======================>......] - ETA: 0s - loss: 0.0012
# 201984/240000 [========================>.....] - ETA: 0s - loss: 0.0012
# 204896/240000 [========================>.....] - ETA: 0s - loss: 0.0012
# 207840/240000 [========================>.....] - ETA: 0s - loss: 0.0012
# 210784/240000 [=========================>....] - ETA: 0s - loss: 0.0012
# 213760/240000 [=========================>....] - ETA: 0s - loss: 0.0012
# 216768/240000 [==========================>...] - ETA: 0s - loss: 0.0012
# 219744/240000 [==========================>...] - ETA: 0s - loss: 0.0012
# 222720/240000 [==========================>...] - ETA: 0s - loss: 0.0012
# 225664/240000 [===========================>..] - ETA: 0s - loss: 0.0012
# 228640/240000 [===========================>..] - ETA: 0s - loss: 0.0012
# 231584/240000 [===========================>..] - ETA: 0s - loss: 0.0012
# 234464/240000 [============================>.] - ETA: 0s - loss: 0.0012
# 237408/240000 [============================>.] - ETA: 0s - loss: 0.0012
# 240000/240000 [==============================] - 4s - loss: 0.0012 - val_loss: 0.0014
# Epoch 4/5
#     32/240000 [..............................] - ETA: 54s - loss: 0.0012
#   2880/240000 [..............................] - ETA: 4s - loss: 0.0011
#   5728/240000 [..............................] - ETA: 4s - loss: 0.0011
#   8640/240000 [>.............................] - ETA: 4s - loss: 0.0011
#  11392/240000 [>.............................] - ETA: 4s - loss: 0.0011
#  14336/240000 [>.............................] - ETA: 4s - loss: 0.0011
#  17248/240000 [=>............................] - ETA: 3s - loss: 0.0011
#  20192/240000 [=>............................] - ETA: 3s - loss: 0.0011
#  23104/240000 [=>............................] - ETA: 3s - loss: 0.0012
#  26048/240000 [==>...........................] - ETA: 3s - loss: 0.0011
#  28608/240000 [==>...........................] - ETA: 3s - loss: 0.0011
#  31424/240000 [==>...........................] - ETA: 3s - loss: 0.0011
#  34272/240000 [===>..........................] - ETA: 3s - loss: 0.0011
#  37056/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  39904/240000 [===>..........................] - ETA: 3s - loss: 0.0012
#  42784/240000 [====>.........................] - ETA: 3s - loss: 0.0011
#  45632/240000 [====>.........................] - ETA: 3s - loss: 0.0012
#  48608/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  51584/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  54592/240000 [=====>........................] - ETA: 3s - loss: 0.0012
#  57504/240000 [======>.......................] - ETA: 3s - loss: 0.0011
#  60480/240000 [======>.......................] - ETA: 3s - loss: 0.0011
#  63424/240000 [======>.......................] - ETA: 3s - loss: 0.0012
#  66400/240000 [=======>......................] - ETA: 3s - loss: 0.0011
#  69376/240000 [=======>......................] - ETA: 2s - loss: 0.0012
#  72352/240000 [========>.....................] - ETA: 2s - loss: 0.0012
#  75328/240000 [========>.....................] - ETA: 2s - loss: 0.0011
#  78272/240000 [========>.....................] - ETA: 2s - loss: 0.0011
#  81216/240000 [=========>....................] - ETA: 2s - loss: 0.0011
#  84096/240000 [=========>....................] - ETA: 2s - loss: 0.0011
#  86944/240000 [=========>....................] - ETA: 2s - loss: 0.0012
#  89856/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  92800/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  95744/240000 [==========>...................] - ETA: 2s - loss: 0.0012
#  98624/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 101504/240000 [===========>..................] - ETA: 2s - loss: 0.0012
# 104448/240000 [============>.................] - ETA: 2s - loss: 0.0012
# 107424/240000 [============>.................] - ETA: 2s - loss: 0.0011
# 110368/240000 [============>.................] - ETA: 2s - loss: 0.0011
# 113344/240000 [=============>................] - ETA: 2s - loss: 0.0011
# 116288/240000 [=============>................] - ETA: 2s - loss: 0.0011
# 119264/240000 [=============>................] - ETA: 2s - loss: 0.0011
# 122176/240000 [==============>...............] - ETA: 2s - loss: 0.0011
# 125120/240000 [==============>...............] - ETA: 1s - loss: 0.0011
# 128064/240000 [===============>..............] - ETA: 1s - loss: 0.0011
# 131072/240000 [===============>..............] - ETA: 1s - loss: 0.0011
# 133920/240000 [===============>..............] - ETA: 1s - loss: 0.0011
# 136896/240000 [================>.............] - ETA: 1s - loss: 0.0011
# 139808/240000 [================>.............] - ETA: 1s - loss: 0.0011
# 142784/240000 [================>.............] - ETA: 1s - loss: 0.0011
# 145760/240000 [=================>............] - ETA: 1s - loss: 0.0011
# 148704/240000 [=================>............] - ETA: 1s - loss: 0.0011
# 151648/240000 [=================>............] - ETA: 1s - loss: 0.0011
# 154624/240000 [==================>...........] - ETA: 1s - loss: 0.0011
# 157568/240000 [==================>...........] - ETA: 1s - loss: 0.0011
# 160544/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 163520/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 166464/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 169280/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 172192/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 175104/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 178048/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 181024/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 183968/240000 [=====================>........] - ETA: 0s - loss: 0.0011
# 186944/240000 [======================>.......] - ETA: 0s - loss: 0.0011
# 189888/240000 [======================>.......] - ETA: 0s - loss: 0.0011
# 192800/240000 [=======================>......] - ETA: 0s - loss: 0.0011
# 195712/240000 [=======================>......] - ETA: 0s - loss: 0.0011
# 198656/240000 [=======================>......] - ETA: 0s - loss: 0.0011
# 201536/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 204480/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 207424/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 210400/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 213312/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 216224/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 219168/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 222080/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 225024/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 227840/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 230784/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 233728/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 236672/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 239616/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 240000/240000 [==============================] - 4s - loss: 0.0011 - val_loss: 0.0014
# Epoch 5/5
#     32/240000 [..............................] - ETA: 50s - loss: 0.0021
#   2816/240000 [..............................] - ETA: 4s - loss: 0.0012
#   5760/240000 [..............................] - ETA: 4s - loss: 0.0012
#   8512/240000 [>.............................] - ETA: 4s - loss: 0.0011
#  11392/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  14336/240000 [>.............................] - ETA: 4s - loss: 0.0012
#  17248/240000 [=>............................] - ETA: 3s - loss: 0.0011
#  20128/240000 [=>............................] - ETA: 3s - loss: 0.0011
#  23072/240000 [=>............................] - ETA: 3s - loss: 0.0011
#  26048/240000 [==>...........................] - ETA: 3s - loss: 0.0011
#  28992/240000 [==>...........................] - ETA: 3s - loss: 0.0011
#  31872/240000 [==>...........................] - ETA: 3s - loss: 0.0011
#  34848/240000 [===>..........................] - ETA: 3s - loss: 0.0011
#  37696/240000 [===>..........................] - ETA: 3s - loss: 0.0011
#  40512/240000 [====>.........................] - ETA: 3s - loss: 0.0011
#  43424/240000 [====>.........................] - ETA: 3s - loss: 0.0011
#  46400/240000 [====>.........................] - ETA: 3s - loss: 0.0011
#  49312/240000 [=====>........................] - ETA: 3s - loss: 0.0011
#  52288/240000 [=====>........................] - ETA: 3s - loss: 0.0011
#  55232/240000 [=====>........................] - ETA: 3s - loss: 0.0011
#  58208/240000 [======>.......................] - ETA: 3s - loss: 0.0011
#  61120/240000 [======>.......................] - ETA: 3s - loss: 0.0011
#  64128/240000 [=======>......................] - ETA: 3s - loss: 0.0011
#  67072/240000 [=======>......................] - ETA: 2s - loss: 0.0011
#  70080/240000 [=======>......................] - ETA: 2s - loss: 0.0011
#  72992/240000 [========>.....................] - ETA: 2s - loss: 0.0011
#  75936/240000 [========>.....................] - ETA: 2s - loss: 0.0011
#  78880/240000 [========>.....................] - ETA: 2s - loss: 0.0011
#  81792/240000 [=========>....................] - ETA: 2s - loss: 0.0011
#  84768/240000 [=========>....................] - ETA: 2s - loss: 0.0011
#  87744/240000 [=========>....................] - ETA: 2s - loss: 0.0011
#  90624/240000 [==========>...................] - ETA: 2s - loss: 0.0011
#  93504/240000 [==========>...................] - ETA: 2s - loss: 0.0011
#  96448/240000 [===========>..................] - ETA: 2s - loss: 0.0011
#  99456/240000 [===========>..................] - ETA: 2s - loss: 0.0011
# 102400/240000 [===========>..................] - ETA: 2s - loss: 0.0011
# 105344/240000 [============>.................] - ETA: 2s - loss: 0.0011
# 108288/240000 [============>.................] - ETA: 2s - loss: 0.0011
# 111264/240000 [============>.................] - ETA: 2s - loss: 0.0011
# 114208/240000 [=============>................] - ETA: 2s - loss: 0.0011
# 117184/240000 [=============>................] - ETA: 2s - loss: 0.0011
# 120096/240000 [==============>...............] - ETA: 2s - loss: 0.0011
# 122976/240000 [==============>...............] - ETA: 2s - loss: 0.0011
# 125920/240000 [==============>...............] - ETA: 1s - loss: 0.0011
# 128928/240000 [===============>..............] - ETA: 1s - loss: 0.0011
# 131872/240000 [===============>..............] - ETA: 1s - loss: 0.0011
# 134880/240000 [===============>..............] - ETA: 1s - loss: 0.0011
# 137792/240000 [================>.............] - ETA: 1s - loss: 0.0011
# 140768/240000 [================>.............] - ETA: 1s - loss: 0.0011
# 143712/240000 [================>.............] - ETA: 1s - loss: 0.0011
# 146688/240000 [=================>............] - ETA: 1s - loss: 0.0011
# 149632/240000 [=================>............] - ETA: 1s - loss: 0.0011
# 152608/240000 [==================>...........] - ETA: 1s - loss: 0.0011
# 155552/240000 [==================>...........] - ETA: 1s - loss: 0.0011
# 158528/240000 [==================>...........] - ETA: 1s - loss: 0.0011
# 161440/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 164448/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 167392/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 170336/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 173280/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 176256/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 179200/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 182176/240000 [=====================>........] - ETA: 0s - loss: 0.0011
# 185088/240000 [======================>.......] - ETA: 0s - loss: 0.0011
# 188064/240000 [======================>.......] - ETA: 0s - loss: 0.0011
# 191008/240000 [======================>.......] - ETA: 0s - loss: 0.0011
# 193952/240000 [=======================>......] - ETA: 0s - loss: 0.0011
# 196928/240000 [=======================>......] - ETA: 0s - loss: 0.0011
# 199904/240000 [=======================>......] - ETA: 0s - loss: 0.0011
# 202880/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 205824/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 208800/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 211712/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 214656/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 217472/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 220320/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 223200/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 226048/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 228960/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 231936/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 234784/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 237632/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 240000/240000 [==============================] - 4s - loss: 0.0011 - val_loss: 0.0015
# RMSE 10+1:
#  0.0348127572413
# Train on 240000 samples, validate on 60000 samples
# Epoch 1/5
#     32/240000 [..............................] - ETA: 414s - loss: 0.5783
#   2496/240000 [..............................] - ETA: 10s - loss: 0.3190
#   5120/240000 [..............................] - ETA: 7s - loss: 0.1913
#   7840/240000 [..............................] - ETA: 6s - loss: 0.1337
#  10528/240000 [>.............................] - ETA: 5s - loss: 0.1010
#  13280/240000 [>.............................] - ETA: 5s - loss: 0.0807
#  16032/240000 [=>............................] - ETA: 4s - loss: 0.0674
#  18784/240000 [=>............................] - ETA: 4s - loss: 0.0580
#  21472/240000 [=>............................] - ETA: 4s - loss: 0.0511
#  24160/240000 [==>...........................] - ETA: 4s - loss: 0.0457
#  26784/240000 [==>...........................] - ETA: 4s - loss: 0.0415
#  29440/240000 [==>...........................] - ETA: 4s - loss: 0.0381
#  32128/240000 [===>..........................] - ETA: 4s - loss: 0.0351
#  34848/240000 [===>..........................] - ETA: 4s - loss: 0.0326
#  37536/240000 [===>..........................] - ETA: 4s - loss: 0.0305
#  40256/240000 [====>.........................] - ETA: 4s - loss: 0.0286
#  42944/240000 [====>.........................] - ETA: 3s - loss: 0.0270
#  45632/240000 [====>.........................] - ETA: 3s - loss: 0.0256
#  48288/240000 [=====>........................] - ETA: 3s - loss: 0.0243
#  51008/240000 [=====>........................] - ETA: 3s - loss: 0.0231
#  53760/240000 [=====>........................] - ETA: 3s - loss: 0.0221
#  56352/240000 [======>.......................] - ETA: 3s - loss: 0.0212
#  59072/240000 [======>.......................] - ETA: 3s - loss: 0.0204
#  61728/240000 [======>.......................] - ETA: 3s - loss: 0.0196
#  64352/240000 [=======>......................] - ETA: 3s - loss: 0.0189
#  67008/240000 [=======>......................] - ETA: 3s - loss: 0.0183
#  69760/240000 [=======>......................] - ETA: 3s - loss: 0.0177
#  72544/240000 [========>.....................] - ETA: 3s - loss: 0.0171
#  75264/240000 [========>.....................] - ETA: 3s - loss: 0.0166
#  78048/240000 [========>.....................] - ETA: 3s - loss: 0.0161
#  80768/240000 [=========>....................] - ETA: 3s - loss: 0.0156
#  83488/240000 [=========>....................] - ETA: 3s - loss: 0.0152
#  86144/240000 [=========>....................] - ETA: 2s - loss: 0.0148
#  88896/240000 [==========>...................] - ETA: 2s - loss: 0.0144
#  91552/240000 [==========>...................] - ETA: 2s - loss: 0.0141
#  94240/240000 [==========>...................] - ETA: 2s - loss: 0.0138
#  96896/240000 [===========>..................] - ETA: 2s - loss: 0.0135
#  99680/240000 [===========>..................] - ETA: 2s - loss: 0.0132
# 102432/240000 [===========>..................] - ETA: 2s - loss: 0.0129
# 105216/240000 [============>.................] - ETA: 2s - loss: 0.0126
# 107936/240000 [============>.................] - ETA: 2s - loss: 0.0123
# 110624/240000 [============>.................] - ETA: 2s - loss: 0.0121
# 113344/240000 [=============>................] - ETA: 2s - loss: 0.0119
# 116064/240000 [=============>................] - ETA: 2s - loss: 0.0117
# 118816/240000 [=============>................] - ETA: 2s - loss: 0.0114
# 121504/240000 [==============>...............] - ETA: 2s - loss: 0.0113
# 124160/240000 [==============>...............] - ETA: 2s - loss: 0.0111
# 126944/240000 [==============>...............] - ETA: 2s - loss: 0.0109
# 129664/240000 [===============>..............] - ETA: 2s - loss: 0.0107
# 132384/240000 [===============>..............] - ETA: 2s - loss: 0.0105
# 135136/240000 [===============>..............] - ETA: 1s - loss: 0.0104
# 137824/240000 [================>.............] - ETA: 1s - loss: 0.0102
# 140512/240000 [================>.............] - ETA: 1s - loss: 0.0101
# 143264/240000 [================>.............] - ETA: 1s - loss: 0.0099
# 146016/240000 [=================>............] - ETA: 1s - loss: 0.0098
# 148768/240000 [=================>............] - ETA: 1s - loss: 0.0096
# 151520/240000 [=================>............] - ETA: 1s - loss: 0.0095
# 154240/240000 [==================>...........] - ETA: 1s - loss: 0.0094
# 156800/240000 [==================>...........] - ETA: 1s - loss: 0.0093
# 159552/240000 [==================>...........] - ETA: 1s - loss: 0.0092
# 162304/240000 [===================>..........] - ETA: 1s - loss: 0.0090
# 165056/240000 [===================>..........] - ETA: 1s - loss: 0.0089
# 167808/240000 [===================>..........] - ETA: 1s - loss: 0.0088
# 170496/240000 [====================>.........] - ETA: 1s - loss: 0.0087
# 173216/240000 [====================>.........] - ETA: 1s - loss: 0.0086
# 175968/240000 [====================>.........] - ETA: 1s - loss: 0.0085
# 178688/240000 [=====================>........] - ETA: 1s - loss: 0.0084
# 181408/240000 [=====================>........] - ETA: 1s - loss: 0.0084
# 184096/240000 [======================>.......] - ETA: 1s - loss: 0.0083
# 186816/240000 [======================>.......] - ETA: 1s - loss: 0.0082
# 189536/240000 [======================>.......] - ETA: 0s - loss: 0.0081
# 192256/240000 [=======================>......] - ETA: 0s - loss: 0.0080
# 194976/240000 [=======================>......] - ETA: 0s - loss: 0.0079
# 197696/240000 [=======================>......] - ETA: 0s - loss: 0.0079
# 200448/240000 [========================>.....] - ETA: 0s - loss: 0.0078
# 203136/240000 [========================>.....] - ETA: 0s - loss: 0.0077
# 205920/240000 [========================>.....] - ETA: 0s - loss: 0.0076
# 208608/240000 [=========================>....] - ETA: 0s - loss: 0.0076
# 211328/240000 [=========================>....] - ETA: 0s - loss: 0.0075
# 214048/240000 [=========================>....] - ETA: 0s - loss: 0.0075
# 216800/240000 [==========================>...] - ETA: 0s - loss: 0.0074
# 219456/240000 [==========================>...] - ETA: 0s - loss: 0.0073
# 222208/240000 [==========================>...] - ETA: 0s - loss: 0.0073
# 224960/240000 [===========================>..] - ETA: 0s - loss: 0.0072
# 227744/240000 [===========================>..] - ETA: 0s - loss: 0.0071
# 230464/240000 [===========================>..] - ETA: 0s - loss: 0.0071
# 233184/240000 [============================>.] - ETA: 0s - loss: 0.0070
# 235904/240000 [============================>.] - ETA: 0s - loss: 0.0070
# 238624/240000 [============================>.] - ETA: 0s - loss: 0.0069
# 240000/240000 [==============================] - 5s - loss: 0.0069 - val_loss: 0.0024
# Epoch 2/5
#     32/240000 [..............................] - ETA: 68s - loss: 0.0024
#   2624/240000 [..............................] - ETA: 5s - loss: 0.0024
#   5248/240000 [..............................] - ETA: 4s - loss: 0.0024
#   7936/240000 [..............................] - ETA: 4s - loss: 0.0025
#  10688/240000 [>.............................] - ETA: 4s - loss: 0.0024
#  13440/240000 [>.............................] - ETA: 4s - loss: 0.0025
#  16160/240000 [=>............................] - ETA: 4s - loss: 0.0025
#  18944/240000 [=>............................] - ETA: 4s - loss: 0.0025
#  21664/240000 [=>............................] - ETA: 4s - loss: 0.0024
#  24448/240000 [==>...........................] - ETA: 4s - loss: 0.0024
#  27136/240000 [==>...........................] - ETA: 4s - loss: 0.0024
#  29888/240000 [==>...........................] - ETA: 3s - loss: 0.0024
#  32640/240000 [===>..........................] - ETA: 3s - loss: 0.0024
#  35360/240000 [===>..........................] - ETA: 3s - loss: 0.0024
#  38112/240000 [===>..........................] - ETA: 3s - loss: 0.0024
#  40864/240000 [====>.........................] - ETA: 3s - loss: 0.0024
#  43616/240000 [====>.........................] - ETA: 3s - loss: 0.0024
#  46368/240000 [====>.........................] - ETA: 3s - loss: 0.0024
#  49120/240000 [=====>........................] - ETA: 3s - loss: 0.0024
#  51904/240000 [=====>........................] - ETA: 3s - loss: 0.0024
#  54560/240000 [=====>........................] - ETA: 3s - loss: 0.0024
#  57344/240000 [======>.......................] - ETA: 3s - loss: 0.0024
#  60064/240000 [======>.......................] - ETA: 3s - loss: 0.0024
#  62784/240000 [======>.......................] - ETA: 3s - loss: 0.0024
#  65536/240000 [=======>......................] - ETA: 3s - loss: 0.0024
#  68192/240000 [=======>......................] - ETA: 3s - loss: 0.0024
#  70944/240000 [=======>......................] - ETA: 3s - loss: 0.0024
#  73600/240000 [========>.....................] - ETA: 3s - loss: 0.0024
#  76320/240000 [========>.....................] - ETA: 3s - loss: 0.0024
#  79072/240000 [========>.....................] - ETA: 2s - loss: 0.0024
#  81824/240000 [=========>....................] - ETA: 2s - loss: 0.0024
#  84576/240000 [=========>....................] - ETA: 2s - loss: 0.0024
#  87296/240000 [=========>....................] - ETA: 2s - loss: 0.0024
#  90016/240000 [==========>...................] - ETA: 2s - loss: 0.0024
#  92800/240000 [==========>...................] - ETA: 2s - loss: 0.0024
#  95552/240000 [==========>...................] - ETA: 2s - loss: 0.0024
#  98304/240000 [===========>..................] - ETA: 2s - loss: 0.0024
# 100800/240000 [===========>..................] - ETA: 2s - loss: 0.0024
# 103520/240000 [===========>..................] - ETA: 2s - loss: 0.0024
# 106272/240000 [============>.................] - ETA: 2s - loss: 0.0024
# 109024/240000 [============>.................] - ETA: 2s - loss: 0.0024
# 111680/240000 [============>.................] - ETA: 2s - loss: 0.0024
# 114400/240000 [=============>................] - ETA: 2s - loss: 0.0024
# 117152/240000 [=============>................] - ETA: 2s - loss: 0.0024
# 119936/240000 [=============>................] - ETA: 2s - loss: 0.0024
# 122720/240000 [==============>...............] - ETA: 2s - loss: 0.0024
# 125472/240000 [==============>...............] - ETA: 2s - loss: 0.0024
# 128192/240000 [===============>..............] - ETA: 2s - loss: 0.0024
# 130912/240000 [===============>..............] - ETA: 2s - loss: 0.0024
# 133696/240000 [===============>..............] - ETA: 1s - loss: 0.0024
# 136480/240000 [================>.............] - ETA: 1s - loss: 0.0024
# 139264/240000 [================>.............] - ETA: 1s - loss: 0.0024
# 141984/240000 [================>.............] - ETA: 1s - loss: 0.0024
# 144768/240000 [=================>............] - ETA: 1s - loss: 0.0024
# 147520/240000 [=================>............] - ETA: 1s - loss: 0.0024
# 150176/240000 [=================>............] - ETA: 1s - loss: 0.0024
# 152928/240000 [==================>...........] - ETA: 1s - loss: 0.0023
# 155648/240000 [==================>...........] - ETA: 1s - loss: 0.0023
# 158176/240000 [==================>...........] - ETA: 1s - loss: 0.0023
# 160800/240000 [===================>..........] - ETA: 1s - loss: 0.0023
# 163584/240000 [===================>..........] - ETA: 1s - loss: 0.0023
# 166144/240000 [===================>..........] - ETA: 1s - loss: 0.0023
# 168832/240000 [====================>.........] - ETA: 1s - loss: 0.0023
# 171552/240000 [====================>.........] - ETA: 1s - loss: 0.0022
# 174336/240000 [====================>.........] - ETA: 1s - loss: 0.0022
# 177056/240000 [=====================>........] - ETA: 1s - loss: 0.0022
# 179808/240000 [=====================>........] - ETA: 1s - loss: 0.0022
# 182528/240000 [=====================>........] - ETA: 1s - loss: 0.0022
# 185312/240000 [======================>.......] - ETA: 1s - loss: 0.0022
# 188064/240000 [======================>.......] - ETA: 0s - loss: 0.0022
# 190816/240000 [======================>.......] - ETA: 0s - loss: 0.0022
# 193536/240000 [=======================>......] - ETA: 0s - loss: 0.0022
# 196224/240000 [=======================>......] - ETA: 0s - loss: 0.0021
# 198944/240000 [=======================>......] - ETA: 0s - loss: 0.0021
# 201728/240000 [========================>.....] - ETA: 0s - loss: 0.0021
# 204416/240000 [========================>.....] - ETA: 0s - loss: 0.0021
# 207168/240000 [========================>.....] - ETA: 0s - loss: 0.0021
# 209792/240000 [=========================>....] - ETA: 0s - loss: 0.0021
# 212512/240000 [=========================>....] - ETA: 0s - loss: 0.0021
# 215136/240000 [=========================>....] - ETA: 0s - loss: 0.0021
# 217920/240000 [==========================>...] - ETA: 0s - loss: 0.0021
# 220672/240000 [==========================>...] - ETA: 0s - loss: 0.0021
# 223456/240000 [==========================>...] - ETA: 0s - loss: 0.0020
# 226080/240000 [===========================>..] - ETA: 0s - loss: 0.0020
# 228864/240000 [===========================>..] - ETA: 0s - loss: 0.0020
# 231616/240000 [===========================>..] - ETA: 0s - loss: 0.0020
# 234400/240000 [============================>.] - ETA: 0s - loss: 0.0020
# 237088/240000 [============================>.] - ETA: 0s - loss: 0.0020
# 239872/240000 [============================>.] - ETA: 0s - loss: 0.0020
# 240000/240000 [==============================] - 5s - loss: 0.0020 - val_loss: 0.0014
# Epoch 3/5
#     32/240000 [..............................] - ETA: 71s - loss: 0.0011
#   2592/240000 [..............................] - ETA: 5s - loss: 0.0014
#   5248/240000 [..............................] - ETA: 4s - loss: 0.0014
#   8032/240000 [>.............................] - ETA: 4s - loss: 0.0014
#  10720/240000 [>.............................] - ETA: 4s - loss: 0.0014
#  13504/240000 [>.............................] - ETA: 4s - loss: 0.0014
#  16128/240000 [=>............................] - ETA: 4s - loss: 0.0014
#  18880/240000 [=>............................] - ETA: 4s - loss: 0.0014
#  21664/240000 [=>............................] - ETA: 4s - loss: 0.0014
#  24448/240000 [==>...........................] - ETA: 4s - loss: 0.0014
#  27200/240000 [==>...........................] - ETA: 4s - loss: 0.0014
#  29952/240000 [==>...........................] - ETA: 3s - loss: 0.0014
#  32704/240000 [===>..........................] - ETA: 3s - loss: 0.0014
#  35392/240000 [===>..........................] - ETA: 3s - loss: 0.0014
#  38144/240000 [===>..........................] - ETA: 3s - loss: 0.0014
#  40928/240000 [====>.........................] - ETA: 3s - loss: 0.0014
#  43680/240000 [====>.........................] - ETA: 3s - loss: 0.0014
#  46464/240000 [====>.........................] - ETA: 3s - loss: 0.0014
#  49120/240000 [=====>........................] - ETA: 3s - loss: 0.0014
#  51872/240000 [=====>........................] - ETA: 3s - loss: 0.0014
#  54592/240000 [=====>........................] - ETA: 3s - loss: 0.0014
#  57344/240000 [======>.......................] - ETA: 3s - loss: 0.0014
#  60096/240000 [======>.......................] - ETA: 3s - loss: 0.0014
#  62848/240000 [======>.......................] - ETA: 3s - loss: 0.0014
#  65472/240000 [=======>......................] - ETA: 3s - loss: 0.0014
#  68096/240000 [=======>......................] - ETA: 3s - loss: 0.0014
#  70592/240000 [=======>......................] - ETA: 3s - loss: 0.0014
#  73152/240000 [========>.....................] - ETA: 3s - loss: 0.0014
#  75744/240000 [========>.....................] - ETA: 3s - loss: 0.0014
#  78304/240000 [========>.....................] - ETA: 3s - loss: 0.0014
#  81024/240000 [=========>....................] - ETA: 2s - loss: 0.0014
#  83808/240000 [=========>....................] - ETA: 2s - loss: 0.0014
#  86560/240000 [=========>....................] - ETA: 2s - loss: 0.0014
#  89312/240000 [==========>...................] - ETA: 2s - loss: 0.0014
#  92000/240000 [==========>...................] - ETA: 2s - loss: 0.0014
#  94560/240000 [==========>...................] - ETA: 2s - loss: 0.0014
#  97312/240000 [===========>..................] - ETA: 2s - loss: 0.0014
# 100064/240000 [===========>..................] - ETA: 2s - loss: 0.0014
# 102848/240000 [===========>..................] - ETA: 2s - loss: 0.0014
# 105568/240000 [============>.................] - ETA: 2s - loss: 0.0014
# 108352/240000 [============>.................] - ETA: 2s - loss: 0.0014
# 111040/240000 [============>.................] - ETA: 2s - loss: 0.0014
# 113664/240000 [=============>................] - ETA: 2s - loss: 0.0013
# 116320/240000 [=============>................] - ETA: 2s - loss: 0.0013
# 119072/240000 [=============>................] - ETA: 2s - loss: 0.0014
# 121824/240000 [==============>...............] - ETA: 2s - loss: 0.0014
# 124576/240000 [==============>...............] - ETA: 2s - loss: 0.0013
# 127296/240000 [==============>...............] - ETA: 2s - loss: 0.0014
# 130048/240000 [===============>..............] - ETA: 2s - loss: 0.0014
# 132800/240000 [===============>..............] - ETA: 1s - loss: 0.0014
# 135584/240000 [===============>..............] - ETA: 1s - loss: 0.0014
# 138336/240000 [================>.............] - ETA: 1s - loss: 0.0013
# 141088/240000 [================>.............] - ETA: 1s - loss: 0.0013
# 143680/240000 [================>.............] - ETA: 1s - loss: 0.0013
# 146240/240000 [=================>............] - ETA: 1s - loss: 0.0014
# 148992/240000 [=================>............] - ETA: 1s - loss: 0.0013
# 151712/240000 [=================>............] - ETA: 1s - loss: 0.0013
# 154464/240000 [==================>...........] - ETA: 1s - loss: 0.0013
# 157216/240000 [==================>...........] - ETA: 1s - loss: 0.0013
# 159968/240000 [==================>...........] - ETA: 1s - loss: 0.0013
# 162688/240000 [===================>..........] - ETA: 1s - loss: 0.0013
# 165408/240000 [===================>..........] - ETA: 1s - loss: 0.0013
# 168128/240000 [====================>.........] - ETA: 1s - loss: 0.0013
# 170880/240000 [====================>.........] - ETA: 1s - loss: 0.0013
# 173664/240000 [====================>.........] - ETA: 1s - loss: 0.0013
# 176448/240000 [=====================>........] - ETA: 1s - loss: 0.0013
# ...
#  64064/240000 [=======>......................] - ETA: 4s - loss: 0.0010
#  65920/240000 [=======>......................] - ETA: 4s - loss: 0.0010
#  67680/240000 [=======>......................] - ETA: 4s - loss: 0.0010
#  69568/240000 [=======>......................] - ETA: 4s - loss: 0.0010
#  71232/240000 [=======>......................] - ETA: 4s - loss: 0.0010
#  73120/240000 [========>.....................] - ETA: 4s - loss: 0.0010
#  75008/240000 [========>.....................] - ETA: 4s - loss: 0.0010
#  76800/240000 [========>.....................] - ETA: 4s - loss: 0.0010
#  78528/240000 [========>.....................] - ETA: 4s - loss: 0.0010
#  80288/240000 [=========>....................] - ETA: 4s - loss: 0.0010
#  81920/240000 [=========>....................] - ETA: 4s - loss: 0.0010
#  83616/240000 [=========>....................] - ETA: 4s - loss: 0.0010
#  85408/240000 [=========>....................] - ETA: 4s - loss: 0.0010
#  87264/240000 [=========>....................] - ETA: 4s - loss: 0.0010
#  89184/240000 [==========>...................] - ETA: 4s - loss: 0.0010
#  91200/240000 [==========>...................] - ETA: 4s - loss: 0.0010
#  93184/240000 [==========>...................] - ETA: 4s - loss: 0.0010
#  95168/240000 [==========>...................] - ETA: 4s - loss: 0.0010
#  97152/240000 [===========>..................] - ETA: 3s - loss: 0.0010
#  99136/240000 [===========>..................] - ETA: 3s - loss: 0.0010
# 101152/240000 [===========>..................] - ETA: 3s - loss: 0.0010
# 103040/240000 [===========>..................] - ETA: 3s - loss: 0.0011
# 105024/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 106912/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 108928/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 110912/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 112672/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 114560/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 116384/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 118208/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 120000/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 121856/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 123840/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 125824/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 127680/240000 [==============>...............] - ETA: 3s - loss: 0.0010
# 129568/240000 [===============>..............] - ETA: 3s - loss: 0.0011
# 131584/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 133536/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 135488/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 137504/240000 [================>.............] - ETA: 2s - loss: 0.0011
# 139360/240000 [================>.............] - ETA: 2s - loss: 0.0010
# 141312/240000 [================>.............] - ETA: 2s - loss: 0.0010
# 143136/240000 [================>.............] - ETA: 2s - loss: 0.0010
# 145024/240000 [=================>............] - ETA: 2s - loss: 0.0010
# 147008/240000 [=================>............] - ETA: 2s - loss: 0.0010
# 148960/240000 [=================>............] - ETA: 2s - loss: 0.0010
# 150912/240000 [=================>............] - ETA: 2s - loss: 0.0010
# 152864/240000 [==================>...........] - ETA: 2s - loss: 0.0010
# 154848/240000 [==================>...........] - ETA: 2s - loss: 0.0010
# 156832/240000 [==================>...........] - ETA: 2s - loss: 0.0010
# 158784/240000 [==================>...........] - ETA: 2s - loss: 0.0010
# 160544/240000 [===================>..........] - ETA: 2s - loss: 0.0010
# 162144/240000 [===================>..........] - ETA: 2s - loss: 0.0010
# 163808/240000 [===================>..........] - ETA: 2s - loss: 0.0010
# 165664/240000 [===================>..........] - ETA: 2s - loss: 0.0011
# 167360/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 169184/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 170912/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 172832/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 174784/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 176768/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 178752/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 180672/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 182688/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 184672/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 186592/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 188544/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 190528/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 192384/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 194336/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 196256/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 198240/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 200192/240000 [========================>.....] - ETA: 1s - loss: 0.0011
# 202176/240000 [========================>.....] - ETA: 1s - loss: 0.0011
# 204096/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 205920/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 207808/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 209696/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 211488/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 213472/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 215392/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 217312/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 219200/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 221152/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 223040/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 224736/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 226624/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 228608/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 230528/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 232416/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 234272/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 236256/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 238208/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 240000/240000 [==============================] - 7s - loss: 0.0011 - val_loss: 0.0011
# Epoch 15/15
#     32/240000 [..............................] - ETA: 52s - loss: 0.0014
#   1920/240000 [..............................] - ETA: 7s - loss: 0.0011
#   3776/240000 [..............................] - ETA: 6s - loss: 0.0010
#   5664/240000 [..............................] - ETA: 6s - loss: 0.0010
#   7520/240000 [..............................] - ETA: 6s - loss: 0.0010
#   9440/240000 [>.............................] - ETA: 6s - loss: 0.0010
#  11392/240000 [>.............................] - ETA: 6s - loss: 0.0010
#  13312/240000 [>.............................] - ETA: 6s - loss: 0.0010
#  15264/240000 [>.............................] - ETA: 6s - loss: 0.0010
#  17216/240000 [=>............................] - ETA: 5s - loss: 0.0010
#  19168/240000 [=>............................] - ETA: 5s - loss: 0.0011
#  21152/240000 [=>............................] - ETA: 5s - loss: 0.0010
#  23072/240000 [=>............................] - ETA: 5s - loss: 0.0011
#  25024/240000 [==>...........................] - ETA: 5s - loss: 0.0011
#  26912/240000 [==>...........................] - ETA: 5s - loss: 0.0011
#  28864/240000 [==>...........................] - ETA: 5s - loss: 0.0011
#  30656/240000 [==>...........................] - ETA: 5s - loss: 0.0010
#  32480/240000 [===>..........................] - ETA: 5s - loss: 0.0011
#  34400/240000 [===>..........................] - ETA: 5s - loss: 0.0011
#  36384/240000 [===>..........................] - ETA: 5s - loss: 0.0011
#  38336/240000 [===>..........................] - ETA: 5s - loss: 0.0011
#  40352/240000 [====>.........................] - ETA: 5s - loss: 0.0011
#  42304/240000 [====>.........................] - ETA: 5s - loss: 0.0011
#  44320/240000 [====>.........................] - ETA: 5s - loss: 0.0011
#  46144/240000 [====>.........................] - ETA: 5s - loss: 0.0011
#  48096/240000 [=====>........................] - ETA: 5s - loss: 0.0011
#  50048/240000 [=====>........................] - ETA: 5s - loss: 0.0011
#  52032/240000 [=====>........................] - ETA: 4s - loss: 0.0011
#  53952/240000 [=====>........................] - ETA: 4s - loss: 0.0011
#  55936/240000 [=====>........................] - ETA: 4s - loss: 0.0011
#  57824/240000 [======>.......................] - ETA: 4s - loss: 0.0011
#  59648/240000 [======>.......................] - ETA: 4s - loss: 0.0011
#  61472/240000 [======>.......................] - ETA: 4s - loss: 0.0011
#  63296/240000 [======>.......................] - ETA: 4s - loss: 0.0011
#  65152/240000 [=======>......................] - ETA: 4s - loss: 0.0011
#  66976/240000 [=======>......................] - ETA: 4s - loss: 0.0011
#  68800/240000 [=======>......................] - ETA: 4s - loss: 0.0011
#  70656/240000 [=======>......................] - ETA: 4s - loss: 0.0011
#  72512/240000 [========>.....................] - ETA: 4s - loss: 0.0011
#  74496/240000 [========>.....................] - ETA: 4s - loss: 0.0011
#  76416/240000 [========>.....................] - ETA: 4s - loss: 0.0011
#  78368/240000 [========>.....................] - ETA: 4s - loss: 0.0011
#  80096/240000 [=========>....................] - ETA: 4s - loss: 0.0011
#  81952/240000 [=========>....................] - ETA: 4s - loss: 0.0011
#  83872/240000 [=========>....................] - ETA: 4s - loss: 0.0011
#  85792/240000 [=========>....................] - ETA: 4s - loss: 0.0011
#  87776/240000 [=========>....................] - ETA: 4s - loss: 0.0011
#  89728/240000 [==========>...................] - ETA: 3s - loss: 0.0011
#  91712/240000 [==========>...................] - ETA: 3s - loss: 0.0011
#  93728/240000 [==========>...................] - ETA: 3s - loss: 0.0011
#  95712/240000 [==========>...................] - ETA: 3s - loss: 0.0011
#  97632/240000 [===========>..................] - ETA: 3s - loss: 0.0011
#  99616/240000 [===========>..................] - ETA: 3s - loss: 0.0011
# 101568/240000 [===========>..................] - ETA: 3s - loss: 0.0011
# 103360/240000 [===========>..................] - ETA: 3s - loss: 0.0011
# 105248/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 107232/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 109184/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 111136/240000 [============>.................] - ETA: 3s - loss: 0.0011
# 113088/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 115072/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 116992/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 118976/240000 [=============>................] - ETA: 3s - loss: 0.0011
# 120896/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 122688/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 124416/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 126144/240000 [==============>...............] - ETA: 3s - loss: 0.0011
# 127936/240000 [==============>...............] - ETA: 2s - loss: 0.0011
# 129696/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 131424/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 133152/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 134880/240000 [===============>..............] - ETA: 2s - loss: 0.0011
# 136704/240000 [================>.............] - ETA: 2s - loss: 0.0011
# 138592/240000 [================>.............] - ETA: 2s - loss: 0.0011
# 140448/240000 [================>.............] - ETA: 2s - loss: 0.0011
# 142432/240000 [================>.............] - ETA: 2s - loss: 0.0011
# 144384/240000 [=================>............] - ETA: 2s - loss: 0.0011
# 146240/240000 [=================>............] - ETA: 2s - loss: 0.0011
# 148064/240000 [=================>............] - ETA: 2s - loss: 0.0011
# 149760/240000 [=================>............] - ETA: 2s - loss: 0.0011
# 151424/240000 [=================>............] - ETA: 2s - loss: 0.0011
# 153184/240000 [==================>...........] - ETA: 2s - loss: 0.0011
# 154816/240000 [==================>...........] - ETA: 2s - loss: 0.0011
# 156608/240000 [==================>...........] - ETA: 2s - loss: 0.0011
# 158592/240000 [==================>...........] - ETA: 2s - loss: 0.0011
# 160576/240000 [===================>..........] - ETA: 2s - loss: 0.0011
# 162432/240000 [===================>..........] - ETA: 2s - loss: 0.0011
# 164416/240000 [===================>..........] - ETA: 2s - loss: 0.0011
# 166368/240000 [===================>..........] - ETA: 1s - loss: 0.0011
# 168352/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 170208/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 172128/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 174112/240000 [====================>.........] - ETA: 1s - loss: 0.0011
# 176032/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 178080/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 180128/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 182112/240000 [=====================>........] - ETA: 1s - loss: 0.0011
# 184096/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 186048/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 188064/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 190048/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 191968/240000 [======================>.......] - ETA: 1s - loss: 0.0011
# 193824/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 195840/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 197600/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 199552/240000 [=======================>......] - ETA: 1s - loss: 0.0011
# 201504/240000 [========================>.....] - ETA: 1s - loss: 0.0011
# 203488/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 205312/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 207328/240000 [========================>.....] - ETA: 0s - loss: 0.0011
# 209312/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 211296/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 213280/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 215296/240000 [=========================>....] - ETA: 0s - loss: 0.0011
# 217280/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 219232/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 221184/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 223168/240000 [==========================>...] - ETA: 0s - loss: 0.0011
# 225024/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 227008/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 228960/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 230944/240000 [===========================>..] - ETA: 0s - loss: 0.0011
# 232832/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 234848/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 236768/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 238784/240000 [============================>.] - ETA: 0s - loss: 0.0011
# 240000/240000 [==============================] - 7s - loss: 0.0011 - val_loss: 0.0010
# RMSE 100+50+50+50+1:
#  0.0323329072937

# %%
tf3ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), tfTest3, [1]*len(y_test)), dtype = stdTypes), binning)
tf4ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), tfTest4, [1]*len(y_test)), dtype = stdTypes), binning)
tf5ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), tfTest5, [1]*len(y_test)), dtype = stdTypes), binning)
tf6ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), tfTest6, [1]*len(y_test)), dtype = stdTypes), binning)
tf7ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), tfTest7, [1]*len(y_test)), dtype = stdTypes), binning)

fig, ax0 = prepareRocPlot({"SKL RF":              (sklRfROC,'black'),
                           "NN #3 (10+1)":        (tf3ROC,'gray'),
                           "NN #4 (10+5+1)":      (tf4ROC,'cyan'),
                           "NN #5 (100+50+1)":    (tf5ROC,'green'),
                           "NN #6 (100+50+50+1)": (tf6ROC,'brown'),
                           "NN #7 (100+50+50+50+1)": (tf7ROC,'blue'),
                           },legPos='lower right')

ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0001, 1.)
plt.show()

# %% [markdown]
# ROC performance of the NN models is pretty close to the one of RF model except for NN #3 and #4 that were not lucky in this round of training and were not optimized to the best. There is still a bit of variability in the model performance from one round of training to another. The blocks below demonstrate performance of few saved models that started with a different set of initial weights and ended up having a better ROC performance.

# %%
from keras.models import load_model

#tfModel3.save('/home/kkotov/work/notebooks/tfModel3.h5')
#tfModel4.save('/home/kkotov/work/notebooks/tfModel4.h5')
#tfModel5.save('/home/kkotov/work/notebooks/tfModel5.h5')
#tfModel6.save('/home/kkotov/work/notebooks/tfModel6.h5')
#tfModel7.save('/home/kkotov/work/notebooks/_tfModel7.h5')

_tfModel3 = load_model('/home/kkotov/work/notebooks/tfModel3.h5')
_tfModel4 = load_model('/home/kkotov/work/notebooks/tfModel4.h5')
_tfModel5 = load_model('/home/kkotov/work/notebooks/tfModel5.h5')
_tfModel6 = load_model('/home/kkotov/work/notebooks/tfModel6.h5')
_tfModel7 = load_model('/home/kkotov/work/notebooks/_tfModel7.h5')
_tfTest3 = 1./_tfModel3.predict(x_test)**4
_tfTest4 = 1./_tfModel4.predict(x_test)**4
_tfTest5 = 1./_tfModel5.predict(x_test)**4
_tfTest6 = 1./_tfModel6.predict(x_test)**4
_tfTest7 = 1./_tfModel7.predict(x_test)**4

_tf3ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), _tfTest3, [1]*len(y_test)), dtype = stdTypes), binning)
_tf4ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), _tfTest4, [1]*len(y_test)), dtype = stdTypes), binning)
_tf5ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), _tfTest5, [1]*len(y_test)), dtype = stdTypes), binning)
_tf6ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), _tfTest6, [1]*len(y_test)), dtype = stdTypes), binning)
_tf7ROC = rocMetric(np.array(zip(1./testSet['ptTrueInv'].values.ravel(), _tfTest7, [1]*len(y_test)), dtype = stdTypes), binning)

fig, ax0 = prepareRocPlot({"SKL RF":              (sklRfROC,'black'),
                           "NN #3 (10+1)":        (_tf3ROC,'gray'),
                           "NN #4 (10+5+1)":      (_tf4ROC,'cyan'),
                           "NN #5 (100+50+1)":    (_tf5ROC,'green'),
                           "NN #6 (100+50+50+1)": (_tf6ROC,'brown'),
                           "NN #7 (100+50+50+50+1)": (_tf7ROC,'blue'),
                           },legPos='lower right')

ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0001, 1.)
plt.show()

# %%
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
plt.hist(1./testSet['ptTrueInv'].values.ravel(), bins=100, range=[0, 50], alpha=0.5 )
plt.hist(   tfTest7, bins=100, range=[0, 50], alpha=0.5 )
ax0.set_xlim(0., 50)
ax0.set_ylabel(r"# events", fontsize=18)
ax0.set_xlabel(r"pT (GeV)", fontsize=18)
plt.yscale('log')
plt.title("Target (blue) and predicted (green) pT spectra", fontsize=20)
plt.show()

# %% [markdown]
# Let's try my favorite [H2O](http://h2o.ai) neural network implementation.

# %%
import h2o
h2o.init()

# load data
fr = h2o.import_file(path="/home/kkotov/work/emtfPtRegression/2017.09.07/one.csv")

# note categorical predictors
fr[cat] = fr[cat].asfactor()
fr["invSqrt2PtTrue"] = 1./fr["muPtGen"].sqrt().sqrt()

print fr.columns
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321.
# .
# .
# .
# .
#  not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "1.8.0_151"; OpenJDK Runtime Environment (build 1.8.0_151-8u151-b12-0ubuntu0.16.04.2-b12); OpenJDK 64-Bit Server VM (build 25.151-b12, mixed mode)
#   Starting server from /usr/local/lib/python2.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpIWEACY
#   JVM stdout: /tmp/tmpIWEACY/h2o_kkotov_started_from_python.out
#   JVM stderr: /tmp/tmpIWEACY/h2o_kkotov_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321...
#  successful.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         01 secs
# H2O cluster version:        3.14.0.7
# H2O cluster version age:    1 month and 9 days
# H2O cluster name:           H2O_from_python_kkotov_0awjik
# H2O cluster total nodes:    1
# H2O cluster free memory:    3.445 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, AutoML, Core V3, Core V4
# Python version:             2.7.12 final
# --------------------------  ----------------------------------------
# Parse progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █████████████████████████████████████████| 100%
# [u'muPtGen', u'theta', u'st1_ring2', u'dPhi12', u'dPhi13', u'dPhi14', u'dPhi23', u'dPhi24', u'dPhi34', u'dTheta12', u'dTheta13', u'dTheta14', u'dTheta23', u'dTheta24', u'dTheta34', u'dPhiS4', u'dPhiS4A', u'dPhiS3', u'dPhiS3A', u'clct1', u'clct2', u'clct3', u'clct4', u'fr1', u'fr2', u'fr3', u'fr4', u'rpc1', u'rpc2', u'rpc3', u'rpc4', u'ptXML', u'trainIdx', u'ranger', u'gbm', 'invSqrt2PtTrue']

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

# Arrange the a simple NN configuration with a couple of hidden layers comprising 50 units each
h2oDlModel = H2ODeepLearningEstimator(
                 nfolds = 10,
                 hidden = [50,50],
                 epochs = 100)

# select only those predictors used to train the other models
predictors = range(1, 9) # theta, st1_ring2, dPhi12, dPhi13, dPhi14, dPhi23, dPhi24, dPhi34
predictors.append(11)    # dTheta14
predictors.extend( range(15,20) ) # dPhiS3, dPhiS4, dPhiS4A, dPhiS3, dPhiS3A, clct1
predictors.append(23)    # fr1
predictors.extend( range(27,31) ) # rpc1, rpc2, rpc3, rpc4

print [ fr.columns[i] for i in predictors ]

train_data = fr[ fr["trainIdx"] == 1 ]
test_data  = fr[ fr["trainIdx"] == 0 ]

h2oDlModel.train(x = predictors, y = 35, training_frame = train_data)
# Out:
# [u'theta', u'st1_ring2', u'dPhi12', u'dPhi13', u'dPhi14', u'dPhi23', u'dPhi24', u'dPhi34', u'dTheta14', u'dPhiS4', u'dPhiS4A', u'dPhiS3', u'dPhiS3A', u'clct1', u'fr1', u'rpc1', u'rpc2', u'rpc3', u'rpc4']
# deeplearning Model Build progress: |
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
# | 100%

# %%
# I load one of the previously saved models below
#_h2oDlModel = h2o.load_model("/home/kkotov/work/notebooks/DeepLearning_model_python_1509441710262_12")
# otherwise use the one from above
_h2oDlModel = h2oDlModel

dlH2Otest = (1./_h2oDlModel.predict(test_data)['predict']).apply(lambda x: x*x*x*x).as_data_frame()["predict"].values.ravel()

dlH2OROC = rocMetric( np.array( zip(test_data.as_data_frame()["muPtGen"].values.ravel(),
                                    [i for i in dlH2Otest],
                                    [1]*len(dlH2Otest) ),
                               dtype = stdTypes ),
                      binning)

fig, ax0 = prepareRocPlot({"EMTF baseline": (baseROC, 'red'),
                           "H2O":           (dlH2OROC,'blue'),
                           "SKL RF":        (sklRfROC,'grey'),
                           "Keras+TF":       (tf7ROC,'green'),
                           },{15:'yellow',20:'magenta'},
                          legPos='lower right')


ax0.set_ylim(0.0, 1.)
ax0.set_xlim(0.0001, 1.)
plt.show()

# %% [markdown]
# Comparable to Keras+TensorFlow with no tuning and in a very simple configuration! I call it a day, gentlemen.

# %%
fig, ax0 = plt.subplots(figsize=(10.5, 6), facecolor='white', edgecolor='white')
plt.hist(test_data['muPtGen'].as_data_frame()["muPtGen"].values.ravel(), bins=100, range=[0, 50], alpha=0.5 )
plt.hist(   dlH2Otest, bins=100, range=[0, 50], alpha=0.5 )
ax0.set_xlim(0., 50)
ax0.set_ylabel(r"# events", fontsize=18)
ax0.set_xlabel(r"pT (GeV)", fontsize=18)
plt.yscale('log')
plt.title("Target (blue) and predicted (green) pT spectra", fontsize=20)
plt.show()

# %%
# save the model above if you like it
#print h2o.save_model(h2oDlModel, path = "/home/kkotov/work/notebooks/", force=True)

# %% [markdown]
# ## Memory-based models
#
# Next step would be to try Support Vector Machines and Nearest Neighbor methods. In such memory-based models the whole training dataset becomes a model. Playing with SVR from SKLearn I've got a feeling that training takes too long (curse of dimensionality?). Since I don't have much of experience with these methods, I'll save my time and leave it alone for the time being.
